# %% [markdown]
# ## NaPDI machine reading - process SemRep triples, map to OBO and generate machine reading graph with triples
#
# Last run on 2022-04-06 with green tea, kratom and microbiome output

# %%
import pandas as pd
import numpy as np
import pickle
from rdflib.namespace import OWL, RDF, RDFS

# %%
import os
files = os.listdir('semrep_data/')
#read all files in semrep_data
files[0][-3:]
df = pd.DataFrame(columns=['index', 'pmid', 'subject_cui', 'subject_type', 'relation', 'object_cui', 'object_type', 'year', 'sentence'])
for file in files:
    if file[-3:] == 'tsv':
        print('Loading file: ', file)
        df_temp = pd.read_csv('semrep_data/'+file, sep='\t')
        print(df_temp.info())
        df = pd.concat([df, df_temp], ignore_index=True)
df.info()
# Out:
# Loading file:  greentea_pmid_all_predicates_semrep-errors-fixed.tsv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48957 entries, 0 to 48956
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         48957 non-null  int64
#  1   pmid          48957 non-null  int64
#  2   subject_cui   47969 non-null  object
#  3   subject_name  47969 non-null  object
#  4   subject_type  48957 non-null  object
#  5   relation      48957 non-null  object
#  6   object_cui    47668 non-null  object
#  7   object_name   47668 non-null  object
#  8   object_type   48957 non-null  object
#  9   year          48957 non-null  object
#  10  sentence      48957 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 4.1+ MB
# None
# Loading file:  microbiome_pmid_all_predicates_semrep-errors-fixed.tsv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14893 entries, 0 to 14892
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         14893 non-null  int64
#  1   pmid          14893 non-null  int64
#  2   subject_cui   14698 non-null  object
#  3   subject_name  14698 non-null  object
#  4   subject_type  14893 non-null  object
#  5   relation      14893 non-null  object
#  6   object_cui    14717 non-null  object
#  7   object_name   14717 non-null  object
#  8   object_type   14893 non-null  object
#  9   year          14893 non-null  object
#  10  sentence      14893 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 1.2+ MB
# None
# Loading file:  greentea_pmid_all_predicates_semrep-0-151.tsv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46752 entries, 0 to 46751
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         46752 non-null  int64
#  1   pmid          46752 non-null  int64
#  2   subject_cui   45782 non-null  object
#  3   subject_name  45782 non-null  object
#  4   subject_type  46752 non-null  object
#  5   relation      46752 non-null  object
#  6   object_cui    45536 non-null  object
#  7   object_name   45536 non-null  object
#  8   object_type   46752 non-null  object
#  9   year          46752 non-null  object
#  10  sentence      46752 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 3.9+ MB
# None
# Loading file:  kratom_pmid_all_predicates_semrep.tsv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1765 entries, 0 to 1764
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         1765 non-null   int64
#  1   pmid          1765 non-null   int64
#  2   subject_cui   1735 non-null   object
#  3   subject_name  1735 non-null   object
#  4   subject_type  1765 non-null   object
#  5   relation      1765 non-null   object
#  6   object_cui    1715 non-null   object
#  7   object_name   1715 non-null   object
#  8   object_type   1765 non-null   object
#  9   year          1765 non-null   object
#  10  sentence      1765 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 151.8+ KB
# None
# Loading file:  greentea_pmid_all_predicates_semrep.tsv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151429 entries, 0 to 151428
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   index         151429 non-null  int64
#  1   pmid          151429 non-null  int64
#  2   subject_cui   148489 non-null  object
#  3   subject_name  148489 non-null  object
#  4   subject_type  151429 non-null  object
#  5   relation      151429 non-null  object
#  6   object_cui    147550 non-null  object
#  7   object_name   147550 non-null  object
#  8   object_type   151429 non-null  object
#  9   year          151159 non-null  object
#  10  sentence      151429 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 12.7+ MB
# None
# Loading file:  kratom_pmid_all_predicates_semrep-errors-fixed.tsv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1475 entries, 0 to 1474
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         1475 non-null   int64
#  1   pmid          1475 non-null   int64
#  2   subject_cui   1439 non-null   object
#  3   subject_name  1439 non-null   object
#  4   subject_type  1475 non-null   object
#  5   relation      1475 non-null   object
#  6   object_cui    1432 non-null   object
#  7   object_name   1432 non-null   object
#  8   object_type   1475 non-null   object
#  9   year          1475 non-null   object
#  10  sentence      1475 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 126.9+ KB
# None
# Loading file:  microbiome_pmid_all_predicates_semrep.tsv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13207 entries, 0 to 13206
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         13207 non-null  int64
#  1   pmid          13207 non-null  int64
#  2   subject_cui   13040 non-null  object
#  3   subject_name  13040 non-null  object
#  4   subject_type  13207 non-null  object
#  5   relation      13207 non-null  object
#  6   object_cui    13053 non-null  object
#  7   object_name   13053 non-null  object
#  8   object_type   13207 non-null  object
#  9   year          13207 non-null  object
#  10  sentence      13207 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 1.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278478 entries, 0 to 278477
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   index         278478 non-null  object
#  1   pmid          278478 non-null  object
#  2   subject_cui   273152 non-null  object
#  3   subject_type  278478 non-null  object
#  4   relation      278478 non-null  object
#  5   object_cui    271671 non-null  object
#  6   object_type   278478 non-null  object
#  7   year          278208 non-null  object
#  8   sentence      278478 non-null  object
#  9   subject_name  273152 non-null  object
#  10  object_name   271671 non-null  object
# dtypes: object(11)
# memory usage: 23.4+ MB

# %%
df.head()
# Out:
#   index      pmid subject_cui subject_type         relation object_cui  \
# 0     0  29913456    C1704263    orch,phsu          AFFECTS   C2349205
# 1     1  29913456    C0014518         dsyn       PROCESS_OF   C0596888
# 2     2  29913456    C0043047    inch,phsu  ADMINISTERED_TO   C0034693
# 3     3  29913456    C0232164         ortf       PROCESS_OF   C0003062
# 4     4  29913456    C0185115         topp             USES   C0006675
#
#       object_type  year                                           sentence  \
# 0            fndg  2018  29913456_ascii.txt.tx.1 Abstract Background/Ai...
# 1            anim  2018  29913456_ascii.txt.tx.2 Methods: The study pop...
# 2            mamm  2018                                                 \n
# 3            anim  2018  29913456_ascii.txt.tx.1 Then, in vivo and ex v...
# 4  bacs,elii,phsu  2018  29913456_ascii.txt.tx.2 Results:  GTE  cardiom...
#
#                  subject_name        object_name
# 0           Green Tea Extract       Normal heart
# 1  Toxic Epidermal Necrolysis      mature animal
# 2                       Water  Rattus norvegicus
# 3            Cardiac function            Animals
# 4                  Extraction            Calcium

# %%
#processing TSV
'''
0. Concatenate files and remove duplicates, get stats of unique PMIDs and triples
1. Fix sentence (empty takes value of previous sentence)
2. Extract year from date and save
3. Map from CUI to GO, HPO where available
4. Map with OntoRunNER
'''
# Out:
# '\n0. Concatenate files and remove duplicates, get stats of unique PMIDs and triples\n1. Fix sentence (empty takes value of previous sentence)\n2. Extract year from date and save\n3. Map from CUI to GO, HPO where available\n4. Map with OntoRunNER\n'

# %%
df = df.drop_duplicates(ignore_index=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277812 entries, 0 to 277811
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   index         277812 non-null  object
#  1   pmid          277812 non-null  object
#  2   subject_cui   272500 non-null  object
#  3   subject_type  277812 non-null  object
#  4   relation      277812 non-null  object
#  5   object_cui    271016 non-null  object
#  6   object_type   277812 non-null  object
#  7   year          277542 non-null  object
#  8   sentence      277812 non-null  object
#  9   subject_name  272500 non-null  object
#  10  object_name   271016 non-null  object
# dtypes: object(11)
# memory usage: 23.3+ MB

# %%
df = df.fillna('')

# %%
len(df.pmid.unique())
# Out:
# 775

# %%
import re

# %%
#use re to fix year as format is not consistent
for i in range(len(df.index)):
    pub_date = df.at[i, 'year']
    x = re.findall(r'\d+', pub_date)
    if x:
        df.at[i, 'year'] = x[0]
df.head()
# Out:
#    index      pmid subject_cui subject_type         relation object_cui  \
# 0      0  29913456    C1704263    orch,phsu          AFFECTS   C2349205
# 1      1  29913456    C0014518         dsyn       PROCESS_OF   C0596888
# 2      2  29913456    C0043047    inch,phsu  ADMINISTERED_TO   C0034693
# 3      3  29913456    C0232164         ortf       PROCESS_OF   C0003062
# 4      4  29913456    C0185115         topp             USES   C0006675
#
#       object_type  year                                           sentence  \
# 0            fndg  2018  29913456_ascii.txt.tx.1 Abstract Background/Ai...
# 1            anim  2018  29913456_ascii.txt.tx.2 Methods: The study pop...
# 2            mamm  2018                                                 \n
# 3            anim  2018  29913456_ascii.txt.tx.1 Then, in vivo and ex v...
# 4  bacs,elii,phsu  2018  29913456_ascii.txt.tx.2 Results:  GTE  cardiom...
#
#                  subject_name        object_name
# 0           Green Tea Extract       Normal heart
# 1  Toxic Epidermal Necrolysis      mature animal
# 2                       Water  Rattus norvegicus
# 3            Cardiac function            Animals
# 4                  Extraction            Calcium

# %%
source_sent = df['sentence'].tolist()

# %%
len(source_sent)
# Out:
# 277812

# %%
##fix source sentence
last = len(source_sent)-1
sentences = []
count = 0
for sent in source_sent:
    sent = sent.strip()
    flag = 0
    if sent == '' or '|||' in sent:
        for i in range(count, -1, -1):
            if source_sent[i].strip() == '' or '|||' in source_sent[i].strip():
                continue
            else:
                sentences.append(source_sent[i].strip())
                flag = 1
                break
        if flag == 0:
            sentences.append(sent.strip())
    else:
        sentences.append(sent.strip())
    count += 1
            
len(sentences)
# Out:
# 277812

# %%
sentences = pd.Series(sentences)

# %%
df['source_text'] = sentences
df.head()
# Out:
#    index      pmid subject_cui subject_type         relation object_cui  \
# 0      0  29913456    C1704263    orch,phsu          AFFECTS   C2349205
# 1      1  29913456    C0014518         dsyn       PROCESS_OF   C0596888
# 2      2  29913456    C0043047    inch,phsu  ADMINISTERED_TO   C0034693
# 3      3  29913456    C0232164         ortf       PROCESS_OF   C0003062
# 4      4  29913456    C0185115         topp             USES   C0006675
#
#       object_type  year                                           sentence  \
# 0            fndg  2018  29913456_ascii.txt.tx.1 Abstract Background/Ai...
# 1            anim  2018  29913456_ascii.txt.tx.2 Methods: The study pop...
# 2            mamm  2018                                                 \n
# 3            anim  2018  29913456_ascii.txt.tx.1 Then, in vivo and ex v...
# 4  bacs,elii,phsu  2018  29913456_ascii.txt.tx.2 Results:  GTE  cardiom...
#
#                  subject_name        object_name  \
# 0           Green Tea Extract       Normal heart
# 1  Toxic Epidermal Necrolysis      mature animal
# 2                       Water  Rattus norvegicus
# 3            Cardiac function            Animals
# 4                  Extraction            Calcium
#
#                                          source_text
# 0  29913456_ascii.txt.tx.1 Abstract Background/Ai...
# 1  29913456_ascii.txt.tx.2 Methods: The study pop...
# 2  29913456_ascii.txt.tx.2 Methods: The study pop...
# 3  29913456_ascii.txt.tx.1 Then, in vivo and ex v...
# 4  29913456_ascii.txt.tx.2 Results:  GTE  cardiom...

# %%
df = df.drop(['sentence', 'index'], axis=1)

# %%
df.head()
# Out:
#        pmid subject_cui subject_type         relation object_cui  \
# 0  29913456    C1704263    orch,phsu          AFFECTS   C2349205
# 1  29913456    C0014518         dsyn       PROCESS_OF   C0596888
# 2  29913456    C0043047    inch,phsu  ADMINISTERED_TO   C0034693
# 3  29913456    C0232164         ortf       PROCESS_OF   C0003062
# 4  29913456    C0185115         topp             USES   C0006675
#
#       object_type  year                subject_name        object_name  \
# 0            fndg  2018           Green Tea Extract       Normal heart
# 1            anim  2018  Toxic Epidermal Necrolysis      mature animal
# 2            mamm  2018                       Water  Rattus norvegicus
# 3            anim  2018            Cardiac function            Animals
# 4  bacs,elii,phsu  2018                  Extraction            Calcium
#
#                                          source_text
# 0  29913456_ascii.txt.tx.1 Abstract Background/Ai...
# 1  29913456_ascii.txt.tx.2 Methods: The study pop...
# 2  29913456_ascii.txt.tx.2 Methods: The study pop...
# 3  29913456_ascii.txt.tx.1 Then, in vivo and ex v...
# 4  29913456_ascii.txt.tx.2 Results:  GTE  cardiom...

# %%
preds = ['affects',
'associated_with',
'augments',
'causes',
'coexists_with',
'complicates',
'disrupts',
'inhibits',
'interacts_with',
'part_of',
'precedes',
'predisposes',
'prevents',
'produces',
'stimulates',
'treats']

# %%
df['predicate'] = df['relation'].str.lower()
df.head()
# Out:
#        pmid subject_cui subject_type         relation object_cui  \
# 0  29913456    C1704263    orch,phsu          AFFECTS   C2349205
# 1  29913456    C0014518         dsyn       PROCESS_OF   C0596888
# 2  29913456    C0043047    inch,phsu  ADMINISTERED_TO   C0034693
# 3  29913456    C0232164         ortf       PROCESS_OF   C0003062
# 4  29913456    C0185115         topp             USES   C0006675
#
#       object_type  year                subject_name        object_name  \
# 0            fndg  2018           Green Tea Extract       Normal heart
# 1            anim  2018  Toxic Epidermal Necrolysis      mature animal
# 2            mamm  2018                       Water  Rattus norvegicus
# 3            anim  2018            Cardiac function            Animals
# 4  bacs,elii,phsu  2018                  Extraction            Calcium
#
#                                          source_text        predicate
# 0  29913456_ascii.txt.tx.1 Abstract Background/Ai...          affects
# 1  29913456_ascii.txt.tx.2 Methods: The study pop...       process_of
# 2  29913456_ascii.txt.tx.2 Methods: The study pop...  administered_to
# 3  29913456_ascii.txt.tx.1 Then, in vivo and ex v...       process_of
# 4  29913456_ascii.txt.tx.2 Results:  GTE  cardiom...             uses

# %%
df = df.drop(['relation'], axis=1)

# %%
dfn = df[df['predicate'].isin(preds)]
dfn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158549 entries, 0 to 277811
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   pmid          158549 non-null  int64
#  1   subject_cui   158549 non-null  object
#  2   subject_type  158549 non-null  object
#  3   object_cui    158549 non-null  object
#  4   object_type   158549 non-null  object
#  5   year          158549 non-null  object
#  6   subject_name  158549 non-null  object
#  7   object_name   158549 non-null  object
#  8   source_text   158549 non-null  object
#  9   predicate     158549 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 13.3+ MB

# %%
dfn['predicate'].value_counts()
# Out:
# interacts_with     26146
# affects            18902
# part_of            18850
# inhibits           15788
# coexists_with      15521
# stimulates         14490
# treats             13062
# causes              9540
# disrupts            7800
# augments            7435
# associated_with     3968
# produces            3213
# prevents            2264
# predisposes         1217
# precedes             309
# complicates           44
# Name: predicate, dtype: int64

# %%
dfn['subject_map'] = None
dfn['object_map'] = None
dfn['predicate_obo'] = None
dfn['subject_obo'] = None
dfn['object_obo'] = None
# Out:
# /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
##add relation ontology mapping
predMapSemRep = {
'affects': 'RO_0002596',
'associated_with': 'RO_0002610',
'augments': 'RO_0002598',
'causes': 'RO_0002566',
'coexists_with': 'RO_0002490',
'complicates': 'RO_0003309',
'disrupts': 'RO_0002212',
'inhibits': 'RO_0002449',
'interacts_with': 'RO_0002434',
'part_of': 'BFO_0000050',
'precedes': 'BFO_0000063',
'predisposes': 'RO_0003302',
'prevents': 'RO_0002599',
'produces': 'RO_0003000',
'stimulates': 'RO_0002213',
'treats': 'RO_0002606'
}

# %%
def relation_mapping(row):
    rel = row['predicate'].lower()
    if rel in predMapSemRep:
        return predMapSemRep[rel]
    else:
        return ''

# %%
dfn['predicate_obo'] = dfn.apply(relation_mapping, axis=1)
dfn.head()
# Out:
# /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        pmid subject_cui subject_type object_cui     object_type  year  \
# 0  29913456    C1704263    orch,phsu   C2349205            fndg  2018
# 5  29913456                gngm,aapp   C2744579  aapp,gngm,enzy  2018
# 6  29913456    C0020538         dsyn   C0878544            dsyn  2018
# 8  29913456    C0059438    orch,phsu   C0035126            inpo  2018
# 9  29913456    C0242973         patf   C0878544            dsyn  2018
#
#                subject_name            object_name  \
# 0         Green Tea Extract           Normal heart
# 5                            ATP8A2 protein, human
# 6      Hypertensive disease       Cardiomyopathies
# 8  epigallocatechin gallate     Reperfusion Injury
# 9   Ventricular Dysfunction       Cardiomyopathies
#
#                                          source_text      predicate  \
# 0  29913456_ascii.txt.tx.1 Abstract Background/Ai...        affects
# 5  29913456_ascii.txt.tx.2 Consistent with functi...     stimulates
# 6  29913456_ascii.txt.tx.1 Previous experimental ...  coexists_with
# 8  29913456_ascii.txt.tx.1 Previous experimental ...         treats
# 9  29913456_ascii.txt.tx.1 Previous experimental ...  coexists_with
#
#   subject_map object_map predicate_obo subject_obo object_obo
# 0        None       None    RO_0002596        None       None
# 5        None       None    RO_0002213        None       None
# 6        None       None    RO_0002490        None       None
# 8        None       None    RO_0002606        None       None
# 9        None       None    RO_0002490        None       None

# %%
dfn = dfn.reset_index(drop=True)
dfn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158549 entries, 0 to 158548
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   pmid           158549 non-null  int64
#  1   subject_cui    158549 non-null  object
#  2   subject_type   158549 non-null  object
#  3   object_cui     158549 non-null  object
#  4   object_type    158549 non-null  object
#  5   year           158549 non-null  object
#  6   subject_name   158549 non-null  object
#  7   object_name    158549 non-null  object
#  8   source_text    158549 non-null  object
#  9   predicate      158549 non-null  object
#  10  subject_map    0 non-null       object
#  11  object_map     0 non-null       object
#  12  predicate_obo  158549 non-null  object
#  13  subject_obo    0 non-null       object
#  14  object_obo     0 non-null       object
# dtypes: int64(1), object(14)
# memory usage: 18.1+ MB

# %%
#filter by semantic types here and then start mapping
excluded_semtype = ['acty','bhvr','evnt','gora','mcha','ocac', #Occupational Activity
'clas',
'cnce',
'ftcn',
'grpa',
'idcn',
'inpr',
'lang',
'qlco',
'qnco',
'rnlw',
'spco',
'tmco',
'enty',
'mnob',
'phob',
'bmod',
'ocdi',
'hcro',
'orgt',
'pros',
'shro',
'eehu',
'hcpp']

# %%
dfn1 = dfn[~dfn['subject_type'].isin(excluded_semtype)]
dfn1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158542 entries, 0 to 158548
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   pmid           158542 non-null  int64
#  1   subject_cui    158542 non-null  object
#  2   subject_type   158542 non-null  object
#  3   object_cui     158542 non-null  object
#  4   object_type    158542 non-null  object
#  5   year           158542 non-null  object
#  6   subject_name   158542 non-null  object
#  7   object_name    158542 non-null  object
#  8   source_text    158542 non-null  object
#  9   predicate      158542 non-null  object
#  10  subject_map    0 non-null       object
#  11  object_map     0 non-null       object
#  12  predicate_obo  158542 non-null  object
#  13  subject_obo    0 non-null       object
#  14  object_obo     0 non-null       object
# dtypes: int64(1), object(14)
# memory usage: 19.4+ MB

# %%
dfn2 = dfn1[~dfn1['object_type'].isin(excluded_semtype)]
dfn2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158519 entries, 0 to 158548
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   pmid           158519 non-null  int64
#  1   subject_cui    158519 non-null  object
#  2   subject_type   158519 non-null  object
#  3   object_cui     158519 non-null  object
#  4   object_type    158519 non-null  object
#  5   year           158519 non-null  object
#  6   subject_name   158519 non-null  object
#  7   object_name    158519 non-null  object
#  8   source_text    158519 non-null  object
#  9   predicate      158519 non-null  object
#  10  subject_map    0 non-null       object
#  11  object_map     0 non-null       object
#  12  predicate_obo  158519 non-null  object
#  13  subject_obo    0 non-null       object
#  14  object_obo     0 non-null       object
# dtypes: int64(1), object(14)
# memory usage: 19.4+ MB

# %%
##exclude all concepts that occur in SemMedDB GENERIC.CONCEPT table
#Get CSV file - https://lhncbc.nlm.nih.gov/ii/tools/SemRep_SemMedDB_SKR/SemMedDB_download.html -- doesn't work
#download from halil covid-19 repository - 
semmed = pd.read_csv('cui_to_ontology_maps/semmedVER43_2020_R_GENERIC_CONCEPT.csv', header=None)
semmed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       259 non-null    int64
#  1   1       259 non-null    object
#  2   2       259 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 6.2+ KB

# %%
semmed.head()
# Out:
#       0         1                                    2
# 0  1983  C0001687                  Adverse effects NEC
# 1  1984  C0002526  Amino Acids, Peptides, and Proteins
# 2  1985  C0003043                             Animalia
# 3  1986  C0003062                              Animals
# 4  1987  C0005515                   Biological Factors

# %%
semmed = semmed.rename(columns={1: 'CUI', 2: 'concept_name'})
semmed.head()
# Out:
#       0       CUI                         concept_name
# 0  1983  C0001687                  Adverse effects NEC
# 1  1984  C0002526  Amino Acids, Peptides, and Proteins
# 2  1985  C0003043                             Animalia
# 3  1986  C0003062                              Animals
# 4  1987  C0005515                   Biological Factors

# %%
semmed = semmed.drop([0], axis=1)
semmed.head()
# Out:
#         CUI                         concept_name
# 0  C0001687                  Adverse effects NEC
# 1  C0002526  Amino Acids, Peptides, and Proteins
# 2  C0003043                             Animalia
# 3  C0003062                              Animals
# 4  C0005515                   Biological Factors

# %%
#drop rows where subject and object matches generic concepts
generic_cui = semmed.CUI.tolist()
len(generic_cui)
# Out:
# 259

# %%
dfn2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158519 entries, 0 to 158548
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   pmid           158519 non-null  int64
#  1   subject_cui    158519 non-null  object
#  2   subject_type   158519 non-null  object
#  3   object_cui     158519 non-null  object
#  4   object_type    158519 non-null  object
#  5   year           158519 non-null  object
#  6   subject_name   158519 non-null  object
#  7   object_name    158519 non-null  object
#  8   source_text    158519 non-null  object
#  9   predicate      158519 non-null  object
#  10  subject_map    0 non-null       object
#  11  object_map     0 non-null       object
#  12  predicate_obo  158519 non-null  object
#  13  subject_obo    0 non-null       object
#  14  object_obo     0 non-null       object
# dtypes: int64(1), object(14)
# memory usage: 19.4+ MB

# %%
dfn3 = dfn2[~dfn2['subject_cui'].isin(generic_cui)]
dfn3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152450 entries, 0 to 158548
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   pmid           152450 non-null  int64
#  1   subject_cui    152450 non-null  object
#  2   subject_type   152450 non-null  object
#  3   object_cui     152450 non-null  object
#  4   object_type    152450 non-null  object
#  5   year           152450 non-null  object
#  6   subject_name   152450 non-null  object
#  7   object_name    152450 non-null  object
#  8   source_text    152450 non-null  object
#  9   predicate      152450 non-null  object
#  10  subject_map    0 non-null       object
#  11  object_map     0 non-null       object
#  12  predicate_obo  152450 non-null  object
#  13  subject_obo    0 non-null       object
#  14  object_obo     0 non-null       object
# dtypes: int64(1), object(14)
# memory usage: 18.6+ MB

# %%
dfn4 = dfn3[~dfn3['object_cui'].isin(generic_cui)]
dfn4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145638 entries, 0 to 158548
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   pmid           145638 non-null  int64
#  1   subject_cui    145638 non-null  object
#  2   subject_type   145638 non-null  object
#  3   object_cui     145638 non-null  object
#  4   object_type    145638 non-null  object
#  5   year           145638 non-null  object
#  6   subject_name   145638 non-null  object
#  7   object_name    145638 non-null  object
#  8   source_text    145638 non-null  object
#  9   predicate      145638 non-null  object
#  10  subject_map    0 non-null       object
#  11  object_map     0 non-null       object
#  12  predicate_obo  145638 non-null  object
#  13  subject_obo    0 non-null       object
#  14  object_obo     0 non-null       object
# dtypes: int64(1), object(14)
# memory usage: 17.8+ MB

# %%
#handle subclassof when mapping to obo

# %%
#map from UMLS to GO, HPO
with open('cui_to_ontology_maps/go_hpo_map_dict.pickle', 'rb') as filep:
    go_hpo_mapping_dict = pickle.load(filep)
len(go_hpo_mapping_dict)
# Out:
# 87745

# %%
def umls_go_hpo_map(row, col):
    if col == 'subject':
        cui = row['subject_cui']
    elif col == 'object':
        cui = row['object_cui']
    else:
        print('specify if subject or object mapping required')
        exit(0)
    if cui in go_hpo_mapping_dict:
        if len(go_hpo_mapping_dict):
            return go_hpo_mapping_dict[cui][0]
    return None

# %%
dfn4['subject_obo'] = dfn4.apply(umls_go_hpo_map, axis=1, col='subject')
dfn4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145638 entries, 0 to 158548
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   pmid           145638 non-null  int64
#  1   subject_cui    145638 non-null  object
#  2   subject_type   145638 non-null  object
#  3   object_cui     145638 non-null  object
#  4   object_type    145638 non-null  object
#  5   year           145638 non-null  object
#  6   subject_name   145638 non-null  object
#  7   object_name    145638 non-null  object
#  8   source_text    145638 non-null  object
#  9   predicate      145638 non-null  object
#  10  subject_map    0 non-null       object
#  11  object_map     0 non-null       object
#  12  predicate_obo  145638 non-null  object
#  13  subject_obo    7160 non-null    object
#  14  object_obo     0 non-null       object
# dtypes: int64(1), object(14)
# memory usage: 17.8+ MB
# /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfn4['object_obo'] = dfn4.apply(umls_go_hpo_map, axis=1, col='object')
dfn4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145638 entries, 0 to 158548
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   pmid           145638 non-null  int64
#  1   subject_cui    145638 non-null  object
#  2   subject_type   145638 non-null  object
#  3   object_cui     145638 non-null  object
#  4   object_type    145638 non-null  object
#  5   year           145638 non-null  object
#  6   subject_name   145638 non-null  object
#  7   object_name    145638 non-null  object
#  8   source_text    145638 non-null  object
#  9   predicate      145638 non-null  object
#  10  subject_map    0 non-null       object
#  11  object_map     0 non-null       object
#  12  predicate_obo  145638 non-null  object
#  13  subject_obo    7160 non-null    object
#  14  object_obo     29282 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 17.8+ MB
# /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfn4 = dfn4.reset_index(drop=True)

# %%
dfn4.head()
# Out:
#        pmid subject_cui subject_type object_cui     object_type  year  \
# 0  29913456    C1704263    orch,phsu   C2349205            fndg  2018
# 1  29913456                gngm,aapp   C2744579  aapp,gngm,enzy  2018
# 2  29913456    C0020538         dsyn   C0878544            dsyn  2018
# 3  29913456    C0059438    orch,phsu   C0035126            inpo  2018
# 4  29913456    C0242973         patf   C0878544            dsyn  2018
#
#                subject_name            object_name  \
# 0         Green Tea Extract           Normal heart
# 1                            ATP8A2 protein, human
# 2      Hypertensive disease       Cardiomyopathies
# 3  epigallocatechin gallate     Reperfusion Injury
# 4   Ventricular Dysfunction       Cardiomyopathies
#
#                                          source_text      predicate  \
# 0  29913456_ascii.txt.tx.1 Abstract Background/Ai...        affects
# 1  29913456_ascii.txt.tx.2 Consistent with functi...     stimulates
# 2  29913456_ascii.txt.tx.1 Previous experimental ...  coexists_with
# 3  29913456_ascii.txt.tx.1 Previous experimental ...         treats
# 4  29913456_ascii.txt.tx.1 Previous experimental ...  coexists_with
#
#   subject_map object_map predicate_obo subject_obo  object_obo
# 0        None       None    RO_0002596        None        None
# 1        None       None    RO_0002213        None        None
# 2        None       None    RO_0002490  HP_0000822  HP_0001638
# 3        None       None    RO_0002606        None        None
# 4        None       None    RO_0002490        None  HP_0001638

# %%
dfn_subset = dfn4

# %%
dfn_subset.head()
# Out:
#        pmid subject_cui subject_type object_cui     object_type  year  \
# 0  29913456    C1704263    orch,phsu   C2349205            fndg  2018
# 1  29913456                gngm,aapp   C2744579  aapp,gngm,enzy  2018
# 2  29913456    C0020538         dsyn   C0878544            dsyn  2018
# 3  29913456    C0059438    orch,phsu   C0035126            inpo  2018
# 4  29913456    C0242973         patf   C0878544            dsyn  2018
#
#                subject_name            object_name  \
# 0         Green Tea Extract           Normal heart
# 1                            ATP8A2 protein, human
# 2      Hypertensive disease       Cardiomyopathies
# 3  epigallocatechin gallate     Reperfusion Injury
# 4   Ventricular Dysfunction       Cardiomyopathies
#
#                                          source_text      predicate  \
# 0  29913456_ascii.txt.tx.1 Abstract Background/Ai...        affects
# 1  29913456_ascii.txt.tx.2 Consistent with functi...     stimulates
# 2  29913456_ascii.txt.tx.1 Previous experimental ...  coexists_with
# 3  29913456_ascii.txt.tx.1 Previous experimental ...         treats
# 4  29913456_ascii.txt.tx.1 Previous experimental ...  coexists_with
#
#   subject_map object_map predicate_obo subject_obo  object_obo
# 0        None       None    RO_0002596        None        None
# 1        None       None    RO_0002213        None        None
# 2        None       None    RO_0002490  HP_0000822  HP_0001638
# 3        None       None    RO_0002606        None        None
# 4        None       None    RO_0002490        None  HP_0001638

# %%
##run the following cells if running ontorunner on unmapped concepts

# %%
unmapped_cui = []
unmapped_string_umls = []
for i in range(len(dfn_subset.index)):
    if not dfn_subset.at[i, 'subject_obo']:
        subcui = dfn_subset.at[i, 'subject_cui']
        if subcui not in unmapped_cui:
            unmapped_cui.append(dfn_subset.at[i, 'subject_cui'])
            unmapped_string_umls.append(dfn_subset.at[i, 'subject_name'])
    if not dfn_subset.at[i, 'object_obo']:
        objcui = dfn_subset.at[i, 'object_cui']
        if objcui not in unmapped_cui:
            unmapped_cui.append(dfn_subset.at[i, 'object_cui'])
            unmapped_string_umls.append(dfn_subset.at[i, 'object_name'])
print(len(unmapped_cui), len(unmapped_string_umls))
# Out:
# 6577 6577

# %%
unmapped_string_umls[:10]
# Out:
# ['Green Tea Extract',
#  'Normal heart',
#  '',
#  'ATP8A2 protein, human',
#  'epigallocatechin gallate',
#  'Reperfusion Injury',
#  'Ventricular Dysfunction',
#  'Troponin',
#  'DNA Modification Methylases',
#  'silence']

# %%
unmapped_cui[2]
# Out:
# ''

# %%
with open('semrep_data/unmapped_semrep_subset.txt', 'w') as fileo:
    for item in unmapped_string_umls:
        fileo.write(item+'\n')

# %%
with open('semrep_data/unmapped_semrep_cui_subset.txt', 'w') as fileco:
    for item in unmapped_cui:
        fileco.write(item+'\n')

# %%
#add ontorunner mapping

# %%
obomap = pd.read_csv('semrep_data/unmapped_semrep_subset_20220406.csv')
obomap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7183 entries, 0 to 7182
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            7183 non-null   int64
#  1   text          7183 non-null   object
#  2   concept_name  3951 non-null   object
#  3   CURIE         3951 non-null   object
#  4   Unnamed: 4    2 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 280.7+ KB

# %%
obomap.head()
# Out:
#    id                      text  \
# 0   0         Green Tea Extract
# 1   1              Normal heart
# 2   2     ATP8A2 protein, human
# 3   3  epigallocatechin gallate
# 4   4        Reperfusion Injury
#
#                                         concept_name  \
# 0                                                tea
# 1                                              heart
# 2  ATP8A2[SYNONYM_OF:phospholipid-transporting AT...
# 3                           epigallocatechin gallate
# 4                                                NaN
#
#                                         CURIE Unnamed: 4
# 0    napdi_srs_imports:camellia_sinensis_leaf        NaN
# 1                              UBERON:0000948        NaN
# 2                        PR:000029291_SYNONYM        NaN
# 3  napdi_srs_imports:epigallocatechin_gallate        NaN
# 4                                         NaN        NaN

# %%
with open('semrep_data/unmapped_semrep_cui_subset.txt', 'r') as fileco:
    unmapped_cui = fileco.readlines()

# %%
unmapped_cui[2].strip()
# Out:
# ''

# %%
unmapped_cui_new = []
for item in unmapped_cui:
    cui = item.strip()
    if cui != '':
        unmapped_cui_new.append(cui)
len(unmapped_cui_new)
# Out:
# 7183

# %%
obomap['CUI'] = unmapped_cui_new
obomap.head()
# Out:
#    id                      text  \
# 0   0         Green Tea Extract
# 1   1              Normal heart
# 2   2     ATP8A2 protein, human
# 3   3  epigallocatechin gallate
# 4   4        Reperfusion Injury
#
#                                         concept_name  \
# 0                                                tea
# 1                                              heart
# 2  ATP8A2[SYNONYM_OF:phospholipid-transporting AT...
# 3                           epigallocatechin gallate
# 4                                                NaN
#
#                                         CURIE Unnamed: 4       CUI
# 0    napdi_srs_imports:camellia_sinensis_leaf        NaN  C1704263
# 1                              UBERON:0000948        NaN  C2349205
# 2                        PR:000029291_SYNONYM        NaN  C2744579
# 3  napdi_srs_imports:epigallocatechin_gallate        NaN  C0059438
# 4                                         NaN        NaN  C0035126

# %%
##clean CURIEs to remove 'SYNONYM' and add underscore. Also find appropriate prefix
##napdi - http://napdi.org/napdi_srs_imports:7_hydroxy_mitragynine

# %%
obomap = obomap.fillna('')
obomap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7183 entries, 0 to 7182
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            7183 non-null   int64
#  1   text          7183 non-null   object
#  2   concept_name  7183 non-null   object
#  3   CURIE         7183 non-null   object
#  4   Unnamed: 4    7183 non-null   object
#  5   CUI           7183 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 336.8+ KB

# %%
x = 'PR:00000_SYNONYM'
x.replace(':', '_')
# Out:
# 'PR_00000_SYNONYM'

# %%
def process_CURIE(row):
    curie = row['CURIE']
    if curie == '':
        return curie
    elif 'napdi' in curie:
        return curie
    elif 'SYNONYM' in curie:
        temp = curie.split('_')[0]
        temp = temp.replace(':', '_')
        return temp
    else:
        temp = curie.replace(':', '_')
        return temp

# %%
obomap['CURIE_new'] = obomap.apply(process_CURIE, axis=1)
obomap.head()
# Out:
#    id                      text  \
# 0   0         Green Tea Extract
# 1   1              Normal heart
# 2   2     ATP8A2 protein, human
# 3   3  epigallocatechin gallate
# 4   4        Reperfusion Injury
#
#                                         concept_name  \
# 0                                                tea
# 1                                              heart
# 2  ATP8A2[SYNONYM_OF:phospholipid-transporting AT...
# 3                           epigallocatechin gallate
# 4
#
#                                         CURIE Unnamed: 4       CUI  \
# 0    napdi_srs_imports:camellia_sinensis_leaf             C1704263
# 1                              UBERON:0000948             C2349205
# 2                        PR:000029291_SYNONYM             C2744579
# 3  napdi_srs_imports:epigallocatechin_gallate             C0059438
# 4                                                         C0035126
#
#                                     CURIE_new
# 0    napdi_srs_imports:camellia_sinensis_leaf
# 1                              UBERON_0000948
# 2                                PR_000029291
# 3  napdi_srs_imports:epigallocatechin_gallate
# 4

# %%
obomap.at[436, 'CURIE_new'] = 'MONDO_0001060'

# %%
obomap.iloc[436]
# Out:
# id                                                            436
# text                                         Early gastric cancer
# concept_name                                 Early gastric cancer
# CURIE           early gastric cancer[SYNONYM_OF:microinvasive ...
# Unnamed: 4                                  MONDO:0001060_SYNONYM
# CUI                                                      C0349530
# CURIE_new                                           MONDO_0001060
# Name: 436, dtype: object

# %%
obosub = obomap.loc[obomap['CURIE_new'] != '']
obosub.head()
# Out:
#    id                         text  \
# 0   0            Green Tea Extract
# 1   1                 Normal heart
# 2   2        ATP8A2 protein, human
# 3   3     epigallocatechin gallate
# 7   7  DNA Modification Methylases
#
#                                         concept_name  \
# 0                                                tea
# 1                                              heart
# 2  ATP8A2[SYNONYM_OF:phospholipid-transporting AT...
# 3                           epigallocatechin gallate
# 7  modification methylase[SYNONYM_OF:DNA restrict...
#
#                                         CURIE Unnamed: 4       CUI  \
# 0    napdi_srs_imports:camellia_sinensis_leaf             C1704263
# 1                              UBERON:0000948             C2349205
# 2                        PR:000029291_SYNONYM             C2744579
# 3  napdi_srs_imports:epigallocatechin_gallate             C0059438
# 7                        PR:000050198_SYNONYM             C0012873
#
#                                     CURIE_new
# 0    napdi_srs_imports:camellia_sinensis_leaf
# 1                              UBERON_0000948
# 2                                PR_000029291
# 3  napdi_srs_imports:epigallocatechin_gallate
# 7                                PR_000050198

# %%
obosub = obosub.reset_index(drop=True)
obosub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3951 entries, 0 to 3950
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            3951 non-null   int64
#  1   text          3951 non-null   object
#  2   concept_name  3951 non-null   object
#  3   CURIE         3951 non-null   object
#  4   Unnamed: 4    3951 non-null   object
#  5   CUI           3951 non-null   object
#  6   CURIE_new     3951 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 216.2+ KB

# %%
obomap.iloc[436]
# Out:
# id                                                            436
# text                                         Early gastric cancer
# concept_name                                 Early gastric cancer
# CURIE           early gastric cancer[SYNONYM_OF:microinvasive ...
# Unnamed: 4                                  MONDO:0001060_SYNONYM
# CUI                                                      C0349530
# CURIE_new                                           MONDO_0001060
# Name: 436, dtype: object

# %%
obosub.to_csv('cui_to_ontology_maps/mapped_semrep_subset_20220406.csv', index=False)

# %%
##create mapping dictionary
obomap_dict = {}
for i in range(len(obosub.index)):
    cui = obosub.at[i, 'CUI']
    curie = obosub.at[i, 'CURIE_new']
    obomap_dict[cui] = curie
len(obomap_dict)
# Out:
# 3951

# %%
with open('cui_to_ontology_maps/CUItoOBO_20220406.pickle', 'wb') as filep:
    pickle.dump(obomap_dict, filep)

# %%
def get_obo_mapping(row, col):
    if col == 'subject':
        cui = row['subject_cui']
    elif col == 'object':
        cui = row['object_cui']
    else:
        print('specify if subject or object mapping required')
        exit(0)
    if cui in obomap_dict:
        return obomap_dict[cui]
    return None

# %%
dfn_subset.head()
# Out:
#        pmid subject_cui subject_type object_cui     object_type  year  \
# 0  29913456    C1704263    orch,phsu   C2349205            fndg  2018
# 1  29913456                gngm,aapp   C2744579  aapp,gngm,enzy  2018
# 2  29913456    C0020538         dsyn   C0878544            dsyn  2018
# 3  29913456    C0059438    orch,phsu   C0035126            inpo  2018
# 4  29913456    C0242973         patf   C0878544            dsyn  2018
#
#                subject_name            object_name  \
# 0         Green Tea Extract           Normal heart
# 1                            ATP8A2 protein, human
# 2      Hypertensive disease       Cardiomyopathies
# 3  epigallocatechin gallate     Reperfusion Injury
# 4   Ventricular Dysfunction       Cardiomyopathies
#
#                                          source_text      predicate  \
# 0  29913456_ascii.txt.tx.1 Abstract Background/Ai...        affects
# 1  29913456_ascii.txt.tx.2 Consistent with functi...     stimulates
# 2  29913456_ascii.txt.tx.1 Previous experimental ...  coexists_with
# 3  29913456_ascii.txt.tx.1 Previous experimental ...         treats
# 4  29913456_ascii.txt.tx.1 Previous experimental ...  coexists_with
#
#   subject_map object_map predicate_obo subject_obo  object_obo
# 0        None       None    RO_0002596        None        None
# 1        None       None    RO_0002213        None        None
# 2        None       None    RO_0002490  HP_0000822  HP_0001638
# 3        None       None    RO_0002606        None        None
# 4        None       None    RO_0002490        None  HP_0001638

# %%
#MAPPING
dfn_subset['subject_obo'] = dfn_subset.apply(get_obo_mapping, axis=1, col='subject')
dfn_subset.head()
# Out:
#        pmid subject_cui subject_type object_cui     object_type  year  \
# 0  29913456    C1704263    orch,phsu   C2349205            fndg  2018
# 1  29913456                gngm,aapp   C2744579  aapp,gngm,enzy  2018
# 2  29913456    C0020538         dsyn   C0878544            dsyn  2018
# 3  29913456    C0059438    orch,phsu   C0035126            inpo  2018
# 4  29913456    C0242973         patf   C0878544            dsyn  2018
#
#                subject_name            object_name  \
# 0         Green Tea Extract           Normal heart
# 1                            ATP8A2 protein, human
# 2      Hypertensive disease       Cardiomyopathies
# 3  epigallocatechin gallate     Reperfusion Injury
# 4   Ventricular Dysfunction       Cardiomyopathies
#
#                                          source_text      predicate  \
# 0  29913456_ascii.txt.tx.1 Abstract Background/Ai...        affects
# 1  29913456_ascii.txt.tx.2 Consistent with functi...     stimulates
# 2  29913456_ascii.txt.tx.1 Previous experimental ...  coexists_with
# 3  29913456_ascii.txt.tx.1 Previous experimental ...         treats
# 4  29913456_ascii.txt.tx.1 Previous experimental ...  coexists_with
#
#   subject_map object_map predicate_obo  \
# 0        None       None    RO_0002596
# 1        None       None    RO_0002213
# 2        None       None    RO_0002490
# 3        None       None    RO_0002606
# 4        None       None    RO_0002490
#
#                                   subject_obo  object_obo
# 0    napdi_srs_imports:camellia_sinensis_leaf        None
# 1                                        None        None
# 2                                        None  HP_0001638
# 3  napdi_srs_imports:epigallocatechin_gallate        None
# 4                                        None  HP_0001638

# %%
dfn_subset['object_obo'] = dfn_subset.apply(get_obo_mapping, axis=1, col='object')
dfn_subset.head()
# Out:
#        pmid subject_cui subject_type object_cui     object_type  year  \
# 0  29913456    C1704263    orch,phsu   C2349205            fndg  2018
# 1  29913456                gngm,aapp   C2744579  aapp,gngm,enzy  2018
# 2  29913456    C0020538         dsyn   C0878544            dsyn  2018
# 3  29913456    C0059438    orch,phsu   C0035126            inpo  2018
# 4  29913456    C0242973         patf   C0878544            dsyn  2018
#
#                subject_name            object_name  \
# 0         Green Tea Extract           Normal heart
# 1                            ATP8A2 protein, human
# 2      Hypertensive disease       Cardiomyopathies
# 3  epigallocatechin gallate     Reperfusion Injury
# 4   Ventricular Dysfunction       Cardiomyopathies
#
#                                          source_text      predicate  \
# 0  29913456_ascii.txt.tx.1 Abstract Background/Ai...        affects
# 1  29913456_ascii.txt.tx.2 Consistent with functi...     stimulates
# 2  29913456_ascii.txt.tx.1 Previous experimental ...  coexists_with
# 3  29913456_ascii.txt.tx.1 Previous experimental ...         treats
# 4  29913456_ascii.txt.tx.1 Previous experimental ...  coexists_with
#
#   subject_map object_map predicate_obo  \
# 0        None       None    RO_0002596
# 1        None       None    RO_0002213
# 2        None       None    RO_0002490
# 3        None       None    RO_0002606
# 4        None       None    RO_0002490
#
#                                   subject_obo      object_obo
# 0    napdi_srs_imports:camellia_sinensis_leaf  UBERON_0000948
# 1                                        None    PR_000029291
# 2                                        None            None
# 3  napdi_srs_imports:epigallocatechin_gallate            None
# 4                                        None            None

# %%
dfn_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145638 entries, 0 to 145637
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   pmid           145638 non-null  int64
#  1   subject_cui    145638 non-null  object
#  2   subject_type   145638 non-null  object
#  3   object_cui     145638 non-null  object
#  4   object_type    145638 non-null  object
#  5   year           145638 non-null  object
#  6   subject_name   145638 non-null  object
#  7   object_name    145638 non-null  object
#  8   source_text    145638 non-null  object
#  9   predicate      145638 non-null  object
#  10  subject_map    0 non-null       object
#  11  object_map     0 non-null       object
#  12  predicate_obo  145638 non-null  object
#  13  subject_obo    103194 non-null  object
#  14  object_obo     75713 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 16.7+ MB

# %%
##add labels for all subjects and objects

# %%
dfn_subset.to_csv('semrep_data/semrep_all_predications_mapped_20220406.csv', index=False)

# %%
##read file after mapping
dfn_subset = pd.read_csv('semrep_data/semrep_all_predications_mapped_20220406.csv')
dfn_subset.head()
# Out:
#        pmid subject_cui subject_type object_cui     object_type    year  \
# 0  29913456    C1704263    orch,phsu   C2349205            fndg  2018.0
# 1  29913456         NaN    gngm,aapp   C2744579  aapp,gngm,enzy  2018.0
# 2  29913456    C0020538         dsyn   C0878544            dsyn  2018.0
# 3  29913456    C0059438    orch,phsu   C0035126            inpo  2018.0
# 4  29913456    C0242973         patf   C0878544            dsyn  2018.0
#
#                subject_name            object_name  \
# 0         Green Tea Extract           Normal heart
# 1                       NaN  ATP8A2 protein, human
# 2      Hypertensive disease       Cardiomyopathies
# 3  epigallocatechin gallate     Reperfusion Injury
# 4   Ventricular Dysfunction       Cardiomyopathies
#
#                                          source_text      predicate  \
# 0  29913456_ascii.txt.tx.1 Abstract Background/Ai...        affects
# 1  29913456_ascii.txt.tx.2 Consistent with functi...     stimulates
# 2  29913456_ascii.txt.tx.1 Previous experimental ...  coexists_with
# 3  29913456_ascii.txt.tx.1 Previous experimental ...         treats
# 4  29913456_ascii.txt.tx.1 Previous experimental ...  coexists_with
#
#    subject_map  object_map predicate_obo  \
# 0          NaN         NaN    RO_0002596
# 1          NaN         NaN    RO_0002213
# 2          NaN         NaN    RO_0002490
# 3          NaN         NaN    RO_0002606
# 4          NaN         NaN    RO_0002490
#
#                                   subject_obo      object_obo
# 0    napdi_srs_imports:camellia_sinensis_leaf  UBERON_0000948
# 1                                         NaN    PR_000029291
# 2                                         NaN             NaN
# 3  napdi_srs_imports:epigallocatechin_gallate             NaN
# 4                                         NaN             NaN

# %%
def add_prefix(row, col):
    obo_prefix = 'http://purl.obolibrary.org/obo/'
    napdi_prefix = 'http://napdi.org/'
    if col == 'predicate':
        predicate_obo = row['predicate_obo']
        if isinstance(predicate_obo, str):
            return obo_prefix+predicate_obo
        else:
            return ''
            
    elif col == 'subject':
        
        subject_obo = row['subject_obo']
        if isinstance(subject_obo, str):
            if subject_obo == None:
                return ''
            if 'napdi' in subject_obo:
                return napdi_prefix+subject_obo
            else:
                return obo_prefix+subject_obo
        else:
            return ''
    elif col == 'object':
        object_obo = row['object_obo']
        if isinstance(object_obo, str):
            if object_obo == None:
                return ''
            if 'napdi' in object_obo:
                return napdi_prefix+object_obo
            else:
                return obo_prefix+object_obo
        else:
            return ''

# %%
#add OBO identifiers to the OBO mappings (where not present) - see df
#drop rows with no mappings
dfn_subset['subject_obo'] = dfn_subset.apply(add_prefix, axis=1, col='subject')
dfn_subset['object_obo'] = dfn_subset.apply(add_prefix, axis=1, col='object')
dfn_subset['predicate_obo'] = dfn_subset.apply(add_prefix, axis=1, col='predicate')

# %%
dfn_subset.head()
# Out:
#        pmid subject_cui subject_type object_cui     object_type    year  \
# 0  29913456    C1704263    orch,phsu   C2349205            fndg  2018.0
# 1  29913456         NaN    gngm,aapp   C2744579  aapp,gngm,enzy  2018.0
# 2  29913456    C0020538         dsyn   C0878544            dsyn  2018.0
# 3  29913456    C0059438    orch,phsu   C0035126            inpo  2018.0
# 4  29913456    C0242973         patf   C0878544            dsyn  2018.0
#
#                subject_name            object_name  \
# 0         Green Tea Extract           Normal heart
# 1                       NaN  ATP8A2 protein, human
# 2      Hypertensive disease       Cardiomyopathies
# 3  epigallocatechin gallate     Reperfusion Injury
# 4   Ventricular Dysfunction       Cardiomyopathies
#
#                                          source_text      predicate  \
# 0  29913456_ascii.txt.tx.1 Abstract Background/Ai...        affects
# 1  29913456_ascii.txt.tx.2 Consistent with functi...     stimulates
# 2  29913456_ascii.txt.tx.1 Previous experimental ...  coexists_with
# 3  29913456_ascii.txt.tx.1 Previous experimental ...         treats
# 4  29913456_ascii.txt.tx.1 Previous experimental ...  coexists_with
#
#    subject_map  object_map                              predicate_obo  \
# 0          NaN         NaN  http://purl.obolibrary.org/obo/RO_0002596
# 1          NaN         NaN  http://purl.obolibrary.org/obo/RO_0002213
# 2          NaN         NaN  http://purl.obolibrary.org/obo/RO_0002490
# 3          NaN         NaN  http://purl.obolibrary.org/obo/RO_0002606
# 4          NaN         NaN  http://purl.obolibrary.org/obo/RO_0002490
#
#                                          subject_obo  \
# 0  http://napdi.org/napdi_srs_imports:camellia_si...
# 1
# 2
# 3  http://napdi.org/napdi_srs_imports:epigallocat...
# 4
#
#                                       object_obo
# 0  http://purl.obolibrary.org/obo/UBERON_0000948
# 1    http://purl.obolibrary.org/obo/PR_000029291
# 2
# 3
# 4

# %%
dfn_subset.to_csv('semrep_data/semrep_all_predications_mapped_with_prefix_20220406.csv', index=False)

# %%
dfn_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145638 entries, 0 to 145637
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   pmid           145638 non-null  int64
#  1   subject_cui    141153 non-null  object
#  2   subject_type   145638 non-null  object
#  3   object_cui     141410 non-null  object
#  4   object_type    145638 non-null  object
#  5   year           145492 non-null  float64
#  6   subject_name   141153 non-null  object
#  7   object_name    141410 non-null  object
#  8   source_text    145638 non-null  object
#  9   predicate      145638 non-null  object
#  10  subject_map    0 non-null       float64
#  11  object_map     0 non-null       float64
#  12  predicate_obo  145638 non-null  object
#  13  subject_obo    145638 non-null  object
#  14  object_obo     145638 non-null  object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 16.7+ MB

# %%
df_new = dfn_subset[dfn_subset['subject_obo'] != '']
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103194 entries, 0 to 145637
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   pmid           103194 non-null  int64
#  1   subject_cui    103194 non-null  object
#  2   subject_type   103194 non-null  object
#  3   object_cui     99735 non-null   object
#  4   object_type    103194 non-null  object
#  5   year           103085 non-null  float64
#  6   subject_name   103194 non-null  object
#  7   object_name    99735 non-null   object
#  8   source_text    103194 non-null  object
#  9   predicate      103194 non-null  object
#  10  subject_map    0 non-null       float64
#  11  object_map     0 non-null       float64
#  12  predicate_obo  103194 non-null  object
#  13  subject_obo    103194 non-null  object
#  14  object_obo     103194 non-null  object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 12.6+ MB

# %%
df_new = df_new[df_new['object_obo'] != '']
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54677 entries, 0 to 145637
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pmid           54677 non-null  int64
#  1   subject_cui    54677 non-null  object
#  2   subject_type   54677 non-null  object
#  3   object_cui     54677 non-null  object
#  4   object_type    54677 non-null  object
#  5   year           54603 non-null  float64
#  6   subject_name   54677 non-null  object
#  7   object_name    54677 non-null  object
#  8   source_text    54677 non-null  object
#  9   predicate      54677 non-null  object
#  10  subject_map    0 non-null      float64
#  11  object_map     0 non-null      float64
#  12  predicate_obo  54677 non-null  object
#  13  subject_obo    54677 non-null  object
#  14  object_obo     54677 non-null  object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 6.7+ MB

# %%
df_new['predicate'].value_counts()
# Out:
# interacts_with     13517
# inhibits            8559
# stimulates          7942
# coexists_with       7404
# part_of             6507
# treats              3641
# affects             1808
# augments            1424
# disrupts            1215
# produces            1114
# causes               692
# associated_with      516
# prevents             225
# predisposes          100
# complicates            7
# precedes               6
# Name: predicate, dtype: int64

# %%
df_new = df_new[df_new['predicate_obo'] != '']
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54677 entries, 0 to 145637
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pmid           54677 non-null  int64
#  1   subject_cui    54677 non-null  object
#  2   subject_type   54677 non-null  object
#  3   object_cui     54677 non-null  object
#  4   object_type    54677 non-null  object
#  5   year           54603 non-null  float64
#  6   subject_name   54677 non-null  object
#  7   object_name    54677 non-null  object
#  8   source_text    54677 non-null  object
#  9   predicate      54677 non-null  object
#  10  subject_map    0 non-null      float64
#  11  object_map     0 non-null      float64
#  12  predicate_obo  54677 non-null  object
#  13  subject_obo    54677 non-null  object
#  14  object_obo     54677 non-null  object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 6.7+ MB

# %%
df_new = df_new.drop_duplicates()
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13676 entries, 0 to 145566
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pmid           13676 non-null  int64
#  1   subject_cui    13676 non-null  object
#  2   subject_type   13676 non-null  object
#  3   object_cui     13676 non-null  object
#  4   object_type    13676 non-null  object
#  5   year           13602 non-null  float64
#  6   subject_name   13676 non-null  object
#  7   object_name    13676 non-null  object
#  8   source_text    13676 non-null  object
#  9   predicate      13676 non-null  object
#  10  subject_map    0 non-null      float64
#  11  object_map     0 non-null      float64
#  12  predicate_obo  13676 non-null  object
#  13  subject_obo    13676 non-null  object
#  14  object_obo     13676 non-null  object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 1.7+ MB

# %%
df_new = df_new.reset_index(drop=True)
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13676 entries, 0 to 13675
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pmid           13676 non-null  int64
#  1   subject_cui    13676 non-null  object
#  2   subject_type   13676 non-null  object
#  3   object_cui     13676 non-null  object
#  4   object_type    13676 non-null  object
#  5   year           13602 non-null  float64
#  6   subject_name   13676 non-null  object
#  7   object_name    13676 non-null  object
#  8   source_text    13676 non-null  object
#  9   predicate      13676 non-null  object
#  10  subject_map    0 non-null      float64
#  11  object_map     0 non-null      float64
#  12  predicate_obo  13676 non-null  object
#  13  subject_obo    13676 non-null  object
#  14  object_obo     13676 non-null  object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 1.6+ MB

# %%
df_new = df_new.drop(['subject_map', 'object_map'], axis=1)
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13676 entries, 0 to 13675
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pmid           13676 non-null  int64
#  1   subject_cui    13676 non-null  object
#  2   subject_type   13676 non-null  object
#  3   object_cui     13676 non-null  object
#  4   object_type    13676 non-null  object
#  5   year           13602 non-null  float64
#  6   subject_name   13676 non-null  object
#  7   object_name    13676 non-null  object
#  8   source_text    13676 non-null  object
#  9   predicate      13676 non-null  object
#  10  predicate_obo  13676 non-null  object
#  11  subject_obo    13676 non-null  object
#  12  object_obo     13676 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.4+ MB

# %%
df_new.to_csv('semrep_data/semrep_predications_mapped_only_20220406.csv', index=False)

# %%
import pandas as pd

# %%
df = pd.read_csv('semrep_data/semrep_predications_mapped_only_20220406.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13676 entries, 0 to 13675
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pmid           13676 non-null  int64
#  1   subject_cui    13676 non-null  object
#  2   subject_type   13676 non-null  object
#  3   object_cui     13676 non-null  object
#  4   object_type    13676 non-null  object
#  5   year           13602 non-null  float64
#  6   subject_name   13676 non-null  object
#  7   object_name    13676 non-null  object
#  8   source_text    13676 non-null  object
#  9   predicate      13676 non-null  object
#  10  predicate_obo  13676 non-null  object
#  11  subject_obo    13676 non-null  object
#  12  object_obo     13676 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.4+ MB

# %%
df['predicate'].value_counts()
# Out:
# interacts_with     3287
# inhibits           2014
# coexists_with      1945
# stimulates         1902
# part_of            1846
# treats              927
# affects             447
# augments            334
# produces            314
# disrupts            242
# causes              190
# associated_with     135
# prevents             59
# predisposes          31
# complicates           2
# precedes              1
# Name: predicate, dtype: int64

# %%
####create ntriples graph and run closure

# %%
#Create networkx graph from triples
import glob
import hashlib
import json
import networkx as nx  # type: ignore
import os
import os.path

from collections import Counter  # type: ignore
from more_itertools import unique_everseen  # type: ignore
from rdflib import BNode, Graph, Literal, Namespace, URIRef  # type: ignore
from rdflib.namespace import OWL, RDF, RDFS  # type: ignore
from rdflib.plugins.serializers.nt import _quoteLiteral  # type: ignore
import subprocess

from tqdm import tqdm  # type: ignore
from typing import Dict, List, Optional, Set, Tuple, Union

# set-up environment variables
obo = Namespace('http://purl.obolibrary.org/obo/')
oboinowl = Namespace('http://www.geneontology.org/formats/oboInOwl#')
schema = Namespace('http://www.w3.org/2001/XMLSchema#')
napdi = Namespace('http://napdi.org/napdi-srs-imports:')

# %%
dfres = df_new[['subject_obo', 'predicate_obo', 'object_obo']]
dfres.head()
# Out:
#                                          subject_obo  \
# 0  http://napdi.org/napdi_srs_imports:camellia_si...
# 1          http://purl.obolibrary.org/obo/CL_0000187
# 2          http://purl.obolibrary.org/obo/CL_0000187
# 3         http://purl.obolibrary.org/obo/CHEBI_17234
# 4         http://purl.obolibrary.org/obo/CHEBI_15361
#
#                                 predicate_obo  \
# 0   http://purl.obolibrary.org/obo/RO_0002596
# 1  http://purl.obolibrary.org/obo/BFO_0000050
# 2  http://purl.obolibrary.org/obo/BFO_0000050
# 3  http://purl.obolibrary.org/obo/BFO_0000050
# 4  http://purl.obolibrary.org/obo/BFO_0000050
#
#                                       object_obo
# 0  http://purl.obolibrary.org/obo/UBERON_0000948
# 1  http://purl.obolibrary.org/obo/UBERON_0002082
# 2  http://purl.obolibrary.org/obo/UBERON_0002082
# 3      http://purl.obolibrary.org/obo/CL_0000187
# 4      http://purl.obolibrary.org/obo/CL_0000187

# %%
df_new.head()
# Out:
#        pmid subject_cui    subject_type object_cui object_type    year  \
# 0  29913456    C1704263       orch,phsu   C2349205        fndg  2018.0
# 1  29913456    C0596981            cell   C0018827        bpoc  2018.0
# 2  29913456    C0596981            cell   C0018827        bpoc  2018.0
# 3  29913456    C0017725  bacs,orch,phsu   C0225828        cell  2018.0
# 4  29913456    C0034354            orch   C0225828        cell  2018.0
#
#         subject_name        object_name  \
# 0  Green Tea Extract       Normal heart
# 1       Muscle Cells    Heart Ventricle
# 2       Muscle Cells    Heart Ventricle
# 3            Glucose  Myocytes, Cardiac
# 4          Pyruvates  Myocytes, Cardiac
#
#                                          source_text predicate  \
# 0  29913456_ascii.txt.tx.1 Abstract Background/Ai...   affects
# 1  29913456_ascii.txt.tx.4 From the heart of 6 CT...   part_of
# 2  29913456_ascii.txt.tx.1 Mechanical properties ...   part_of
# 3  29913456_ascii.txt.tx.4 Mitochondrial respirat...   part_of
# 4  29913456_ascii.txt.tx.4 Mitochondrial respirat...   part_of
#
#                                 predicate_obo  \
# 0   http://purl.obolibrary.org/obo/RO_0002596
# 1  http://purl.obolibrary.org/obo/BFO_0000050
# 2  http://purl.obolibrary.org/obo/BFO_0000050
# 3  http://purl.obolibrary.org/obo/BFO_0000050
# 4  http://purl.obolibrary.org/obo/BFO_0000050
#
#                                          subject_obo  \
# 0  http://napdi.org/napdi_srs_imports:camellia_si...
# 1          http://purl.obolibrary.org/obo/CL_0000187
# 2          http://purl.obolibrary.org/obo/CL_0000187
# 3         http://purl.obolibrary.org/obo/CHEBI_17234
# 4         http://purl.obolibrary.org/obo/CHEBI_15361
#
#                                       object_obo
# 0  http://purl.obolibrary.org/obo/UBERON_0000948
# 1  http://purl.obolibrary.org/obo/UBERON_0002082
# 2  http://purl.obolibrary.org/obo/UBERON_0002082
# 3      http://purl.obolibrary.org/obo/CL_0000187
# 4      http://purl.obolibrary.org/obo/CL_0000187

# %%
dfres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13676 entries, 0 to 13675
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   subject_obo    13676 non-null  object
#  1   predicate_obo  13676 non-null  object
#  2   object_obo     13676 non-null  object
# dtypes: object(3)
# memory usage: 320.7+ KB

# %%
dfres = dfres.drop_duplicates()
dfres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9232 entries, 0 to 13666
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   subject_obo    9232 non-null   object
#  1   predicate_obo  9232 non-null   object
#  2   object_obo     9232 non-null   object
# dtypes: object(3)
# memory usage: 288.5+ KB

# %%
#create rdflib graph from dataframe triples and serialize as ntriples file
graph  = Graph()
pred_label = URIRef("http://www.w3.org/2000/01/rdf-schema#label")
for i in range(len(df_new.index)):
    subj = df_new.at[i, 'subject_obo']
    obj = df_new.at[i, 'object_obo']
    pred = df_new.at[i, 'predicate_obo']
    subj_node = URIRef(subj)
    obj_node = URIRef(obj)
    predicate = URIRef(pred)
    subj_name = df_new.at[i, 'subject_name']
    obj_name = df_new.at[i, 'object_name']
    graph.add((subj_node, predicate, obj_node))
    graph.add((subj_node, pred_label, Literal(subj_name)))
    graph.add((obj_node, pred_label, Literal(obj_name)))

# %%
graph.serialize('output_graphs/machineread_semrep_version3.nt', format='nt')

# %%
##save graph as gpickle, nodelabels as TSV also (run closure in spearate notebook)

# %%
df_new.head()
# Out:
#        pmid subject_cui    subject_type object_cui object_type    year  \
# 0  29913456    C1704263       orch,phsu   C2349205        fndg  2018.0
# 1  29913456    C0596981            cell   C0018827        bpoc  2018.0
# 2  29913456    C0596981            cell   C0018827        bpoc  2018.0
# 3  29913456    C0017725  bacs,orch,phsu   C0225828        cell  2018.0
# 4  29913456    C0034354            orch   C0225828        cell  2018.0
#
#         subject_name        object_name  \
# 0  Green Tea Extract       Normal heart
# 1       Muscle Cells    Heart Ventricle
# 2       Muscle Cells    Heart Ventricle
# 3            Glucose  Myocytes, Cardiac
# 4          Pyruvates  Myocytes, Cardiac
#
#                                          source_text predicate  \
# 0  29913456_ascii.txt.tx.1 Abstract Background/Ai...   affects
# 1  29913456_ascii.txt.tx.4 From the heart of 6 CT...   part_of
# 2  29913456_ascii.txt.tx.1 Mechanical properties ...   part_of
# 3  29913456_ascii.txt.tx.4 Mitochondrial respirat...   part_of
# 4  29913456_ascii.txt.tx.4 Mitochondrial respirat...   part_of
#
#                                 predicate_obo  \
# 0   http://purl.obolibrary.org/obo/RO_0002596
# 1  http://purl.obolibrary.org/obo/BFO_0000050
# 2  http://purl.obolibrary.org/obo/BFO_0000050
# 3  http://purl.obolibrary.org/obo/BFO_0000050
# 4  http://purl.obolibrary.org/obo/BFO_0000050
#
#                                          subject_obo  \
# 0  http://napdi.org/napdi_srs_imports:camellia_si...
# 1          http://purl.obolibrary.org/obo/CL_0000187
# 2          http://purl.obolibrary.org/obo/CL_0000187
# 3         http://purl.obolibrary.org/obo/CHEBI_17234
# 4         http://purl.obolibrary.org/obo/CHEBI_15361
#
#                                       object_obo
# 0  http://purl.obolibrary.org/obo/UBERON_0000948
# 1  http://purl.obolibrary.org/obo/UBERON_0002082
# 2  http://purl.obolibrary.org/obo/UBERON_0002082
# 3      http://purl.obolibrary.org/obo/CL_0000187
# 4      http://purl.obolibrary.org/obo/CL_0000187

# %%
def n3(node: Union[URIRef, BNode, Literal]) -> str:
    """Method takes an RDFLib node of type BNode, URIRef, or Literal and serializes it to meet the RDF 1.1 NTriples
    format.
    Src: https://github.com/RDFLib/rdflib/blob/c11f7b503b50b7c3cdeec0f36261fa09b0615380/rdflib/plugins/serializers/nt.py
    Args:
        node: An RDFLib
    Returns:
        serialized_node: A string containing the serialized
    """
    if isinstance(node, Literal): serialized_node = "%s" % _quoteLiteral(node)
    else: serialized_node = "%s" % node.n3()
    return serialized_node

# %%
df_new.head()
# Out:
#        pmid subject_cui    subject_type object_cui object_type    year  \
# 0  29913456    C1704263       orch,phsu   C2349205        fndg  2018.0
# 1  29913456    C0596981            cell   C0018827        bpoc  2018.0
# 2  29913456    C0596981            cell   C0018827        bpoc  2018.0
# 3  29913456    C0017725  bacs,orch,phsu   C0225828        cell  2018.0
# 4  29913456    C0034354            orch   C0225828        cell  2018.0
#
#         subject_name        object_name  \
# 0  Green Tea Extract       Normal heart
# 1       Muscle Cells    Heart Ventricle
# 2       Muscle Cells    Heart Ventricle
# 3            Glucose  Myocytes, Cardiac
# 4          Pyruvates  Myocytes, Cardiac
#
#                                          source_text predicate  \
# 0  29913456_ascii.txt.tx.1 Abstract Background/Ai...   affects
# 1  29913456_ascii.txt.tx.4 From the heart of 6 CT...   part_of
# 2  29913456_ascii.txt.tx.1 Mechanical properties ...   part_of
# 3  29913456_ascii.txt.tx.4 Mitochondrial respirat...   part_of
# 4  29913456_ascii.txt.tx.4 Mitochondrial respirat...   part_of
#
#                                 predicate_obo  \
# 0   http://purl.obolibrary.org/obo/RO_0002596
# 1  http://purl.obolibrary.org/obo/BFO_0000050
# 2  http://purl.obolibrary.org/obo/BFO_0000050
# 3  http://purl.obolibrary.org/obo/BFO_0000050
# 4  http://purl.obolibrary.org/obo/BFO_0000050
#
#                                          subject_obo  \
# 0  http://napdi.org/napdi_srs_imports:camellia_si...
# 1          http://purl.obolibrary.org/obo/CL_0000187
# 2          http://purl.obolibrary.org/obo/CL_0000187
# 3         http://purl.obolibrary.org/obo/CHEBI_17234
# 4         http://purl.obolibrary.org/obo/CHEBI_15361
#
#                                       object_obo
# 0  http://purl.obolibrary.org/obo/UBERON_0000948
# 1  http://purl.obolibrary.org/obo/UBERON_0002082
# 2  http://purl.obolibrary.org/obo/UBERON_0002082
# 3      http://purl.obolibrary.org/obo/CL_0000187
# 4      http://purl.obolibrary.org/obo/CL_0000187

# %%
x = 'http://purl.obolibrary.org/obo/CL_0000187' 
y = 'http://purl.obolibrary.org/obo/BFO_0000050'
z = 'http://purl.obolibrary.org/obo/UBERON_0002082'

# %%
df_new.loc[(df_new['subject_obo'] == x) & (df_new['object_obo'] == z)  & (df_new['predicate_obo'] == y)]
# Out:
#            pmid subject_cui subject_type object_cui object_type    year  \
# 1      29913456    C0596981         cell   C0018827        bpoc  2018.0
# 2      29913456    C0596981         cell   C0018827        bpoc  2018.0
# 11     29913456    C0596981         cell   C0018827        bpoc  2018.0
# 122    23116965    C0596981         cell   C0018827        bpoc  2013.0
# 130    23116965    C0596981         cell   C0018827        bpoc  2013.0
# 1148   20798525    C0225828         cell   C0018827        bpoc  2010.0
# 2059   27306406    C0225828         cell   C0018827        bpoc  2016.0
# 4348   28768059    C0225828         cell   C0018827        bpoc  2017.0
# 4677   33228183    C0225828         cell   C2355627        bpoc  2020.0
# 5607   18406205    C0596981         cell   C0018827        bpoc  2008.0
# 6799   30847932    C0225828         cell   C0018827        bpoc  2019.0
# 6813   30847932    C0596981         cell   C0018827        bpoc  2019.0
# 6918   17656102    C0596981         cell   C0018827        bpoc  2007.0
# 6922   17656102    C0596981         cell   C0018827        bpoc  2007.0
# 7051   20473584    C0596981         cell   C0018827        bpoc  2010.0
# 7054   20473584    C0596981         cell   C0018827        bpoc  2010.0
# 7064   20473584    C0596981         cell   C0018827        bpoc  2010.0
# 7887   33727059    C0596981         cell   C0018827        bpoc  2021.0
# 8163   22918967    C0596981         cell   C0018827        bpoc  2012.0
# 11168  17016511    C0596981         cell   C0018827        bpoc  2006.0
#
#             subject_name      object_name  \
# 1           Muscle Cells  Heart Ventricle
# 2           Muscle Cells  Heart Ventricle
# 11          Muscle Cells  Heart Ventricle
# 122         Muscle Cells  Heart Ventricle
# 130         Muscle Cells  Heart Ventricle
# 1148   Myocytes, Cardiac  Heart Ventricle
# 2059   Myocytes, Cardiac  Heart Ventricle
# 4348   Myocytes, Cardiac  Heart Ventricle
# 4677   Myocytes, Cardiac        Ventricle
# 5607        Muscle Cells  Heart Ventricle
# 6799   Myocytes, Cardiac  Heart Ventricle
# 6813        Muscle Cells  Heart Ventricle
# 6918        Muscle Cells  Heart Ventricle
# 6922        Muscle Cells  Heart Ventricle
# 7051        Muscle Cells  Heart Ventricle
# 7054        Muscle Cells  Heart Ventricle
# 7064        Muscle Cells  Heart Ventricle
# 7887        Muscle Cells  Heart Ventricle
# 8163        Muscle Cells  Heart Ventricle
# 11168       Muscle Cells  Heart Ventricle
#
#                                              source_text predicate  \
# 1      29913456_ascii.txt.tx.4 From the heart of 6 CT...   part_of
# 2      29913456_ascii.txt.tx.1 Mechanical properties ...   part_of
# 11     29913456_ascii.txt.tx.3 Mean values +/- SEM of...   part_of
# 122    23116965_ascii.txt.tx.1 Here,  we  reported  t...   part_of
# 130    23116965_ascii.txt.tx.2 Previous  studies  in ...   part_of
# 1148   20798525_ascii.txt.tx.3|relation|C0110613|Conn...   part_of
# 2059   27306406_ascii.txt.tx.1 Gap junctions are comp...   part_of
# 4348   28768059_ascii.txt.tx.1 We found that protein ...   part_of
# 4677   33228183_ascii.txt.tx.2 Furthermore, RA treatm...   part_of
# 5607   18406205_ascii.txt.tx.1 Diastolic cell length ...   part_of
# 6799   30847932_ascii.txt.tx.4 Connexin 43 (Cx43) is ...   part_of
# 6813   30847932_ascii.txt.tx.2 Apart from Cx43, there...   part_of
# 6918   17656102_ascii.txt.tx.1 However, the effective...   part_of
# 6922   17656102_ascii.txt.tx.3 Electrophysiological r...   part_of
# 7051   20473584_ascii.txt.tx.2 However, there are few...   part_of
# 7054   20473584_ascii.txt.tx.1 CAT activity in ventri...   part_of
# 7064   20473584_ascii.txt.tx.3 Decreased CAT activity...   part_of
# 7887   33727059_ascii.txt.tx.1 These features define ...   part_of
# 8163   22918967_ascii.txt.tx.1 At these pharmacologic...   part_of
# 11168  17016511_ascii.txt.tx.2 Measurement of calcium...   part_of
#
#                                     predicate_obo  \
# 1      http://purl.obolibrary.org/obo/BFO_0000050
# 2      http://purl.obolibrary.org/obo/BFO_0000050
# 11     http://purl.obolibrary.org/obo/BFO_0000050
# 122    http://purl.obolibrary.org/obo/BFO_0000050
# 130    http://purl.obolibrary.org/obo/BFO_0000050
# 1148   http://purl.obolibrary.org/obo/BFO_0000050
# 2059   http://purl.obolibrary.org/obo/BFO_0000050
# 4348   http://purl.obolibrary.org/obo/BFO_0000050
# 4677   http://purl.obolibrary.org/obo/BFO_0000050
# 5607   http://purl.obolibrary.org/obo/BFO_0000050
# 6799   http://purl.obolibrary.org/obo/BFO_0000050
# 6813   http://purl.obolibrary.org/obo/BFO_0000050
# 6918   http://purl.obolibrary.org/obo/BFO_0000050
# 6922   http://purl.obolibrary.org/obo/BFO_0000050
# 7051   http://purl.obolibrary.org/obo/BFO_0000050
# 7054   http://purl.obolibrary.org/obo/BFO_0000050
# 7064   http://purl.obolibrary.org/obo/BFO_0000050
# 7887   http://purl.obolibrary.org/obo/BFO_0000050
# 8163   http://purl.obolibrary.org/obo/BFO_0000050
# 11168  http://purl.obolibrary.org/obo/BFO_0000050
#
#                                      subject_obo  \
# 1      http://purl.obolibrary.org/obo/CL_0000187
# 2      http://purl.obolibrary.org/obo/CL_0000187
# 11     http://purl.obolibrary.org/obo/CL_0000187
# 122    http://purl.obolibrary.org/obo/CL_0000187
# 130    http://purl.obolibrary.org/obo/CL_0000187
# 1148   http://purl.obolibrary.org/obo/CL_0000187
# 2059   http://purl.obolibrary.org/obo/CL_0000187
# 4348   http://purl.obolibrary.org/obo/CL_0000187
# 4677   http://purl.obolibrary.org/obo/CL_0000187
# 5607   http://purl.obolibrary.org/obo/CL_0000187
# 6799   http://purl.obolibrary.org/obo/CL_0000187
# 6813   http://purl.obolibrary.org/obo/CL_0000187
# 6918   http://purl.obolibrary.org/obo/CL_0000187
# 6922   http://purl.obolibrary.org/obo/CL_0000187
# 7051   http://purl.obolibrary.org/obo/CL_0000187
# 7054   http://purl.obolibrary.org/obo/CL_0000187
# 7064   http://purl.obolibrary.org/obo/CL_0000187
# 7887   http://purl.obolibrary.org/obo/CL_0000187
# 8163   http://purl.obolibrary.org/obo/CL_0000187
# 11168  http://purl.obolibrary.org/obo/CL_0000187
#
#                                           object_obo
# 1      http://purl.obolibrary.org/obo/UBERON_0002082
# 2      http://purl.obolibrary.org/obo/UBERON_0002082
# 11     http://purl.obolibrary.org/obo/UBERON_0002082
# 122    http://purl.obolibrary.org/obo/UBERON_0002082
# 130    http://purl.obolibrary.org/obo/UBERON_0002082
# 1148   http://purl.obolibrary.org/obo/UBERON_0002082
# 2059   http://purl.obolibrary.org/obo/UBERON_0002082
# 4348   http://purl.obolibrary.org/obo/UBERON_0002082
# 4677   http://purl.obolibrary.org/obo/UBERON_0002082
# 5607   http://purl.obolibrary.org/obo/UBERON_0002082
# 6799   http://purl.obolibrary.org/obo/UBERON_0002082
# 6813   http://purl.obolibrary.org/obo/UBERON_0002082
# 6918   http://purl.obolibrary.org/obo/UBERON_0002082
# 6922   http://purl.obolibrary.org/obo/UBERON_0002082
# 7051   http://purl.obolibrary.org/obo/UBERON_0002082
# 7054   http://purl.obolibrary.org/obo/UBERON_0002082
# 7064   http://purl.obolibrary.org/obo/UBERON_0002082
# 7887   http://purl.obolibrary.org/obo/UBERON_0002082
# 8163   http://purl.obolibrary.org/obo/UBERON_0002082
# 11168  http://purl.obolibrary.org/obo/UBERON_0002082

# %%
df_new.loc[(df_new['subject_obo'] == x) & (df_new['object_obo'] == z)  & 
                               (df_new['predicate_obo'] == y)]['pmid'].values[0]
# Out:
# 29913456

# %%
df_new.head()
# Out:
#        pmid subject_cui    subject_type object_cui object_type    year  \
# 0  29913456    C1704263       orch,phsu   C2349205        fndg  2018.0
# 1  29913456    C0596981            cell   C0018827        bpoc  2018.0
# 2  29913456    C0596981            cell   C0018827        bpoc  2018.0
# 3  29913456    C0017725  bacs,orch,phsu   C0225828        cell  2018.0
# 4  29913456    C0034354            orch   C0225828        cell  2018.0
#
#         subject_name        object_name  \
# 0  Green Tea Extract       Normal heart
# 1       Muscle Cells    Heart Ventricle
# 2       Muscle Cells    Heart Ventricle
# 3            Glucose  Myocytes, Cardiac
# 4          Pyruvates  Myocytes, Cardiac
#
#                                          source_text predicate  \
# 0  29913456_ascii.txt.tx.1 Abstract Background/Ai...   affects
# 1  29913456_ascii.txt.tx.4 From the heart of 6 CT...   part_of
# 2  29913456_ascii.txt.tx.1 Mechanical properties ...   part_of
# 3  29913456_ascii.txt.tx.4 Mitochondrial respirat...   part_of
# 4  29913456_ascii.txt.tx.4 Mitochondrial respirat...   part_of
#
#                                 predicate_obo  \
# 0   http://purl.obolibrary.org/obo/RO_0002596
# 1  http://purl.obolibrary.org/obo/BFO_0000050
# 2  http://purl.obolibrary.org/obo/BFO_0000050
# 3  http://purl.obolibrary.org/obo/BFO_0000050
# 4  http://purl.obolibrary.org/obo/BFO_0000050
#
#                                          subject_obo  \
# 0  http://napdi.org/napdi_srs_imports:camellia_si...
# 1          http://purl.obolibrary.org/obo/CL_0000187
# 2          http://purl.obolibrary.org/obo/CL_0000187
# 3         http://purl.obolibrary.org/obo/CHEBI_17234
# 4         http://purl.obolibrary.org/obo/CHEBI_15361
#
#                                       object_obo
# 0  http://purl.obolibrary.org/obo/UBERON_0000948
# 1  http://purl.obolibrary.org/obo/UBERON_0002082
# 2  http://purl.obolibrary.org/obo/UBERON_0002082
# 3      http://purl.obolibrary.org/obo/CL_0000187
# 4      http://purl.obolibrary.org/obo/CL_0000187

# %%
for s,p,o in tqdm(graph):
    print(s,p,o)
    break
# Out:
#   0%|          | 0/9771 [00:00<?, ?it/s]
# http://purl.obolibrary.org/obo/PR_000008555 http://purl.obolibrary.org/obo/RO_0002434 http://purl.obolibrary.org/obo/CHEBI_35610

# %%
#convert rdflib graph to multidigraph - code borrowed from PheKnowLator: kg_utils.py
#use the pred key to also create a dictionary with metadata about the edge - 
#pub_year, pmid, source graph, belief
nx_mdg = nx.MultiDiGraph()
for s, p, o in tqdm(graph):
    #do not save label predicate to gpickle
    subj = str(s)
    obj = str(o)
    pred = str(p)
    if pred == 'http://www.w3.org/2000/01/rdf-schema#label':
        continue
    else:

        pred_key = hashlib.md5('{}{}{}'.format(n3(s), n3(p), n3(o)).encode()).hexdigest()
        pmid = str(df_new.loc[(df_new['subject_obo'] == subj) & (df_new['object_obo'] == obj)  & 
                       (df_new['predicate_obo'] == pred)]['pmid'].values[0])
        timestamp = str(df_new.loc[(df_new['subject_obo'] == subj) & (df_new['object_obo'] == obj)  & 
                                   (df_new['predicate_obo'] == pred)]['year'].values[0])
        belief_score = 0.8
        nx_mdg.add_node(s, key=n3(s))
        nx_mdg.add_node(o, key=n3(o))
        nx_mdg.add_edge(s, o, **{'key': p, 'predicate_key': pred_key, 'weight':0.0,
                                 'pmid': pmid, 'timestamp': timestamp, 'source_graph': 'machine_read',
                                'belief': belief_score})
nx.write_gpickle(nx_mdg, "output_graphs/machineread_semrep_version3.gpickle")
# Out:
# 100%|██████████| 12079/12079 [01:48<00:00, 111.11it/s]

# %%
triples = len(graph)
nodes = len(set(list(graph.subjects()) + list(graph.objects())))
rels = len(set(list(graph.predicates())))
print(triples, nodes, rels)
# Out:
# 12079 5557 17

# %%
#this should have less edges than rdflib graph after removing 'labels'
nodes = nx.number_of_nodes(nx_mdg)
edges = nx.number_of_edges(nx_mdg)
density = nx.density(nx_mdg)
avg_deg = float(edges)/nodes
print(nodes, edges, density, avg_deg)
# Out:
# 2710 9232 0.0012575275254413673 3.4066420664206642

# %%
#figure out how to extract information from saved gpickle predicate dictionary - pmid,

# %%
NV = nx_mdg.nodes()
i = 0
for (k,v) in NV.items():
    if i==20:
        break
    print('{}:{}'.format(k,v))
    i=i+1
# Out:
# http://purl.obolibrary.org/obo/CHEBI_36856:{'key': '<http://purl.obolibrary.org/obo/CHEBI_36856>'}
# http://purl.obolibrary.org/obo/PR_Q05421:{'key': '<http://purl.obolibrary.org/obo/PR_Q05421>'}
# http://purl.obolibrary.org/obo/PR_Q5EG47:{'key': '<http://purl.obolibrary.org/obo/PR_Q5EG47>'}
# http://purl.obolibrary.org/obo/GO_0005243:{'key': '<http://purl.obolibrary.org/obo/GO_0005243>'}
# http://purl.obolibrary.org/obo/CHEBI_80961:{'key': '<http://purl.obolibrary.org/obo/CHEBI_80961>'}
# http://purl.obolibrary.org/obo/CHEBI_16856:{'key': '<http://purl.obolibrary.org/obo/CHEBI_16856>'}
# http://purl.obolibrary.org/obo/CHEBI_4911:{'key': '<http://purl.obolibrary.org/obo/CHEBI_4911>'}
# http://purl.obolibrary.org/obo/CHEBI_39124:{'key': '<http://purl.obolibrary.org/obo/CHEBI_39124>'}
# http://purl.obolibrary.org/obo/CHEBI_27881:{'key': '<http://purl.obolibrary.org/obo/CHEBI_27881>'}
# http://purl.obolibrary.org/obo/PR_000001044:{'key': '<http://purl.obolibrary.org/obo/PR_000001044>'}
# http://purl.obolibrary.org/obo/CHEBI_4806:{'key': '<http://purl.obolibrary.org/obo/CHEBI_4806>'}
# http://purl.obolibrary.org/obo/PR_F1LP90:{'key': '<http://purl.obolibrary.org/obo/PR_F1LP90>'}
# http://purl.obolibrary.org/obo/GO_0006351:{'key': '<http://purl.obolibrary.org/obo/GO_0006351>'}
# http://purl.obolibrary.org/obo/GO_0006954:{'key': '<http://purl.obolibrary.org/obo/GO_0006954>'}
# http://purl.obolibrary.org/obo/CHEBI_35026:{'key': '<http://purl.obolibrary.org/obo/CHEBI_35026>'}
# http://purl.obolibrary.org/obo/CHEBI_5441:{'key': '<http://purl.obolibrary.org/obo/CHEBI_5441>'}
# http://purl.obolibrary.org/obo/CHEBI_16234:{'key': '<http://purl.obolibrary.org/obo/CHEBI_16234>'}
# http://purl.obolibrary.org/obo/PR_000015224:{'key': '<http://purl.obolibrary.org/obo/PR_000015224>'}
# http://purl.obolibrary.org/obo/PR_Q9UKG1:{'key': '<http://purl.obolibrary.org/obo/PR_Q9UKG1>'}
# http://purl.obolibrary.org/obo/CHEBI_9506:{'key': '<http://purl.obolibrary.org/obo/CHEBI_9506>'}

# %%
i = -1
for (s,o,k,d) in nx_mdg.edges(data=True, keys=True):
    i+=1
    if i==2:
        break
    print(s)
    print(o)
    print(k)
    print(d)
# Out:
# http://purl.obolibrary.org/obo/CHEBI_36856
# http://purl.obolibrary.org/obo/PR_Q05421
# http://purl.obolibrary.org/obo/RO_0002449
# {'predicate_key': '92e324b79c1218fb412629e2cc185585', 'weight': 0.0, 'pmid': '29356593', 'timestamp': '2018 Feb', 'source_graph': 'machine_read'}
# http://purl.obolibrary.org/obo/CHEBI_36856
# http://purl.obolibrary.org/obo/PR_Q05421
# http://purl.obolibrary.org/obo/RO_0002436
# {'predicate_key': 'e79d4f1ccf29afa3b87bde913d61c4eb', 'weight': 0.0, 'pmid': '29356593', 'timestamp': '2018 Feb', 'source_graph': 'machine_read'}

# %%
#save node labels as dictionary
#key: URI, value is label
label_dict = {}
for i in range(len(df_new.index)):
    subj = str(df_new.at[i, 'subject_obo'])
    obj = str(df_new.at[i, 'object_obo'])
    pred = str(df_new.at[i, 'predicate_obo'])
    if subj not in label_dict:
        label_dict[subj] = {}
        label_dict[subj]['entity_type'] = 'NODES'
        label_dict[subj]['label'] = df_new.at[i, 'subject_name']
        label_dict[subj]['cui'] = df_new.at[i, 'subject_cui']
    if obj not in label_dict:
        label_dict[obj] = {}
        label_dict[obj]['entity_type'] = 'NODES'
        label_dict[obj]['label'] = df_new.at[i, 'object_name']
        label_dict[obj]['cui'] = df_new.at[i, 'object_cui']
    if pred not in label_dict:
        label_dict[pred] = {}
        label_dict[pred]['entity_type'] = 'RELATIONS'
        label_dict[pred]['label'] = df_new.at[i, 'predicate']
len(label_dict)
# Out:
# 2726

# %%
import pickle
with open('output_graphs/machineread_semrep_version3_NodeLabels.pickle', 'wb') as file_p:
    pickle.dump(label_dict, file_p)

# %%
dfmap = pd.DataFrame.from_dict(label_dict, orient='index')
dfmap.head()
# Out:
#                                                    entity_type  \
# http://napdi.org/napdi_srs_imports:camellia_sin...       NODES
# http://purl.obolibrary.org/obo/UBERON_0000948            NODES
# http://purl.obolibrary.org/obo/RO_0002596            RELATIONS
# http://purl.obolibrary.org/obo/CL_0000187                NODES
# http://purl.obolibrary.org/obo/UBERON_0002082            NODES
#
#                                                                 label  \
# http://napdi.org/napdi_srs_imports:camellia_sin...  Green Tea Extract
# http://purl.obolibrary.org/obo/UBERON_0000948            Normal heart
# http://purl.obolibrary.org/obo/RO_0002596                     affects
# http://purl.obolibrary.org/obo/CL_0000187                Muscle Cells
# http://purl.obolibrary.org/obo/UBERON_0002082         Heart Ventricle
#
#                                                          cui
# http://napdi.org/napdi_srs_imports:camellia_sin...  C1704263
# http://purl.obolibrary.org/obo/UBERON_0000948       C2349205
# http://purl.obolibrary.org/obo/RO_0002596                NaN
# http://purl.obolibrary.org/obo/CL_0000187           C0596981
# http://purl.obolibrary.org/obo/UBERON_0002082       C0018827

# %%
dfmap = dfmap.reset_index()
dfmap.head()
# Out:
#                                                index entity_type  \
# 0  http://napdi.org/napdi_srs_imports:camellia_si...       NODES
# 1      http://purl.obolibrary.org/obo/UBERON_0000948       NODES
# 2          http://purl.obolibrary.org/obo/RO_0002596   RELATIONS
# 3          http://purl.obolibrary.org/obo/CL_0000187       NODES
# 4      http://purl.obolibrary.org/obo/UBERON_0002082       NODES
#
#                label       cui
# 0  Green Tea Extract  C1704263
# 1       Normal heart  C2349205
# 2            affects       NaN
# 3       Muscle Cells  C0596981
# 4    Heart Ventricle  C0018827

# %%
dfmap = dfmap.rename(columns={"index":"entity_uri"})
dfmap.head()
# Out:
#                                           entity_uri entity_type  \
# 0  http://napdi.org/napdi_srs_imports:camellia_si...       NODES
# 1      http://purl.obolibrary.org/obo/UBERON_0000948       NODES
# 2          http://purl.obolibrary.org/obo/RO_0002596   RELATIONS
# 3          http://purl.obolibrary.org/obo/CL_0000187       NODES
# 4      http://purl.obolibrary.org/obo/UBERON_0002082       NODES
#
#                label       cui
# 0  Green Tea Extract  C1704263
# 1       Normal heart  C2349205
# 2            affects       NaN
# 3       Muscle Cells  C0596981
# 4    Heart Ventricle  C0018827

# %%
dfmap.to_csv('output_graphs/machineread_semrep_version3_NodeLabels.tsv', index=False, sep='\t')

# %%
##run closure in separate notebook - see machine_read_closure.ipynb

# %%
import pandas as pd
# import built-in namespaces
from rdflib.namespace import OWL, RDF, RDFS

# %%
#at some point do for multiple files with machine read triples

# %%
dfgt = pd.read_csv('predication_files/greentea_pmid_all_predicates_umls.tsv', sep='\t')
dfgt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11799 entries, 0 to 11798
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   seq                   11799 non-null  int64
#  1   pmid                  11799 non-null  int64
#  2   subject_cui           10243 non-null  object
#  3   subject_name          10243 non-null  object
#  4   subject_type          10243 non-null  object
#  5   subject_source        11473 non-null  object
#  6   subj_map_reach        11778 non-null  object
#  7   predicate             11799 non-null  object
#  8   object_source         11580 non-null  object
#  9   object_cui            10356 non-null  object
#  10  object_name           10356 non-null  object
#  11  object_type           10356 non-null  object
#  12  obj_map_reach         11799 non-null  object
#  13  belief                11799 non-null  float64
#  14  sentence              11799 non-null  object
#  15  pub_year              11799 non-null  object
#  16  subject_score         10243 non-null  float64
#  17  object_score          10356 non-null  float64
#  18  umls_flag             11799 non-null  int64
#  19  subj_reach_grounding  11778 non-null  object
#  20  obj_reach_grounding   11799 non-null  object
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.9+ MB

# %%
dfgt.head()
# Out:
#    seq      pmid subject_cui              subject_name  \
# 0    0  30286210    C0017337                     Genes
# 1    1  30286210    C0017337                     Genes
# 2    2  25680958    C1562292                 Incretins
# 3    3  25680958    C1418880                PRDX2_gene
# 4    4  23210776    C0059438  epigallocatechin_gallate
#
#                subject_type                subject_source  \
# 0                  ['gngm']         gene encoding SERCA2a
# 1                  ['gngm']         gene encoding SERCA2a
# 2  ['aapp', 'horm', 'phsu']                      incretin
# 3                  ['gngm']                trichostatin A
# 4          ['orch', 'phsu']  --epigallocatechin 3-gallate
#
#                                       subj_map_reach    predicate  \
# 0                  {'TEXT': 'gene encoding SERCA2a'}  Acetylation
# 1                  {'TEXT': 'gene encoding SERCA2a'}  Acetylation
# 2                               {'TEXT': 'incretin'}  Acetylation
# 3  {'PUBCHEM': '444732', 'CHEBI': 'CHEBI:46024', ...  Acetylation
# 4  {'PUBCHEM': '65064', 'CHEBI': 'CHEBI:4806', 'C...  Acetylation
#
#   object_source object_cui  ...       object_type  \
# 0    Histone_H3   C0019652  ...  ['aapp', 'bacs']
# 1    Histone_H3   C0019652  ...  ['aapp', 'bacs']
# 2  Kv  subunits        NaN  ...               NaN
# 3       Tubulin   C0041348  ...  ['aapp', 'bacs']
# 4       Histone   C0019652  ...  ['aapp', 'bacs']
#
#                                        obj_map_reach belief  \
# 0  {'FPLX': 'Histone_H3', 'TEXT': 'histone 3', 'N...   0.65
# 1  {'FPLX': 'Histone_H3', 'TEXT': 'histone 3', 'N...   0.65
# 2                           {'TEXT': 'Kv␤ subunits'}   0.65
# 3  {'FPLX': 'Tubulin', 'NCIT': 'C17219', 'MESH': ...   0.65
# 4  {'FPLX': 'Histone', 'CAS': '37244-51-2', 'MESH...   0.65
#
#                                             sentence  pub_year subject_score  \
# 0  Our data indicate that increased HDAC1 activit...      2018         16.09
# 1  Our data indicate that increased HDAC1 activit...      2018         16.09
# 2  Modification of\nchannel proteins by acetylati...  2015 Apr         20.95
# 3  It was reported that ␣-tubulin underwent\nlysi...  2015 Apr          5.18
# 4  EGCG [177] \nand  grape  seed  proanthocyanidi...      2013         14.64
#
#    object_score  umls_flag      subj_reach_grounding     obj_reach_grounding
# 0          16.3          1              (None, None)  ('FPLX', 'Histone_H3')
# 1          16.3          1              (None, None)  ('FPLX', 'Histone_H3')
# 2           NaN          1              (None, None)            (None, None)
# 3          17.8          1  ('CHEBI', 'CHEBI:46024')     ('FPLX', 'Tubulin')
# 4          17.8          1   ('CHEBI', 'CHEBI:4806')     ('FPLX', 'Histone')
#
# [5 rows x 21 columns]

# %%
df = dfgt[['subject_cui', 'subject_name', 'subject_source', 'predicate', 'object_source',
       'object_cui', 'object_name', 'subj_reach_grounding', 'obj_reach_grounding', 'pmid', 
           'pub_year', 'belief', 'sentence']]

# %%
df['predicate_obo'] = None
df['subject_obo'] = None
df['object_obo'] = None
# Out:
# /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.head()
# Out:
#   subject_cui              subject_name                subject_source  \
# 0    C0017337                     Genes         gene encoding SERCA2a
# 1    C0017337                     Genes         gene encoding SERCA2a
# 2    C1562292                 Incretins                      incretin
# 3    C1418880                PRDX2_gene                trichostatin A
# 4    C0059438  epigallocatechin_gallate  --epigallocatechin 3-gallate
#
#      predicate object_source object_cui object_name      subj_reach_grounding  \
# 0  Acetylation    Histone_H3   C0019652    Histones              (None, None)
# 1  Acetylation    Histone_H3   C0019652    Histones              (None, None)
# 2  Acetylation  Kv  subunits        NaN         NaN              (None, None)
# 3  Acetylation       Tubulin   C0041348     Tubulin  ('CHEBI', 'CHEBI:46024')
# 4  Acetylation       Histone   C0019652    Histones   ('CHEBI', 'CHEBI:4806')
#
#       obj_reach_grounding      pmid  pub_year  belief  \
# 0  ('FPLX', 'Histone_H3')  30286210      2018    0.65
# 1  ('FPLX', 'Histone_H3')  30286210      2018    0.65
# 2            (None, None)  25680958  2015 Apr    0.65
# 3     ('FPLX', 'Tubulin')  25680958  2015 Apr    0.65
# 4     ('FPLX', 'Histone')  23210776      2013    0.65
#
#                                             sentence predicate_obo  \
# 0  Our data indicate that increased HDAC1 activit...          None
# 1  Our data indicate that increased HDAC1 activit...          None
# 2  Modification of\nchannel proteins by acetylati...          None
# 3  It was reported that ␣-tubulin underwent\nlysi...          None
# 4  EGCG [177] \nand  grape  seed  proanthocyanidi...          None
#
#   subject_obo object_obo
# 0        None       None
# 1        None       None
# 2        None       None
# 3        None       None
# 4        None       None

# %%
go_hpo_map = pd.read_csv('cui_to_ontology_maps/go_hpo_map.csv')

# %%
go_hpo_map.index
# Out:
# RangeIndex(start=0, stop=90376, step=1)

# %%
go_hpo_mapping_dict = {}
for i in range(len(go_hpo_map.index)):
    cui = go_hpo_map.at[i,'cui']
    if cui not in go_hpo_mapping_dict:
        go_hpo_mapping_dict[cui] = []
    code = go_hpo_map.at[i, 'code']
    code = code.replace(':', '_')
    go_hpo_mapping_dict[cui].append(code)
print(len(go_hpo_mapping_dict))
# Out:
# 87745

# %%
#taking only first mapped for now -- assess if that option is the best (how?)

# %%
go_hpo_mapping_dict['C0001122']
# Out:
# ['HP_0001941']

# %%
import numpy as np

# %%
#reach mapping
#(CHEBI,CHEBI:xx), (GO, GO:x)x, (UP, xx)
df.iloc[3].subj_reach_grounding != np.nan
# Out:
# True

# %%
df = df.fillna('')

# %%
reach_grounding_dict = {}
for i in range(len(df.index)):
    sub_cui = df.at[i, 'subject_cui']
    reach_grounding_dict[sub_cui] = []
    obj_cui = df.at[i, 'object_cui']
    if obj_cui not in reach_grounding_dict:
        reach_grounding_dict[obj_cui] = []
    sub_ground = df.at[i, 'subj_reach_grounding']
    obj_ground = df.at[i, 'obj_reach_grounding']
    if sub_ground != np.nan:
        if 'CHEBI' in sub_ground or 'GO' in sub_ground:
            subject_map = sub_ground.split("'")[-2]
            subject_map = subject_map.replace(':', '_')
            reach_grounding_dict[sub_cui].append(subject_map)
        elif 'UP' in sub_ground:
            subject_map = sub_ground.split("'")[-2]
            subject_map = 'PR_' + subject_map
            reach_grounding_dict[sub_cui].append(subject_map)
    if obj_ground != np.nan:
        if 'CHEBI' in obj_ground or 'GO' in obj_ground:
            object_map = obj_ground.split("'")[-2]
            object_map = object_map.replace(':', '_')
            reach_grounding_dict[obj_cui].append(object_map)
        elif 'UP' in obj_ground:
            object_map = obj_ground.split("'")[-2]
            object_map = 'PR_' + object_map
            reach_grounding_dict[obj_cui].append(object_map)
print(len(reach_grounding_dict))
# Out:
# 2738

# %%
reach_grounding_dict['C1418880']
# Out:
# ['CHEBI_46024']

# %%
predMapD = {
    'regulateactivity':'',
    'regulateamount':'',
    'phosphorylation':'RO_0002447',
    'dephosphorylation':'GO_0006470',
    'ubiquitination':'RO_0002480',
    'deubiquitination':'GO_0016579',
    'sumoylation':'',
    'desumoylation':'',
    'hydroxylation':'GO_0018126',
    'dehydroxylation':'RO_0002436',
    'acetylation':'GO_0006473',
    'deacetylation':'GO_0006476',
    'glycosylation':'GO_0006486',
    'deglycosylation':'GO_0006517',
    'farnesylation':'',
    'defarnesylation':'',
    'geranylgeranylation':'',
    'degeranylgeranylation':'',
    'palmitoylation':'',
    'depalmitoylation':'',
    'myristoylation':'',
    'demyristoylation':'',
    'ribosylation':'',
    'deribosylation':'',
    'methylation':'GO_0006479',
    'demethylation':'GO_0006482',
    'activation':'RO_0002436',
    'inhibition':'RO_0002449',
    'increaseamount':'RO_0002429',
    'decreaseamount':'RO_0002212'
}

# %%
#if reach_grounding has multiple values, currently only first one is taken -- assess if this is the best option
def get_obo_mapping(row, col):
    if col == 'subject':
        cui = row['subject_cui']
    elif col == 'object':
        cui = row['object_cui']
    else:
        print('specify is subject or object mapping required')
        exit(0)
    if cui in go_hpo_mapping_dict:
        if len(go_hpo_mapping_dict):
            return go_hpo_mapping_dict[cui][0]
    if cui in reach_grounding_dict:
        if len(reach_grounding_dict[cui]):
            return reach_grounding_dict[cui][0]
    return ''

# %%
def relation_mapping(row):
    rel = row['predicate'].lower()
    if rel in predMapD:
        return predMapD[rel]
    else:
        return ''

# %%
df['predicate_obo'] = df.apply(relation_mapping, axis=1)

# %%
df['predicate_obo'] = df.apply(relation_mapping, axis=1)

# %%
df.head()
# Out:
#   subject_cui              subject_name                subject_source  \
# 0    C0017337                     Genes         gene encoding SERCA2a
# 1    C0017337                     Genes         gene encoding SERCA2a
# 2    C1562292                 Incretins                      incretin
# 3    C1418880                PRDX2_gene                trichostatin A
# 4    C0059438  epigallocatechin_gallate  --epigallocatechin 3-gallate
#
#      predicate object_source object_cui object_name      subj_reach_grounding  \
# 0  Acetylation    Histone_H3   C0019652    Histones              (None, None)
# 1  Acetylation    Histone_H3   C0019652    Histones              (None, None)
# 2  Acetylation  Kv  subunits                                     (None, None)
# 3  Acetylation       Tubulin   C0041348     Tubulin  ('CHEBI', 'CHEBI:46024')
# 4  Acetylation       Histone   C0019652    Histones   ('CHEBI', 'CHEBI:4806')
#
#       obj_reach_grounding      pmid  pub_year  belief  \
# 0  ('FPLX', 'Histone_H3')  30286210      2018    0.65
# 1  ('FPLX', 'Histone_H3')  30286210      2018    0.65
# 2            (None, None)  25680958  2015 Apr    0.65
# 3     ('FPLX', 'Tubulin')  25680958  2015 Apr    0.65
# 4     ('FPLX', 'Histone')  23210776      2013    0.65
#
#                                             sentence predicate_obo  \
# 0  Our data indicate that increased HDAC1 activit...    GO_0006473
# 1  Our data indicate that increased HDAC1 activit...    GO_0006473
# 2  Modification of\nchannel proteins by acetylati...    GO_0006473
# 3  It was reported that ␣-tubulin underwent\nlysi...    GO_0006473
# 4  EGCG [177] \nand  grape  seed  proanthocyanidi...    GO_0006473
#
#   subject_obo object_obo
# 0
# 1
# 2
# 3
# 4

# %%
#MAPPING
df['subject_obo'] = df.apply(get_obo_mapping, axis=1, col='subject')
df.head()
# Out:
#   subject_cui              subject_name                subject_source  \
# 0    C0017337                     Genes         gene encoding SERCA2a
# 1    C0017337                     Genes         gene encoding SERCA2a
# 2    C1562292                 Incretins                      incretin
# 3    C1418880                PRDX2_gene                trichostatin A
# 4    C0059438  epigallocatechin_gallate  --epigallocatechin 3-gallate
#
#      predicate object_source object_cui object_name      subj_reach_grounding  \
# 0  Acetylation    Histone_H3   C0019652    Histones              (None, None)
# 1  Acetylation    Histone_H3   C0019652    Histones              (None, None)
# 2  Acetylation  Kv  subunits                                     (None, None)
# 3  Acetylation       Tubulin   C0041348     Tubulin  ('CHEBI', 'CHEBI:46024')
# 4  Acetylation       Histone   C0019652    Histones   ('CHEBI', 'CHEBI:4806')
#
#       obj_reach_grounding      pmid  pub_year  belief  \
# 0  ('FPLX', 'Histone_H3')  30286210      2018    0.65
# 1  ('FPLX', 'Histone_H3')  30286210      2018    0.65
# 2            (None, None)  25680958  2015 Apr    0.65
# 3     ('FPLX', 'Tubulin')  25680958  2015 Apr    0.65
# 4     ('FPLX', 'Histone')  23210776      2013    0.65
#
#                                             sentence predicate_obo  \
# 0  Our data indicate that increased HDAC1 activit...    GO_0006473
# 1  Our data indicate that increased HDAC1 activit...    GO_0006473
# 2  Modification of\nchannel proteins by acetylati...    GO_0006473
# 3  It was reported that ␣-tubulin underwent\nlysi...    GO_0006473
# 4  EGCG [177] \nand  grape  seed  proanthocyanidi...    GO_0006473
#
#    subject_obo object_obo
# 0
# 1
# 2
# 3  CHEBI_46024
# 4   CHEBI_4806

# %%
df['object_obo'] = df.apply(get_obo_mapping, axis=1, col='object')
df.head()
# Out:
#   subject_cui              subject_name                subject_source  \
# 0    C0017337                     Genes         gene encoding SERCA2a
# 1    C0017337                     Genes         gene encoding SERCA2a
# 2    C1562292                 Incretins                      incretin
# 3    C1418880                PRDX2_gene                trichostatin A
# 4    C0059438  epigallocatechin_gallate  --epigallocatechin 3-gallate
#
#      predicate object_source object_cui object_name      subj_reach_grounding  \
# 0  Acetylation    Histone_H3   C0019652    Histones              (None, None)
# 1  Acetylation    Histone_H3   C0019652    Histones              (None, None)
# 2  Acetylation  Kv  subunits                                     (None, None)
# 3  Acetylation       Tubulin   C0041348     Tubulin  ('CHEBI', 'CHEBI:46024')
# 4  Acetylation       Histone   C0019652    Histones   ('CHEBI', 'CHEBI:4806')
#
#       obj_reach_grounding      pmid  pub_year  belief  \
# 0  ('FPLX', 'Histone_H3')  30286210      2018    0.65
# 1  ('FPLX', 'Histone_H3')  30286210      2018    0.65
# 2            (None, None)  25680958  2015 Apr    0.65
# 3     ('FPLX', 'Tubulin')  25680958  2015 Apr    0.65
# 4     ('FPLX', 'Histone')  23210776      2013    0.65
#
#                                             sentence predicate_obo  \
# 0  Our data indicate that increased HDAC1 activit...    GO_0006473
# 1  Our data indicate that increased HDAC1 activit...    GO_0006473
# 2  Modification of\nchannel proteins by acetylati...    GO_0006473
# 3  It was reported that ␣-tubulin underwent\nlysi...    GO_0006473
# 4  EGCG [177] \nand  grape  seed  proanthocyanidi...    GO_0006473
#
#    subject_obo object_obo
# 0
# 1
# 2
# 3  CHEBI_46024
# 4   CHEBI_4806

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11799 entries, 0 to 11798
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   subject_cui           11799 non-null  object
#  1   subject_name          11799 non-null  object
#  2   subject_source        11799 non-null  object
#  3   predicate             11799 non-null  object
#  4   object_source         11799 non-null  object
#  5   object_cui            11799 non-null  object
#  6   object_name           11799 non-null  object
#  7   subj_reach_grounding  11799 non-null  object
#  8   obj_reach_grounding   11799 non-null  object
#  9   pmid                  11799 non-null  int64
#  10  pub_year              11799 non-null  object
#  11  belief                11799 non-null  float64
#  12  sentence              11799 non-null  object
#  13  predicate_obo         11799 non-null  object
#  14  subject_obo           11799 non-null  object
#  15  object_obo            11799 non-null  object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 1.4+ MB

# %%
#do we need bioportal mapping? -- yes. Get unmapped CUIs
unmapped_cui = []
unmapped_string_umls = []
for i in range(len(df.index)):
    if df.at[i, 'subject_obo'] == '':
        subcui = df.at[i, 'subject_cui']
        if subcui not in unmapped_cui:
            unmapped_cui.append(df.at[i, 'subject_cui'])
            unmapped_string_umls.append(df.at[i, 'subject_name'])
    if df.at[i, 'object_obo'] == '':
        objcui = df.at[i, 'object_cui']
        if objcui not in unmapped_cui:
            unmapped_cui.append(df.at[i, 'object_cui'])
            unmapped_string_umls.append(df.at[i, 'object_name'])

# %%
print(len(unmapped_cui))
print(len(unmapped_string_umls))
# Out:
# 1487
# 1487

# %%
#Total CUI = 2737
#unmapped CUI = 1487
#mapped CUI = 1250

# %%
unmapped_string_umls[:20]
# Out:
# ['Genes',
#  'Histones',
#  'Incretins',
#  '',
#  'Tubulin',
#  'rosoxacin',
#  'Hat_-_Headwear',
#  'Sirtuin_1',
#  'Retinoid_X_Receptors',
#  'NR1H4_gene',
#  'EIF4E_wt_Allele',
#  'WNK1_protein,_human',
#  'EP300_protein,_human',
#  'ATP2A2_protein,_human',
#  'Juan_de_Nova_Island',
#  'NF-kappa_B',
#  'Fluorides',
#  'Insulin',
#  'Mus',
#  '13-lipoxygenase']

# %%
unmapped_string_umls_new = []
for item in unmapped_string_umls:
    item = item.replace('_', ' ')
    unmapped_string_umls_new.append(item.upper())

# %%
unmapped_string_umls_new[:20]
# Out:
# ['GENES',
#  'HISTONES',
#  'INCRETINS',
#  '',
#  'TUBULIN',
#  'ROSOXACIN',
#  'HAT - HEADWEAR',
#  'SIRTUIN 1',
#  'RETINOID X RECEPTORS',
#  'NR1H4 GENE',
#  'EIF4E WT ALLELE',
#  'WNK1 PROTEIN, HUMAN',
#  'EP300 PROTEIN, HUMAN',
#  'ATP2A2 PROTEIN, HUMAN',
#  'JUAN DE NOVA ISLAND',
#  'NF-KAPPA B',
#  'FLUORIDES',
#  'INSULIN',
#  'MUS',
#  '13-LIPOXYGENASE']

# %%
unmapped_cui[:20]
# Out:
# ['C0017337',
#  'C0019652',
#  'C1562292',
#  '',
#  'C0041348',
#  'C0073591',
#  'C0444765',
#  'C2720167',
#  'C0140283',
#  'C1417825',
#  'C3539643',
#  'C1453853',
#  'C1530358',
#  'C1567357',
#  'C4053566',
#  'C0079904',
#  'C0016327',
#  'C0021641',
#  'C0026809',
#  'C0763738']

# %%
with open('cui_to_ontology_maps/unmapped_umls_strings.txt', 'w') as file1:
    for item in unmapped_string_umls_new:
        file1.write(item)
        file1.write('\n')
with open('cui_to_ontology_maps/unmapped_umls_cui.txt', 'w') as file2:
    for item in unmapped_cui:
        file2.write(item)
        file2.write('\n')

# %%
#Bioportal mappings - load and use (run curl query and use json response)
# Process Bioportal annotator response
bioportal_map_dict = {}
import json
f = open('cui_to_ontology_maps/unmapped_strings_annotator_response.json','r')
map_d_l = json.load(f)
f.close()

# all unmapped strings and CUIs
strToCuiD = {}
cuiToStrD = {}
#len = 1487
for i in range(len(unmapped_cui)):
    s = unmapped_string_umls_new[i]
    cui = unmapped_cui[i]
    strToCuiD[s.upper()] = cui
    cuiToStrD[cui] = s.upper()

for d in map_d_l:
    mapped_to = d['annotatedClass']['@id']
    for mapped_from_d in d['annotations']:
            if not strToCuiD.get(mapped_from_d['text'].upper()):
                continue
            else:
                cui = strToCuiD[mapped_from_d['text'].upper()]
                if not bioportal_map_dict.get(cui):
                    bioportal_map_dict[cui] = [mapped_to]
                else:
                    if mapped_to not in bioportal_map_dict[cui]:
                        bioportal_map_dict[cui].append(mapped_to)
print(len(bioportal_map_dict))
# Out:
# 337

# %%
for key in bioportal_map_dict:
    print(key)
    print(bioportal_map_dict[key])
    break
# Out:
# C0209278
# ['http://purl.obolibrary.org/obo/PR_000008652']

# %%
map_d_l[0]['annotations']
# Out:
# [{'from': 1, 'to': 15, 'matchType': 'PREF', 'text': 'SERUM AMYLOID A'}]

# %%
bioportal_mappings = {}
for item in map_d_l:
    mapped_to = item['annotatedClass']['@id']
    for mapped_from_d in item['annotations']:
        if mapped_from_d['text'] not in bioportal_mappings:
            bioportal_mappings[mapped_from_d['text']] = mapped_to
len(bioportal_mappings)
# Out:
# 1137

# %%
bioportal_mappings['SLC9A1']
# Out:
# 'http://purl.obolibrary.org/obo/PR_P19634'

# %%
strToBioMap = {}
for key in strToCuiD:
    original_text = key
    strToBioMap[original_text] = []
    for key_bioportal in bioportal_mappings:
        if key_bioportal in original_text:
            strToBioMap[original_text].append((key_bioportal, bioportal_mappings[key_bioportal]))
len(strToBioMap)
# Out:
# 1487

# %%
for key in strToBioMap:
    print(key)
    print(strToBioMap[key])
    break
# Out:
# GENES
# [('GENE', 'http://purl.obolibrary.org/obo/SO_0000704')]

# %% [markdown]
# **skip next 3 cells if not manually reviewing mappings**

# %%
##manually assessing if the mapping is correct for non-exact matches
##do not assess if already mapped in bioportal_map_dict
df_list = []
for key in strToBioMap:
    cui = strToCuiD[key]
    if cui in bioportal_map_dict:
        continue
    else:
        original_text = key
        df_list.append([cui, original_text, strToBioMap[key]])
len(df_list)
# Out:
# 1150

# %%
df_ass = pd.DataFrame(df_list, columns = ['cui', 'original_text', 'bioportal_mappings'])
df_ass.head()
# Out:
#         cui   original_text                                 bioportal_mappings
# 0  C0017337           GENES  [(GENE, http://purl.obolibrary.org/obo/SO_0000...
# 1  C0019652        HISTONES  [(HISTONE, http://purl.obolibrary.org/obo/PR_0...
# 2  C1562292       INCRETINS                                                 []
# 3                                                                           []
# 4  C0444765  HAT - HEADWEAR  [(HAT, http://purl.obolibrary.org/obo/PR_Q9M2N5)]

# %%
df_ass.to_csv('cui_to_ontology_maps/bioportal_mappings_unlinked.tsv', index=False, sep='\t')

# %%
##use correct mappings and add to bioportal_map_dict
#if no mapping found, remove triple and assume not-relevant to domain etc.
df_map = pd.read_csv('cui_to_ontology_maps/bioportal_mappings_unlinked_reviewed.tsv', sep='\t')
df_map.head()
# Out:
#         cui   original_text                                 bioportal_mappings
# 0  C0017337           GENES  GENE', 'http://purl.obolibrary.org/obo/SO_0000...
# 1  C0019652        HISTONES  HISTONE', 'http://purl.obolibrary.org/obo/PR_0...
# 2  C1562292       INCRETINS                                                NaN
# 3  C0444765  HAT - HEADWEAR   HAT', 'http://purl.obolibrary.org/obo/PR_Q9M2N5'
# 4  C2720167       SIRTUIN 1                                                NaN

# %%
df_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149 entries, 0 to 1148
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   cui                 1146 non-null   object
#  1   original_text       1146 non-null   object
#  2   bioportal_mappings  950 non-null    object
# dtypes: object(3)
# memory usage: 27.1+ KB

# %%
#remove rows with no mapping
df_map = df_map.dropna(subset = ['bioportal_mappings'])
df_map = df_map.reset_index()
df_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               950 non-null    int64
#  1   cui                 950 non-null    object
#  2   original_text       950 non-null    object
#  3   bioportal_mappings  950 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 29.8+ KB

# %%
df.head()
# Out:
#   subject_cui              subject_name                subject_source  \
# 0    C0017337                     Genes         gene encoding SERCA2a
# 1    C0017337                     Genes         gene encoding SERCA2a
# 2    C1562292                 Incretins                      incretin
# 3    C1418880                PRDX2_gene                trichostatin A
# 4    C0059438  epigallocatechin_gallate  --epigallocatechin 3-gallate
#
#      predicate object_source object_cui object_name      subj_reach_grounding  \
# 0  Acetylation    Histone_H3   C0019652    Histones              (None, None)
# 1  Acetylation    Histone_H3   C0019652    Histones              (None, None)
# 2  Acetylation  Kv  subunits                                     (None, None)
# 3  Acetylation       Tubulin   C0041348     Tubulin  ('CHEBI', 'CHEBI:46024')
# 4  Acetylation       Histone   C0019652    Histones   ('CHEBI', 'CHEBI:4806')
#
#       obj_reach_grounding      pmid  pub_year  belief  \
# 0  ('FPLX', 'Histone_H3')  30286210      2018    0.65
# 1  ('FPLX', 'Histone_H3')  30286210      2018    0.65
# 2            (None, None)  25680958  2015 Apr    0.65
# 3     ('FPLX', 'Tubulin')  25680958  2015 Apr    0.65
# 4     ('FPLX', 'Histone')  23210776      2013    0.65
#
#                                             sentence predicate_obo  \
# 0  Our data indicate that increased HDAC1 activit...    GO_0006473
# 1  Our data indicate that increased HDAC1 activit...    GO_0006473
# 2  Modification of\nchannel proteins by acetylati...    GO_0006473
# 3  It was reported that ␣-tubulin underwent\nlysi...    GO_0006473
# 4  EGCG [177] \nand  grape  seed  proanthocyanidi...    GO_0006473
#
#    subject_obo object_obo
# 0
# 1
# 2
# 3  CHEBI_46024
# 4   CHEBI_4806

# %%
df.iloc[0].subject_obo
# Out:
# ''

# %%
#key is CUI and value is OBO identifier
#increased bioportal mappings from 337 to 1287
for i in range(len(df_map.index)):
    cui = df_map.at[i, 'cui']
    mapping = df_map.at[i, 'bioportal_mappings']
    mapping_list = mapping.split(',')
    mapped_obo = mapping_list[-1].strip()
    mapped_obo = mapped_obo.replace("'", '')
    if cui not in bioportal_map_dict:
        bioportal_map_dict[cui] = mapped_obo
len(bioportal_map_dict)
# Out:
# 1287

# %%
#get bioportal mappings and add to df
def get_obo_bioportal_mapping(row, col):
    if col == 'subject':
        cui = row['subject_cui']
        mapping = row['subject_obo']
    elif col == 'object':
        cui = row['object_cui']
        mapping = row['object_obo']
    else:
        print('specify if subject or object mapping required')
        exit(0)
    if mapping == '':
        if cui in bioportal_map_dict:
            return bioportal_map_dict[cui]
    else:
        return mapping

# %%
df['subject_obo'] = df.apply(get_obo_bioportal_mapping, axis=1, col='subject')
df.head()
# Out:
#   subject_cui              subject_name                subject_source  \
# 0    C0017337                     Genes         gene encoding SERCA2a
# 1    C0017337                     Genes         gene encoding SERCA2a
# 2    C1562292                 Incretins                      incretin
# 3    C1418880                PRDX2_gene                trichostatin A
# 4    C0059438  epigallocatechin_gallate  --epigallocatechin 3-gallate
#
#      predicate object_source object_cui object_name      subj_reach_grounding  \
# 0  Acetylation    Histone_H3   C0019652    Histones              (None, None)
# 1  Acetylation    Histone_H3   C0019652    Histones              (None, None)
# 2  Acetylation  Kv  subunits                                     (None, None)
# 3  Acetylation       Tubulin   C0041348     Tubulin  ('CHEBI', 'CHEBI:46024')
# 4  Acetylation       Histone   C0019652    Histones   ('CHEBI', 'CHEBI:4806')
#
#       obj_reach_grounding      pmid  pub_year  belief  \
# 0  ('FPLX', 'Histone_H3')  30286210      2018    0.65
# 1  ('FPLX', 'Histone_H3')  30286210      2018    0.65
# 2            (None, None)  25680958  2015 Apr    0.65
# 3     ('FPLX', 'Tubulin')  25680958  2015 Apr    0.65
# 4     ('FPLX', 'Histone')  23210776      2013    0.65
#
#                                             sentence predicate_obo  \
# 0  Our data indicate that increased HDAC1 activit...    GO_0006473
# 1  Our data indicate that increased HDAC1 activit...    GO_0006473
# 2  Modification of\nchannel proteins by acetylati...    GO_0006473
# 3  It was reported that ␣-tubulin underwent\nlysi...    GO_0006473
# 4  EGCG [177] \nand  grape  seed  proanthocyanidi...    GO_0006473
#
#                                  subject_obo object_obo
# 0  http://purl.obolibrary.org/obo/SO_0000704
# 1  http://purl.obolibrary.org/obo/SO_0000704
# 2                                       None
# 3                                CHEBI_46024
# 4                                 CHEBI_4806

# %%
df['object_obo'] = df.apply(get_obo_bioportal_mapping, axis=1, col='object')
df.head()
# Out:
#   subject_cui              subject_name                subject_source  \
# 0    C0017337                     Genes         gene encoding SERCA2a
# 1    C0017337                     Genes         gene encoding SERCA2a
# 2    C1562292                 Incretins                      incretin
# 3    C1418880                PRDX2_gene                trichostatin A
# 4    C0059438  epigallocatechin_gallate  --epigallocatechin 3-gallate
#
#      predicate object_source object_cui object_name      subj_reach_grounding  \
# 0  Acetylation    Histone_H3   C0019652    Histones              (None, None)
# 1  Acetylation    Histone_H3   C0019652    Histones              (None, None)
# 2  Acetylation  Kv  subunits                                     (None, None)
# 3  Acetylation       Tubulin   C0041348     Tubulin  ('CHEBI', 'CHEBI:46024')
# 4  Acetylation       Histone   C0019652    Histones   ('CHEBI', 'CHEBI:4806')
#
#       obj_reach_grounding      pmid  pub_year  belief  \
# 0  ('FPLX', 'Histone_H3')  30286210      2018    0.65
# 1  ('FPLX', 'Histone_H3')  30286210      2018    0.65
# 2            (None, None)  25680958  2015 Apr    0.65
# 3     ('FPLX', 'Tubulin')  25680958  2015 Apr    0.65
# 4     ('FPLX', 'Histone')  23210776      2013    0.65
#
#                                             sentence predicate_obo  \
# 0  Our data indicate that increased HDAC1 activit...    GO_0006473
# 1  Our data indicate that increased HDAC1 activit...    GO_0006473
# 2  Modification of\nchannel proteins by acetylati...    GO_0006473
# 3  It was reported that ␣-tubulin underwent\nlysi...    GO_0006473
# 4  EGCG [177] \nand  grape  seed  proanthocyanidi...    GO_0006473
#
#                                  subject_obo  \
# 0  http://purl.obolibrary.org/obo/SO_0000704
# 1  http://purl.obolibrary.org/obo/SO_0000704
# 2                                       None
# 3                                CHEBI_46024
# 4                                 CHEBI_4806
#
#                                       object_obo
# 0    http://purl.obolibrary.org/obo/PR_000041244
# 1    http://purl.obolibrary.org/obo/PR_000041244
# 2                                           None
# 3  [http://purl.obolibrary.org/obo/PR_000028799]
# 4    http://purl.obolibrary.org/obo/PR_000041244

# %%
df.head(10)
# Out:
#   subject_cui              subject_name                subject_source  \
# 0    C0017337                     Genes         gene encoding SERCA2a
# 1    C0017337                     Genes         gene encoding SERCA2a
# 2    C1562292                 Incretins                      incretin
# 3    C1418880                PRDX2_gene                trichostatin A
# 4    C0059438  epigallocatechin_gallate  --epigallocatechin 3-gallate
# 5    C0073591                 rosoxacin                          ROS1
# 6    C2720167                 Sirtuin_1                         SIRT1
# 7    C2720167                 Sirtuin_1                         SIRT1
# 8    C3539643           EIF4E_wt_Allele                        CREBBP
# 9    C0444765            Hat_-_Headwear                     TMPRSS11D
#
#      predicate object_source object_cui           object_name  \
# 0  Acetylation    Histone_H3   C0019652              Histones
# 1  Acetylation    Histone_H3   C0019652              Histones
# 2  Acetylation  Kv  subunits
# 3  Acetylation       Tubulin   C0041348               Tubulin
# 4  Acetylation       Histone   C0019652              Histones
# 5  Acetylation     TMPRSS11D   C0444765        Hat_-_Headwear
# 6  Acetylation           RXR   C0140283  Retinoid_X_Receptors
# 7  Acetylation         NR1H4   C1417825            NR1H4_gene
# 8  Acetylation          RELA   C1453853   WNK1_protein,_human
# 9  Acetylation   p-NF-jB p65   C1453853   WNK1_protein,_human
#
#        subj_reach_grounding     obj_reach_grounding      pmid     pub_year  \
# 0              (None, None)  ('FPLX', 'Histone_H3')  30286210         2018
# 1              (None, None)  ('FPLX', 'Histone_H3')  30286210         2018
# 2              (None, None)            (None, None)  25680958     2015 Apr
# 3  ('CHEBI', 'CHEBI:46024')     ('FPLX', 'Tubulin')  25680958     2015 Apr
# 4   ('CHEBI', 'CHEBI:4806')     ('FPLX', 'Histone')  23210776         2013
# 5         ('HGNC', '10261')       ('HGNC', '24059')  25847253         2015
# 6         ('HGNC', '14929')         ('FPLX', 'RXR')  31661763  2019 Oct 28
# 7         ('HGNC', '14929')        ('HGNC', '7967')  31661763  2019 Oct 28
# 8          ('HGNC', '2348')        ('HGNC', '9955')  25847253         2015
# 9         ('HGNC', '24059')            (None, None)  25847253         2015
#
#    belief                                           sentence predicate_obo  \
# 0    0.65  Our data indicate that increased HDAC1 activit...    GO_0006473
# 1    0.65  Our data indicate that increased HDAC1 activit...    GO_0006473
# 2    0.65  Modification of\nchannel proteins by acetylati...    GO_0006473
# 3    0.65  It was reported that ␣-tubulin underwent\nlysi...    GO_0006473
# 4    0.65  EGCG [177] \nand  grape  seed  proanthocyanidi...    GO_0006473
# 5    0.65  Redox status exerts a great influence on the a...    GO_0006473
# 6    0.65  Resveratrol may confer its beneficial effects ...    GO_0006473
# 7    0.65  Resveratrol may confer its beneficial effects ...    GO_0006473
# 8    0.86  p-NF-jB p65 that is acetylated on lysine resid...    GO_0006473
# 9    0.65  p-NF-jB p65 binds to CREB-binding protein (CBP...    GO_0006473
#
#                                      subject_obo  \
# 0      http://purl.obolibrary.org/obo/SO_0000704
# 1      http://purl.obolibrary.org/obo/SO_0000704
# 2                                           None
# 3                                    CHEBI_46024
# 4                                     CHEBI_4806
# 5  [http://purl.obolibrary.org/obo/CHEBI_131715]
# 6                                           None
# 7                                           None
# 8       http://purl.obolibrary.org/obo/PR_P63074
# 9       http://purl.obolibrary.org/obo/PR_Q9M2N5
#
#                                       object_obo
# 0    http://purl.obolibrary.org/obo/PR_000041244
# 1    http://purl.obolibrary.org/obo/PR_000041244
# 2                                           None
# 3  [http://purl.obolibrary.org/obo/PR_000028799]
# 4    http://purl.obolibrary.org/obo/PR_000041244
# 5       http://purl.obolibrary.org/obo/PR_Q9M2N5
# 6     http://purl.obolibrary.org/obo/CHEBI_26537
# 7       http://purl.obolibrary.org/obo/PR_Q96RI1
# 8    http://purl.obolibrary.org/obo/PR_000017431
# 9    http://purl.obolibrary.org/obo/PR_000017431

# %%
def add_prefix(row, col):
    obo_prefix = 'http://purl.obolibrary.org/obo/'
    if col == 'predicate':
        predicate_obo = row['predicate_obo']
        return obo_prefix+predicate_obo
    elif col == 'subject':
        subject_obo = row['subject_obo']
        if isinstance(subject_obo, list) and subject_obo:
            subject_obo = subject_obo[0]
        if subject_obo == None:
            return ''
        subject_obo = subject_obo.replace(']', '')
        subject_obo = subject_obo.replace('[', '')
        subject_obo = subject_obo.replace(')', '')
        subject_obo = subject_obo.replace('(', '')
        if 'http' not in subject_obo:
            return obo_prefix+subject_obo
        else:
            return subject_obo
    elif col == 'object':
        object_obo = row['object_obo']
        if isinstance(object_obo, list) and object_obo:
            object_obo = object_obo[0]
        if object_obo == None:
            return ''
        object_obo = object_obo.replace(']', '')
        object_obo = object_obo.replace('[', '')
        object_obo = object_obo.replace(')', '')
        object_obo = object_obo.replace('(', '')
        if 'http' not in object_obo:
            return obo_prefix+object_obo
        else:
            return object_obo

# %%
#add OBO identifiers to the OBO mappings (where not present) - see df
#drop rows with no mappings
df['subject_obo'] = df.apply(add_prefix, axis=1, col='subject')
df['object_obo'] = df.apply(add_prefix, axis=1, col='object')
df['predicate_obo'] = df.apply(add_prefix, axis=1, col='predicate')

# %%
df.head(20)
# Out:
#    subject_cui              subject_name                     subject_source  \
# 0     C0017337                     Genes              gene encoding SERCA2a
# 1     C0017337                     Genes              gene encoding SERCA2a
# 2     C1562292                 Incretins                           incretin
# 3     C1418880                PRDX2_gene                     trichostatin A
# 4     C0059438  epigallocatechin_gallate       --epigallocatechin 3-gallate
# 5     C0073591                 rosoxacin                               ROS1
# 6     C2720167                 Sirtuin_1                              SIRT1
# 7     C2720167                 Sirtuin_1                              SIRT1
# 8     C3539643           EIF4E_wt_Allele                             CREBBP
# 9     C0444765            Hat_-_Headwear                          TMPRSS11D
# 10    C1530358      EP300_protein,_human                              EP300
# 11    C1567357     ATP2A2_protein,_human                             ATP2A2
# 12    C1567357     ATP2A2_protein,_human                             ATP2A2
# 13    C4053566       Juan_de_Nova_Island                               + QU
# 14                                                              ++ ++ ++ ++
# 15    C0016327                 Fluorides  ., Marasciulo, F. L.,\nMontagnani
# 16    C0016327                 Fluorides  ., Marasciulo, F. L.,\nMontagnani
# 17    C0030016            Oxidoreductase                  11bHSD1 reductase
# 18    C0030016            Oxidoreductase                  11bHSD1 reductase
# 19                                                                  11bHSD1
#
#       predicate object_source object_cui           object_name  \
# 0   Acetylation    Histone_H3   C0019652              Histones
# 1   Acetylation    Histone_H3   C0019652              Histones
# 2   Acetylation  Kv  subunits
# 3   Acetylation       Tubulin   C0041348               Tubulin
# 4   Acetylation       Histone   C0019652              Histones
# 5   Acetylation     TMPRSS11D   C0444765        Hat_-_Headwear
# 6   Acetylation           RXR   C0140283  Retinoid_X_Receptors
# 7   Acetylation         NR1H4   C1417825            NR1H4_gene
# 8   Acetylation          RELA   C1453853   WNK1_protein,_human
# 9   Acetylation   p-NF-jB p65   C1453853   WNK1_protein,_human
# 10  Acetylation          RELA   C1453853   WNK1_protein,_human
# 11  Acetylation    Histone_H3   C0019652              Histones
# 12  Acetylation    Histone_H3   C0019652              Histones
# 13   Activation           ing
# 14   Activation      NFkappaB   C0079904            NF-kappa_B
# 15   Activation  nitric oxide   C0028128          Nitric_Oxide
# 16   Activation  vasodilation   C0042401          Vasodilation
# 17   Activation           INS   C0021641               Insulin
# 18   Activation          Mice   C0026809                   Mus
# 19   Activation         NADPH   C0027303                  NADP
#
#         subj_reach_grounding       obj_reach_grounding      pmid  \
# 0               (None, None)    ('FPLX', 'Histone_H3')  30286210
# 1               (None, None)    ('FPLX', 'Histone_H3')  30286210
# 2               (None, None)              (None, None)  25680958
# 3   ('CHEBI', 'CHEBI:46024')       ('FPLX', 'Tubulin')  25680958
# 4    ('CHEBI', 'CHEBI:4806')       ('FPLX', 'Histone')  23210776
# 5          ('HGNC', '10261')         ('HGNC', '24059')  25847253
# 6          ('HGNC', '14929')           ('FPLX', 'RXR')  31661763
# 7          ('HGNC', '14929')          ('HGNC', '7967')  31661763
# 8           ('HGNC', '2348')          ('HGNC', '9955')  25847253
# 9          ('HGNC', '24059')              (None, None)  25847253
# 10          ('HGNC', '3373')          ('HGNC', '9955')  25847253
# 11           ('HGNC', '812')    ('FPLX', 'Histone_H3')  30286210
# 12           ('HGNC', '812')    ('FPLX', 'Histone_H3')  30286210
# 13              (None, None)              (None, None)  25813735
# 14              (None, None)      ('FPLX', 'NFkappaB')  16887864
# 15              (None, None)  ('CHEBI', 'CHEBI:16480')  30513192
# 16              (None, None)      ('GO', 'GO:0042311')  30513192
# 17              (None, None)          ('HGNC', '6081')  23554216
# 18              (None, None)       ('MESH', 'D051379')  23554216
# 19              (None, None)  ('CHEBI', 'CHEBI:16474')  23554216
#
#         pub_year  belief                                           sentence  \
# 0           2018    0.65  Our data indicate that increased HDAC1 activit...
# 1           2018    0.65  Our data indicate that increased HDAC1 activit...
# 2       2015 Apr    0.65  Modification of\nchannel proteins by acetylati...
# 3       2015 Apr    0.65  It was reported that ␣-tubulin underwent\nlysi...
# 4           2013    0.65  EGCG [177] \nand  grape  seed  proanthocyanidi...
# 5           2015    0.65  Redox status exerts a great influence on the a...
# 6    2019 Oct 28    0.65  Resveratrol may confer its beneficial effects ...
# 7    2019 Oct 28    0.65  Resveratrol may confer its beneficial effects ...
# 8           2015    0.86  p-NF-jB p65 that is acetylated on lysine resid...
# 9           2015    0.65  p-NF-jB p65 binds to CREB-binding protein (CBP...
# 10          2015    0.86  p-NF-jB p65 that is acetylated on lysine resid...
# 11          2018    0.65  Our data indicate that increased HDAC1 activit...
# 12          2018    0.65  Our data indicate that increased HDAC1 activit...
# 13   2015 Jun 20    0.65  In Fig. 1, it can also be observed that the ef...
# 14      2007 Jan    0.65  Modulation of Ca++ fluxes and colon carcinogen...
# 15   2019 Jan 16    0.65  A., Marasciulo, F. L.,\nMontagnani, M., and Qu...
# 16   2019 Jan 16    0.65  A., Marasciulo, F. L.,\nMontagnani, M., and Qu...
# 17  2013 Sep-Oct    0.65  Lack of 11bHSD1 reductase activity and increas...
# 18  2013 Sep-Oct    0.65  Lack of 11bHSD1 reductase activity and increas...
# 19  2013 Sep-Oct    0.65  The linear increment of the ﬂuorescent signal ...
#
#                                 predicate_obo  \
# 0   http://purl.obolibrary.org/obo/GO_0006473
# 1   http://purl.obolibrary.org/obo/GO_0006473
# 2   http://purl.obolibrary.org/obo/GO_0006473
# 3   http://purl.obolibrary.org/obo/GO_0006473
# 4   http://purl.obolibrary.org/obo/GO_0006473
# 5   http://purl.obolibrary.org/obo/GO_0006473
# 6   http://purl.obolibrary.org/obo/GO_0006473
# 7   http://purl.obolibrary.org/obo/GO_0006473
# 8   http://purl.obolibrary.org/obo/GO_0006473
# 9   http://purl.obolibrary.org/obo/GO_0006473
# 10  http://purl.obolibrary.org/obo/GO_0006473
# 11  http://purl.obolibrary.org/obo/GO_0006473
# 12  http://purl.obolibrary.org/obo/GO_0006473
# 13  http://purl.obolibrary.org/obo/RO_0002436
# 14  http://purl.obolibrary.org/obo/RO_0002436
# 15  http://purl.obolibrary.org/obo/RO_0002436
# 16  http://purl.obolibrary.org/obo/RO_0002436
# 17  http://purl.obolibrary.org/obo/RO_0002436
# 18  http://purl.obolibrary.org/obo/RO_0002436
# 19  http://purl.obolibrary.org/obo/RO_0002436
#
#                                     subject_obo  \
# 0     http://purl.obolibrary.org/obo/SO_0000704
# 1     http://purl.obolibrary.org/obo/SO_0000704
# 2
# 3    http://purl.obolibrary.org/obo/CHEBI_46024
# 4     http://purl.obolibrary.org/obo/CHEBI_4806
# 5   http://purl.obolibrary.org/obo/CHEBI_131715
# 6
# 7
# 8      http://purl.obolibrary.org/obo/PR_P63074
# 9      http://purl.obolibrary.org/obo/PR_Q9M2N5
# 10  http://purl.obolibrary.org/obo/PR_000007102
# 11     http://purl.obolibrary.org/obo/PR_O55143
# 12     http://purl.obolibrary.org/obo/PR_O55143
# 13   http://purl.obolibrary.org/obo/CHEBI_75281
# 14
# 15   http://purl.obolibrary.org/obo/CHEBI_24060
# 16   http://purl.obolibrary.org/obo/CHEBI_24060
# 17     http://purl.obolibrary.org/obo/PR_Q9SEV0
# 18     http://purl.obolibrary.org/obo/PR_Q9SEV0
# 19
#
#                                         object_obo
# 0      http://purl.obolibrary.org/obo/PR_000041244
# 1      http://purl.obolibrary.org/obo/PR_000041244
# 2
# 3      http://purl.obolibrary.org/obo/PR_000028799
# 4      http://purl.obolibrary.org/obo/PR_000041244
# 5         http://purl.obolibrary.org/obo/PR_Q9M2N5
# 6       http://purl.obolibrary.org/obo/CHEBI_26537
# 7         http://purl.obolibrary.org/obo/PR_Q96RI1
# 8      http://purl.obolibrary.org/obo/PR_000017431
# 9      http://purl.obolibrary.org/obo/PR_000017431
# 10     http://purl.obolibrary.org/obo/PR_000017431
# 11     http://purl.obolibrary.org/obo/PR_000041244
# 12     http://purl.obolibrary.org/obo/PR_000041244
# 13
# 14
# 15      http://purl.obolibrary.org/obo/CHEBI_16480
# 16       http://purl.obolibrary.org/obo/GO_0042311
# 17       http://purl.obolibrary.org/obo/CHEBI_5931
# 18  http://purl.obolibrary.org/obo/NCBITaxon_10088
# 19      http://purl.obolibrary.org/obo/CHEBI_18009

# %%
obo_prefix = 'http://purl.obolibrary.org/obo/'

# %%
#remove all rows with blank obo mappings and only prefix rows
df_new = df[df['subject_obo'] != '']
df_new = df_new[df_new['subject_obo'] != obo_prefix]
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9548 entries, 0 to 11798
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   subject_cui           9548 non-null   object
#  1   subject_name          9548 non-null   object
#  2   subject_source        9548 non-null   object
#  3   predicate             9548 non-null   object
#  4   object_source         9548 non-null   object
#  5   object_cui            9548 non-null   object
#  6   object_name           9548 non-null   object
#  7   subj_reach_grounding  9548 non-null   object
#  8   obj_reach_grounding   9548 non-null   object
#  9   pmid                  9548 non-null   int64
#  10  pub_year              9548 non-null   object
#  11  belief                9548 non-null   float64
#  12  sentence              9548 non-null   object
#  13  predicate_obo         9548 non-null   object
#  14  subject_obo           9548 non-null   object
#  15  object_obo            9548 non-null   object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 1.2+ MB

# %%
df_new = df_new[df_new['object_obo'] != '']
df_new = df_new[df_new['object_obo'] != obo_prefix]
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7697 entries, 0 to 11798
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   subject_cui           7697 non-null   object
#  1   subject_name          7697 non-null   object
#  2   subject_source        7697 non-null   object
#  3   predicate             7697 non-null   object
#  4   object_source         7697 non-null   object
#  5   object_cui            7697 non-null   object
#  6   object_name           7697 non-null   object
#  7   subj_reach_grounding  7697 non-null   object
#  8   obj_reach_grounding   7697 non-null   object
#  9   pmid                  7697 non-null   int64
#  10  pub_year              7697 non-null   object
#  11  belief                7697 non-null   float64
#  12  sentence              7697 non-null   object
#  13  predicate_obo         7697 non-null   object
#  14  subject_obo           7697 non-null   object
#  15  object_obo            7697 non-null   object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 1022.3+ KB

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7697 entries, 0 to 11798
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   subject_cui           7697 non-null   object
#  1   subject_name          7697 non-null   object
#  2   subject_source        7697 non-null   object
#  3   predicate             7697 non-null   object
#  4   object_source         7697 non-null   object
#  5   object_cui            7697 non-null   object
#  6   object_name           7697 non-null   object
#  7   subj_reach_grounding  7697 non-null   object
#  8   obj_reach_grounding   7697 non-null   object
#  9   pmid                  7697 non-null   int64
#  10  pub_year              7697 non-null   object
#  11  belief                7697 non-null   float64
#  12  sentence              7697 non-null   object
#  13  predicate_obo         7697 non-null   object
#  14  subject_obo           7697 non-null   object
#  15  object_obo            7697 non-null   object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 1022.3+ KB

# %%
df_new = df_new.drop_duplicates()
df_new.head()
# Out:
#   subject_cui              subject_name                subject_source  \
# 0    C0017337                     Genes         gene encoding SERCA2a
# 3    C1418880                PRDX2_gene                trichostatin A
# 4    C0059438  epigallocatechin_gallate  --epigallocatechin 3-gallate
# 5    C0073591                 rosoxacin                          ROS1
# 8    C3539643           EIF4E_wt_Allele                        CREBBP
#
#      predicate object_source object_cui          object_name  \
# 0  Acetylation    Histone_H3   C0019652             Histones
# 3  Acetylation       Tubulin   C0041348              Tubulin
# 4  Acetylation       Histone   C0019652             Histones
# 5  Acetylation     TMPRSS11D   C0444765       Hat_-_Headwear
# 8  Acetylation          RELA   C1453853  WNK1_protein,_human
#
#        subj_reach_grounding     obj_reach_grounding      pmid  pub_year  \
# 0              (None, None)  ('FPLX', 'Histone_H3')  30286210      2018
# 3  ('CHEBI', 'CHEBI:46024')     ('FPLX', 'Tubulin')  25680958  2015 Apr
# 4   ('CHEBI', 'CHEBI:4806')     ('FPLX', 'Histone')  23210776      2013
# 5         ('HGNC', '10261')       ('HGNC', '24059')  25847253      2015
# 8          ('HGNC', '2348')        ('HGNC', '9955')  25847253      2015
#
#    belief                                           sentence  \
# 0    0.65  Our data indicate that increased HDAC1 activit...
# 3    0.65  It was reported that ␣-tubulin underwent\nlysi...
# 4    0.65  EGCG [177] \nand  grape  seed  proanthocyanidi...
# 5    0.65  Redox status exerts a great influence on the a...
# 8    0.86  p-NF-jB p65 that is acetylated on lysine resid...
#
#                                predicate_obo  \
# 0  http://purl.obolibrary.org/obo/GO_0006473
# 3  http://purl.obolibrary.org/obo/GO_0006473
# 4  http://purl.obolibrary.org/obo/GO_0006473
# 5  http://purl.obolibrary.org/obo/GO_0006473
# 8  http://purl.obolibrary.org/obo/GO_0006473
#
#                                    subject_obo  \
# 0    http://purl.obolibrary.org/obo/SO_0000704
# 3   http://purl.obolibrary.org/obo/CHEBI_46024
# 4    http://purl.obolibrary.org/obo/CHEBI_4806
# 5  http://purl.obolibrary.org/obo/CHEBI_131715
# 8     http://purl.obolibrary.org/obo/PR_P63074
#
#                                     object_obo
# 0  http://purl.obolibrary.org/obo/PR_000041244
# 3  http://purl.obolibrary.org/obo/PR_000028799
# 4  http://purl.obolibrary.org/obo/PR_000041244
# 5     http://purl.obolibrary.org/obo/PR_Q9M2N5
# 8  http://purl.obolibrary.org/obo/PR_000017431

# %%
df_new = df_new.reset_index(drop=True)
df_new.head()
# Out:
#   subject_cui              subject_name                subject_source  \
# 0    C0017337                     Genes         gene encoding SERCA2a
# 1    C1418880                PRDX2_gene                trichostatin A
# 2    C0059438  epigallocatechin_gallate  --epigallocatechin 3-gallate
# 3    C0073591                 rosoxacin                          ROS1
# 4    C3539643           EIF4E_wt_Allele                        CREBBP
#
#      predicate object_source object_cui          object_name  \
# 0  Acetylation    Histone_H3   C0019652             Histones
# 1  Acetylation       Tubulin   C0041348              Tubulin
# 2  Acetylation       Histone   C0019652             Histones
# 3  Acetylation     TMPRSS11D   C0444765       Hat_-_Headwear
# 4  Acetylation          RELA   C1453853  WNK1_protein,_human
#
#        subj_reach_grounding     obj_reach_grounding      pmid  pub_year  \
# 0              (None, None)  ('FPLX', 'Histone_H3')  30286210      2018
# 1  ('CHEBI', 'CHEBI:46024')     ('FPLX', 'Tubulin')  25680958  2015 Apr
# 2   ('CHEBI', 'CHEBI:4806')     ('FPLX', 'Histone')  23210776      2013
# 3         ('HGNC', '10261')       ('HGNC', '24059')  25847253      2015
# 4          ('HGNC', '2348')        ('HGNC', '9955')  25847253      2015
#
#    belief                                           sentence  \
# 0    0.65  Our data indicate that increased HDAC1 activit...
# 1    0.65  It was reported that ␣-tubulin underwent\nlysi...
# 2    0.65  EGCG [177] \nand  grape  seed  proanthocyanidi...
# 3    0.65  Redox status exerts a great influence on the a...
# 4    0.86  p-NF-jB p65 that is acetylated on lysine resid...
#
#                                predicate_obo  \
# 0  http://purl.obolibrary.org/obo/GO_0006473
# 1  http://purl.obolibrary.org/obo/GO_0006473
# 2  http://purl.obolibrary.org/obo/GO_0006473
# 3  http://purl.obolibrary.org/obo/GO_0006473
# 4  http://purl.obolibrary.org/obo/GO_0006473
#
#                                    subject_obo  \
# 0    http://purl.obolibrary.org/obo/SO_0000704
# 1   http://purl.obolibrary.org/obo/CHEBI_46024
# 2    http://purl.obolibrary.org/obo/CHEBI_4806
# 3  http://purl.obolibrary.org/obo/CHEBI_131715
# 4     http://purl.obolibrary.org/obo/PR_P63074
#
#                                     object_obo
# 0  http://purl.obolibrary.org/obo/PR_000041244
# 1  http://purl.obolibrary.org/obo/PR_000028799
# 2  http://purl.obolibrary.org/obo/PR_000041244
# 3     http://purl.obolibrary.org/obo/PR_Q9M2N5
# 4  http://purl.obolibrary.org/obo/PR_000017431

# %%
#fix mapping for Tea - map to SRS camellia sinensis not triethylamine
tea_map = 'http://napdi.org/napdi-srs-imports:camellia_sinensis_leaf'
for i in range(len(df_new.index)):
    subj = df_new.at[i, 'subject_name']
    obj = df_new.at[i, 'object_name']
    if subj == 'Tea':
        df_new.at[i, 'subject_obo'] = tea_map
    if obj == 'Tea':
        df_new.at[i, 'object_obo'] = tea_map

# %%
df_new.head()
# Out:
#   subject_cui              subject_name                subject_source  \
# 0    C0017337                     Genes         gene encoding SERCA2a
# 1    C1418880                PRDX2_gene                trichostatin A
# 2    C0059438  epigallocatechin_gallate  --epigallocatechin 3-gallate
# 3    C0073591                 rosoxacin                          ROS1
# 4    C3539643           EIF4E_wt_Allele                        CREBBP
#
#      predicate object_source object_cui          object_name  \
# 0  Acetylation    Histone_H3   C0019652             Histones
# 1  Acetylation       Tubulin   C0041348              Tubulin
# 2  Acetylation       Histone   C0019652             Histones
# 3  Acetylation     TMPRSS11D   C0444765       Hat_-_Headwear
# 4  Acetylation          RELA   C1453853  WNK1_protein,_human
#
#        subj_reach_grounding     obj_reach_grounding      pmid  pub_year  \
# 0              (None, None)  ('FPLX', 'Histone_H3')  30286210      2018
# 1  ('CHEBI', 'CHEBI:46024')     ('FPLX', 'Tubulin')  25680958  2015 Apr
# 2   ('CHEBI', 'CHEBI:4806')     ('FPLX', 'Histone')  23210776      2013
# 3         ('HGNC', '10261')       ('HGNC', '24059')  25847253      2015
# 4          ('HGNC', '2348')        ('HGNC', '9955')  25847253      2015
#
#    belief                                           sentence  \
# 0    0.65  Our data indicate that increased HDAC1 activit...
# 1    0.65  It was reported that ␣-tubulin underwent\nlysi...
# 2    0.65  EGCG [177] \nand  grape  seed  proanthocyanidi...
# 3    0.65  Redox status exerts a great influence on the a...
# 4    0.86  p-NF-jB p65 that is acetylated on lysine resid...
#
#                                predicate_obo  \
# 0  http://purl.obolibrary.org/obo/GO_0006473
# 1  http://purl.obolibrary.org/obo/GO_0006473
# 2  http://purl.obolibrary.org/obo/GO_0006473
# 3  http://purl.obolibrary.org/obo/GO_0006473
# 4  http://purl.obolibrary.org/obo/GO_0006473
#
#                                    subject_obo  \
# 0    http://purl.obolibrary.org/obo/SO_0000704
# 1   http://purl.obolibrary.org/obo/CHEBI_46024
# 2    http://purl.obolibrary.org/obo/CHEBI_4806
# 3  http://purl.obolibrary.org/obo/CHEBI_131715
# 4     http://purl.obolibrary.org/obo/PR_P63074
#
#                                     object_obo
# 0  http://purl.obolibrary.org/obo/PR_000041244
# 1  http://purl.obolibrary.org/obo/PR_000028799
# 2  http://purl.obolibrary.org/obo/PR_000041244
# 3     http://purl.obolibrary.org/obo/PR_Q9M2N5
# 4  http://purl.obolibrary.org/obo/PR_000017431

# %%
#save all mapping dict and labels as node labels file --use the dictionaries or the dataframe
#(go_hpo, bioportal, predmap, )
df_new.to_csv('predication_files/greentea_pmid_all_predicates_umls_processed.tsv', sep='\t', index=False)

# %%
import pandas as pd
df = pd.read_csv('predication_files/greentea_pmid_all_predicates_umls_processed.tsv', sep='\t')
dft = pd.read_csv('predication_files/greentea_pmid_all_predicates_umls_processed_triples.tsv', sep='\t')

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7678 entries, 0 to 7677
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   subject_obo    7678 non-null   object
#  1   predicate_obo  7678 non-null   object
#  2   object_obo     7678 non-null   object
# dtypes: object(3)
# memory usage: 180.1+ KB

# %%
#Create networkx graph from triples
import glob
import hashlib
import json
import networkx as nx  # type: ignore
import os
import os.path

from collections import Counter  # type: ignore
from more_itertools import unique_everseen  # type: ignore
from rdflib import BNode, Graph, Literal, Namespace, URIRef  # type: ignore
from rdflib.namespace import OWL, RDF, RDFS  # type: ignore
from rdflib.plugins.serializers.nt import _quoteLiteral  # type: ignore
import subprocess

from tqdm import tqdm  # type: ignore
from typing import Dict, List, Optional, Set, Tuple, Union

# set-up environment variables
obo = Namespace('http://purl.obolibrary.org/obo/')
oboinowl = Namespace('http://www.geneontology.org/formats/oboInOwl#')
schema = Namespace('http://www.w3.org/2001/XMLSchema#')
napdi = Namespace('http://napdi.org/napdi-srs-imports:')

# %%
dfres = df_new[['subject_obo', 'predicate_obo', 'object_obo']]
dfres.head()
# Out:
#                                    subject_obo  \
# 0    http://purl.obolibrary.org/obo/SO_0000704
# 1   http://purl.obolibrary.org/obo/CHEBI_46024
# 2    http://purl.obolibrary.org/obo/CHEBI_4806
# 3  http://purl.obolibrary.org/obo/CHEBI_131715
# 4     http://purl.obolibrary.org/obo/PR_P63074
#
#                                predicate_obo  \
# 0  http://purl.obolibrary.org/obo/GO_0006473
# 1  http://purl.obolibrary.org/obo/GO_0006473
# 2  http://purl.obolibrary.org/obo/GO_0006473
# 3  http://purl.obolibrary.org/obo/GO_0006473
# 4  http://purl.obolibrary.org/obo/GO_0006473
#
#                                     object_obo
# 0  http://purl.obolibrary.org/obo/PR_000041244
# 1  http://purl.obolibrary.org/obo/PR_000028799
# 2  http://purl.obolibrary.org/obo/PR_000041244
# 3     http://purl.obolibrary.org/obo/PR_Q9M2N5
# 4  http://purl.obolibrary.org/obo/PR_000017431

# %%
dfres.to_csv('predication_files/greentea_pmid_all_predicates_umls_processed_triples.tsv', sep='\t', index=False)

# %%
URIRef(dfres.iloc[0]['subject_obo'])
# Out:
# rdflib.term.URIRef('http://purl.obolibrary.org/obo/SO_0000704')

# %%
##TODO - take OBO label instead of UMLS preferred name in future

# %%
#create rdflib graph from dataframe triples and serialize as ntriples file
graph  = Graph()
pred_label = URIRef("http://www.w3.org/2000/01/rdf-schema#label")
for i in range(len(df_new.index)):
    subj = df_new.at[i, 'subject_obo']
    obj = df_new.at[i, 'object_obo']
    pred = df_new.at[i, 'predicate_obo']
    subj_node = URIRef(subj)
    obj_node = URIRef(obj)
    predicate = URIRef(pred)
    subj_name = df_new.at[i, 'subject_name']
    obj_name = df_new.at[i, 'object_name']
    graph.add((subj_node, predicate, obj_node))
    graph.add((subj_node, pred_label, Literal(subj_name)))
    graph.add((obj_node, pred_label, Literal(obj_name)))

# %%
graph.serialize('output_graphs/machineread_greentea_version2.nt', format='nt')

# %%
def n3(node: Union[URIRef, BNode, Literal]) -> str:
    """Method takes an RDFLib node of type BNode, URIRef, or Literal and serializes it to meet the RDF 1.1 NTriples
    format.
    Src: https://github.com/RDFLib/rdflib/blob/c11f7b503b50b7c3cdeec0f36261fa09b0615380/rdflib/plugins/serializers/nt.py
    Args:
        node: An RDFLib
    Returns:
        serialized_node: A string containing the serialized
    """
    if isinstance(node, Literal): serialized_node = "%s" % _quoteLiteral(node)
    else: serialized_node = "%s" % node.n3()
    return serialized_node

# %%
for s,p,o in tqdm(graph):
    x = str(s)
    y = str(p)
    z = str(o)
    break
# Out:
#   0%|          | 0/9603 [00:00<?, ?it/s]

# %%
df_new.head()
# Out:
#   subject_cui              subject_name                subject_source  \
# 0    C0017337                     Genes         gene encoding SERCA2a
# 1    C1418880                PRDX2_gene                trichostatin A
# 2    C0059438  epigallocatechin_gallate  --epigallocatechin 3-gallate
# 3    C0073591                 rosoxacin                          ROS1
# 4    C3539643           EIF4E_wt_Allele                        CREBBP
#
#      predicate object_source object_cui          object_name  \
# 0  Acetylation    Histone_H3   C0019652             Histones
# 1  Acetylation       Tubulin   C0041348              Tubulin
# 2  Acetylation       Histone   C0019652             Histones
# 3  Acetylation     TMPRSS11D   C0444765       Hat_-_Headwear
# 4  Acetylation          RELA   C1453853  WNK1_protein,_human
#
#        subj_reach_grounding     obj_reach_grounding      pmid  pub_year  \
# 0              (None, None)  ('FPLX', 'Histone_H3')  30286210      2018
# 1  ('CHEBI', 'CHEBI:46024')     ('FPLX', 'Tubulin')  25680958  2015 Apr
# 2   ('CHEBI', 'CHEBI:4806')     ('FPLX', 'Histone')  23210776      2013
# 3         ('HGNC', '10261')       ('HGNC', '24059')  25847253      2015
# 4          ('HGNC', '2348')        ('HGNC', '9955')  25847253      2015
#
#    belief                              predicate_obo  \
# 0    0.65  http://purl.obolibrary.org/obo/GO_0006473
# 1    0.65  http://purl.obolibrary.org/obo/GO_0006473
# 2    0.65  http://purl.obolibrary.org/obo/GO_0006473
# 3    0.65  http://purl.obolibrary.org/obo/GO_0006473
# 4    0.86  http://purl.obolibrary.org/obo/GO_0006473
#
#                                    subject_obo  \
# 0    http://purl.obolibrary.org/obo/SO_0000704
# 1   http://purl.obolibrary.org/obo/CHEBI_46024
# 2    http://purl.obolibrary.org/obo/CHEBI_4806
# 3  http://purl.obolibrary.org/obo/CHEBI_131715
# 4     http://purl.obolibrary.org/obo/PR_P63074
#
#                                     object_obo
# 0  http://purl.obolibrary.org/obo/PR_000041244
# 1  http://purl.obolibrary.org/obo/PR_000028799
# 2  http://purl.obolibrary.org/obo/PR_000041244
# 3     http://purl.obolibrary.org/obo/PR_Q9M2N5
# 4  http://purl.obolibrary.org/obo/PR_000017431

# %%
x = 'http://purl.obolibrary.org/obo/SO_0000704'
y = 'http://purl.obolibrary.org/obo/GO_0006473'
z = 'http://purl.obolibrary.org/obo/PR_000041244'

# %%
df_new.loc[(df_new['subject_obo'] == x) & (df_new['object_obo'] == z)  & (df_new['predicate_obo'] == y)]
# Out:
#   subject_cui subject_name         subject_source    predicate object_source  \
# 0    C0017337        Genes  gene encoding SERCA2a  Acetylation    Histone_H3
#
#   object_cui object_name subj_reach_grounding     obj_reach_grounding  \
# 0   C0019652    Histones         (None, None)  ('FPLX', 'Histone_H3')
#
#        pmid pub_year  belief                              predicate_obo  \
# 0  30286210     2018    0.65  http://purl.obolibrary.org/obo/GO_0006473
#
#                                  subject_obo  \
# 0  http://purl.obolibrary.org/obo/SO_0000704
#
#                                     object_obo
# 0  http://purl.obolibrary.org/obo/PR_000041244

# %%
df_new.loc[(df_new['subject_obo'] == x) & (df_new['object_obo'] == z)  & 
                               (df_new['predicate_obo'] == y)]['belief'].values[0]
# Out:
# 0.65

# %%
#convert rdflib graph to multidigraph - code borrowed from PheKnowLator: kg_utils.py
#use the pred key to also create a dictionary with metadata about the edge - 
#pub_year, pmid, source graph, belief
nx_mdg = nx.MultiDiGraph()
for s, p, o in tqdm(graph):
    #do not save label predicate to gpickle
    subj = str(s)
    obj = str(o)
    pred = str(p)
    if pred == 'http://www.w3.org/2000/01/rdf-schema#label':
        continue
    pred_key = hashlib.md5('{}{}{}'.format(n3(s), n3(p), n3(o)).encode()).hexdigest()
    
    pmid = str(df_new.loc[(df_new['subject_obo'] == subj) & (df_new['object_obo'] == obj)  & 
                   (df_new['predicate_obo'] == pred)]['pmid'].values[0])
    timestamp = str(df_new.loc[(df_new['subject_obo'] == subj) & (df_new['object_obo'] == obj)  & 
                               (df_new['predicate_obo'] == pred)]['pub_year'].values[0])
    belief_score = df_new.loc[(df_new['subject_obo'] == subj) & (df_new['object_obo'] == obj)  & 
                               (df_new['predicate_obo'] == pred)]['belief'].values[0]
    nx_mdg.add_node(s, key=n3(s))
    nx_mdg.add_node(o, key=n3(o))
    nx_mdg.add_edge(s, o, **{'key': p, 'predicate_key': pred_key, 'weight':0.0,
                             'pmid': pmid, 'timestamp': timestamp, 'source_graph': 'machine_read',
                            'belief': belief_score})
nx.write_gpickle(nx_mdg, "output_graphs/machineread_greentea_version2.gpickle")
# Out:
# 100%|██████████| 9603/9603 [01:18<00:00, 122.77it/s]

# %%
triples = len(graph)
nodes = len(set(list(graph.subjects()) + list(graph.objects())))
rels = len(set(list(graph.predicates())))
print(triples, nodes, rels)
# Out:
# 9603 4247 14

# %%
#this should have less edges than rdflib graph after removing 'labels'
nodes = nx.number_of_nodes(nx_mdg)
edges = nx.number_of_edges(nx_mdg)
density = nx.density(nx_mdg)
avg_deg = float(edges)/nodes
print(nodes, edges, density, avg_deg)
# Out:
# 2009 7365 0.0018256986984862937 3.666002986560478

# %%
#figure out how to extract information from saved gpickle predicate dictionary - pmid,

# %%
NV = nx_mdg.nodes()
i = 0
for (k,v) in NV.items():
    if i==20:
        break
    print('{}:{}'.format(k,v))
    i=i+1
# Out:
# http://purl.obolibrary.org/obo/CHEBI_33348:{'key': '<http://purl.obolibrary.org/obo/CHEBI_33348>'}
# http://purl.obolibrary.org/obo/PR_000004078:{'key': '<http://purl.obolibrary.org/obo/PR_000004078>'}
# http://purl.obolibrary.org/obo/CHEBI_72544:{'key': '<http://purl.obolibrary.org/obo/CHEBI_72544>'}
# http://purl.obolibrary.org/obo/CHEBI_17489:{'key': '<http://purl.obolibrary.org/obo/CHEBI_17489>'}
# http://purl.obolibrary.org/obo/CHEBI_4806:{'key': '<http://purl.obolibrary.org/obo/CHEBI_4806>'}
# http://purl.obolibrary.org/obo/PR_000001471:{'key': '<http://purl.obolibrary.org/obo/PR_000001471>'}
# http://purl.obolibrary.org/obo/CHEBI_16236:{'key': '<http://purl.obolibrary.org/obo/CHEBI_16236>'}
# http://purl.obolibrary.org/obo/PR_Q9SIY3:{'key': '<http://purl.obolibrary.org/obo/PR_Q9SIY3>'}
# http://purl.obolibrary.org/obo/PR_Q8WXI4:{'key': '<http://purl.obolibrary.org/obo/PR_Q8WXI4>'}
# http://purl.obolibrary.org/obo/GO_0005490:{'key': '<http://purl.obolibrary.org/obo/GO_0005490>'}
# http://purl.obolibrary.org/obo/GO_0005243:{'key': '<http://purl.obolibrary.org/obo/GO_0005243>'}
# http://purl.obolibrary.org/obo/PR_000007009:{'key': '<http://purl.obolibrary.org/obo/PR_000007009>'}
# http://purl.obolibrary.org/obo/CHEBI_4056:{'key': '<http://purl.obolibrary.org/obo/CHEBI_4056>'}
# http://purl.obolibrary.org/obo/CHEBI_11909:{'key': '<http://purl.obolibrary.org/obo/CHEBI_11909>'}
# http://purl.obolibrary.org/obo/CHEBI_16865:{'key': '<http://purl.obolibrary.org/obo/CHEBI_16865>'}
# http://purl.obolibrary.org/obo/PR_P40630:{'key': '<http://purl.obolibrary.org/obo/PR_P40630>'}
# http://purl.obolibrary.org/obo/PR_P03899:{'key': '<http://purl.obolibrary.org/obo/PR_P03899>'}
# http://purl.obolibrary.org/obo/HP_0010536:{'key': '<http://purl.obolibrary.org/obo/HP_0010536>'}
# http://purl.obolibrary.org/obo/CHEBI_15864:{'key': '<http://purl.obolibrary.org/obo/CHEBI_15864>'}
# http://purl.obolibrary.org/obo/CHEBI_3092:{'key': '<http://purl.obolibrary.org/obo/CHEBI_3092>'}

# %%
i = -1
for (s,o,k,d) in nx_mdg.edges(data=True, keys=True):
    i+=1
    if i==2:
        break
    print(s)
    print(o)
    print(k)
    print(d)
# Out:
# http://purl.obolibrary.org/obo/CHEBI_36856
# http://purl.obolibrary.org/obo/PR_Q05421
# http://purl.obolibrary.org/obo/RO_0002449
# {'predicate_key': '92e324b79c1218fb412629e2cc185585', 'weight': 0.0, 'pmid': '29356593', 'timestamp': '2018 Feb', 'source_graph': 'machine_read'}
# http://purl.obolibrary.org/obo/CHEBI_36856
# http://purl.obolibrary.org/obo/PR_Q05421
# http://purl.obolibrary.org/obo/RO_0002436
# {'predicate_key': 'e79d4f1ccf29afa3b87bde913d61c4eb', 'weight': 0.0, 'pmid': '29356593', 'timestamp': '2018 Feb', 'source_graph': 'machine_read'}

# %%
#save node labels as dictionary
#key: URI, value is label
label_dict = {}
for i in range(len(df_new.index)):
    subj = str(df_new.at[i, 'subject_obo'])
    obj = str(df_new.at[i, 'object_obo'])
    pred = str(df_new.at[i, 'predicate_obo'])
    if subj not in label_dict:
        label_dict[subj] = {}
        label_dict[subj]['entity_type'] = 'NODES'
        label_dict[subj]['label'] = df_new.at[i, 'subject_name']
        label_dict[subj]['cui'] = df_new.at[i, 'subject_cui']
    if obj not in label_dict:
        label_dict[obj] = {}
        label_dict[obj]['entity_type'] = 'NODES'
        label_dict[obj]['label'] = df_new.at[i, 'object_name']
        label_dict[obj]['cui'] = df_new.at[i, 'object_cui']
    if pred not in label_dict:
        label_dict[pred] = {}
        label_dict[pred]['entity_type'] = 'RELATIONS'
        label_dict[pred]['label'] = df_new.at[i, 'predicate']
len(label_dict)
# Out:
# 2022

# %%
import pickle
with open('output_graphs/machineread_greentea_version2_NodeLabels.pickle', 'wb') as file_p:
    pickle.dump(label_dict, file_p)

# %%
dfmap = pd.DataFrame.from_dict(label_dict, orient='index')
dfmap.head()
# Out:
#                                             entity_type        label       cui
# http://purl.obolibrary.org/obo/SO_0000704         NODES        Genes  C0017337
# http://purl.obolibrary.org/obo/PR_000041244       NODES     Histones  C0019652
# http://purl.obolibrary.org/obo/GO_0006473     RELATIONS  Acetylation       NaN
# http://purl.obolibrary.org/obo/CHEBI_46024        NODES   PRDX2_gene  C1418880
# http://purl.obolibrary.org/obo/PR_000028799       NODES      Tubulin  C0041348

# %%
dfmap = dfmap.reset_index()
dfmap.head()
# Out:
#                                          index entity_type        label  \
# 0    http://purl.obolibrary.org/obo/SO_0000704       NODES        Genes
# 1  http://purl.obolibrary.org/obo/PR_000041244       NODES     Histones
# 2    http://purl.obolibrary.org/obo/GO_0006473   RELATIONS  Acetylation
# 3   http://purl.obolibrary.org/obo/CHEBI_46024       NODES   PRDX2_gene
# 4  http://purl.obolibrary.org/obo/PR_000028799       NODES      Tubulin
#
#         cui
# 0  C0017337
# 1  C0019652
# 2       NaN
# 3  C1418880
# 4  C0041348

# %%
dfmap = dfmap.rename(columns={"index":"entity_uri"})
dfmap.head()
# Out:
#                                     entity_uri entity_type        label  \
# 0    http://purl.obolibrary.org/obo/SO_0000704       NODES        Genes
# 1  http://purl.obolibrary.org/obo/PR_000041244       NODES     Histones
# 2    http://purl.obolibrary.org/obo/GO_0006473   RELATIONS  Acetylation
# 3   http://purl.obolibrary.org/obo/CHEBI_46024       NODES   PRDX2_gene
# 4  http://purl.obolibrary.org/obo/PR_000028799       NODES      Tubulin
#
#         cui
# 0  C0017337
# 1  C0019652
# 2       NaN
# 3  C1418880
# 4  C0041348

# %%
dfmap.to_csv('output_graphs/machineread_greentea_version2_NodeLabels.tsv', index=False, sep='\t')

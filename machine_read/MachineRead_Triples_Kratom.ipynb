# %%
import pandas as pd
# import built-in namespaces
from rdflib.namespace import OWL, RDF, RDFS
import numpy as np

# %%
#at some point do for multiple files with machine read triples

# %%
dfgt = pd.read_csv('predication_files/kratom_pmid_all_predicates_umls.tsv', sep='\t')
dfgt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 511 entries, 0 to 510
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   seq                   511 non-null    int64
#  1   pmid                  511 non-null    int64
#  2   subject_cui           445 non-null    object
#  3   subject_name          445 non-null    object
#  4   subject_type          445 non-null    object
#  5   subject_source        491 non-null    object
#  6   subj_map_reach        511 non-null    object
#  7   predicate             511 non-null    object
#  8   object_source         494 non-null    object
#  9   object_cui            450 non-null    object
#  10  object_name           450 non-null    object
#  11  object_type           450 non-null    object
#  12  obj_map_reach         511 non-null    object
#  13  belief                511 non-null    float64
#  14  sentence              511 non-null    object
#  15  year                  511 non-null    object
#  16  subject_score         445 non-null    float64
#  17  object_score          450 non-null    float64
#  18  umls_flag             511 non-null    int64
#  19  subj_reach_grounding  511 non-null    object
#  20  obj_reach_grounding   511 non-null    object
# dtypes: float64(3), int64(3), object(15)
# memory usage: 84.0+ KB

# %%
dfgt.head()
# Out:
#    seq      pmid subject_cui                              subject_name  \
# 0    0   9545295    C0033684                                  Proteins
# 1    1   9545295    C0596902               Membrane_Transport_Proteins
# 2    2  17628447    C0001473                 Adenosine_Triphosphatases
# 3    3  29966288    C3816745                                        1+
# 4    4  23773766    C0795974  Hereditary_macular_epidermolysis_bullosa
#
#        subject_type       subject_source                       subj_map_reach  \
# 0  ['aapp', 'bacs']   AATP1 gene product       {'TEXT': 'AATP1 gene product'}
# 1  ['aapp', 'bacs']  ATP/ADP transporter      {'TEXT': 'ATP/ADP transporter'}
# 2  ['aapp', 'enzy']               ATPase  {'PF': 'PF06745', 'TEXT': 'ATPase'}
# 3          ['fndg']             AtPHT5;1                 {'TEXT': 'AtPHT5;1'}
# 4          ['dsyn']                EBM-2                    {'TEXT': 'EBM-2'}
#
#     predicate         object_source object_cui  ...       object_type  \
# 0  Activation  ATP/ADP\ntransporter   C2744579  ...  ['aapp', 'enzy']
# 1  Activation                   ATP   C2744579  ...  ['aapp', 'enzy']
# 2  Activation                   ATP   C2744579  ...  ['aapp', 'enzy']
# 3  Activation              SERPINA1   C0429863  ...          ['fndg']
# 4  Activation          RBEC barrier   C1706912  ...          ['medd']
#
#                                        obj_map_reach belief  \
# 0                   {'TEXT': 'ATP/ADP\ntransporter'}   0.65
# 1  {'HMDB': 'HMDB0000538', 'PUBCHEM': '5957', 'CH...   0.65
# 2  {'HMDB': 'HMDB0000538', 'PUBCHEM': '5957', 'CH...   0.65
# 3  {'UP': 'P01009', 'TEXT': 'Pi', 'HGNC': '8941',...   0.65
# 4                           {'TEXT': 'RBEC barrier'}   0.65
#
#                                             sentence         year  \
# 0  The analysis of both,\ntopological arrangement...  1998 Apr 17
# 1  ATP import into all types of plastids is media...  1998 Apr 17
# 2  Proton translocation is crucial in maintaining...     2007 Sep
# 3  The authors found that AtPHT5;1 mediated Pi in...  2018 Jun 29
# 4  Experimentally determined hydrodynamic radii a...  2013 Jun 18
#
#   subject_score  object_score  umls_flag  subj_reach_grounding  \
# 0          6.91         12.94          1          (None, None)
# 1         13.09         14.64          1          (None, None)
# 2         17.80         14.64          1          (None, None)
# 3          5.18          5.18          1          (None, None)
# 4         13.14          3.68          1          (None, None)
#
#         obj_reach_grounding
# 0              (None, None)
# 1  ('CHEBI', 'CHEBI:15422')
# 2  ('CHEBI', 'CHEBI:15422')
# 3          ('HGNC', '8941')
# 4              (None, None)
#
# [5 rows x 21 columns]

# %%
df = dfgt.fillna('')

# %%
df.head()
# Out:
#    seq      pmid subject_cui                              subject_name  \
# 0    0   9545295    C0033684                                  Proteins
# 1    1   9545295    C0596902               Membrane_Transport_Proteins
# 2    2  17628447    C0001473                 Adenosine_Triphosphatases
# 3    3  29966288    C3816745                                        1+
# 4    4  23773766    C0795974  Hereditary_macular_epidermolysis_bullosa
#
#        subject_type       subject_source                       subj_map_reach  \
# 0  ['aapp', 'bacs']   AATP1 gene product       {'TEXT': 'AATP1 gene product'}
# 1  ['aapp', 'bacs']  ATP/ADP transporter      {'TEXT': 'ATP/ADP transporter'}
# 2  ['aapp', 'enzy']               ATPase  {'PF': 'PF06745', 'TEXT': 'ATPase'}
# 3          ['fndg']             AtPHT5;1                 {'TEXT': 'AtPHT5;1'}
# 4          ['dsyn']                EBM-2                    {'TEXT': 'EBM-2'}
#
#     predicate         object_source object_cui  ...       object_type  \
# 0  Activation  ATP/ADP\ntransporter   C2744579  ...  ['aapp', 'enzy']
# 1  Activation                   ATP   C2744579  ...  ['aapp', 'enzy']
# 2  Activation                   ATP   C2744579  ...  ['aapp', 'enzy']
# 3  Activation              SERPINA1   C0429863  ...          ['fndg']
# 4  Activation          RBEC barrier   C1706912  ...          ['medd']
#
#                                        obj_map_reach belief  \
# 0                   {'TEXT': 'ATP/ADP\ntransporter'}   0.65
# 1  {'HMDB': 'HMDB0000538', 'PUBCHEM': '5957', 'CH...   0.65
# 2  {'HMDB': 'HMDB0000538', 'PUBCHEM': '5957', 'CH...   0.65
# 3  {'UP': 'P01009', 'TEXT': 'Pi', 'HGNC': '8941',...   0.65
# 4                           {'TEXT': 'RBEC barrier'}   0.65
#
#                                             sentence         year  \
# 0  The analysis of both,\ntopological arrangement...  1998 Apr 17
# 1  ATP import into all types of plastids is media...  1998 Apr 17
# 2  Proton translocation is crucial in maintaining...     2007 Sep
# 3  The authors found that AtPHT5;1 mediated Pi in...  2018 Jun 29
# 4  Experimentally determined hydrodynamic radii a...  2013 Jun 18
#
#   subject_score object_score umls_flag  subj_reach_grounding  \
# 0          6.91        12.94         1          (None, None)
# 1         13.09        14.64         1          (None, None)
# 2          17.8        14.64         1          (None, None)
# 3          5.18         5.18         1          (None, None)
# 4         13.14         3.68         1          (None, None)
#
#         obj_reach_grounding
# 0              (None, None)
# 1  ('CHEBI', 'CHEBI:15422')
# 2  ('CHEBI', 'CHEBI:15422')
# 3          ('HGNC', '8941')
# 4              (None, None)
#
# [5 rows x 21 columns]

# %%
#fixes reach mappings to OBO (if available) and adds text if no mapping or blank name of entity
for i in range(len(df.index)):
    subj_ground = df.at[i, 'subj_reach_grounding']
    obj_ground = df.at[i, 'obj_reach_grounding']
    subj_map = df.at[i, 'subj_map_reach']
    obj_map = df.at[i, 'obj_map_reach']
    if subj_ground == '(None, None)' or subj_ground == np.nan:
        temp = subj_map.split(',')
        if 'GO' in subj_map or 'CHEBI' in subj_map:
            for item in temp:
                if 'GO' in item or 'CHEBI' in item:
                    df.at[i, 'subj_reach_grounding'] = item
        elif 'UP' in subj_map:
            for item in temp:
                if 'UP' in item:
                    df.at[i, 'subj_reach_grounding'] = item
        elif 'TEXT' in subj_map:
            if df.at[i, 'subject_source'] == '':
                for item in temp:
                    if 'TEXT' in item:
                        df.at[i, 'subject_source'] = item.split(':')[-1]
    elif 'GO' not in subj_ground and 'CHEBI' not in subj_ground and 'UP' not in subj_ground:
        temp = subj_map.split(',')
        if 'GO' in subj_map or 'CHEBI' in subj_map:
            for item in temp:
                if 'GO' in item or 'CHEBI' in item:
                    df.at[i, 'subj_reach_grounding'] = item
        elif 'UP' in subj_map:
            for item in temp:
                if 'UP' in item:
                    df.at[i, 'subj_reach_grounding'] = item
        elif 'TEXT' in subj_map:
            if df.at[i, 'subject_source'] == '':
                for item in temp:
                    if 'TEXT' in item:
                        df.at[i, 'subject_source'] = item.split(':')[-1]
    
    #same for object mapping
    if obj_ground == '(None, None)' or obj_ground == np.nan:
        temp = obj_map.split(',')
        if 'GO' in obj_map or 'CHEBI' in obj_map:
            for item in temp:
                if 'GO' in item or 'CHEBI' in item:
                    df.at[i, 'obj_reach_grounding'] = item
        elif 'UP' in obj_map:
            for item in temp:
                if 'UP' in item:
                    df.at[i, 'obj_reach_grounding'] = item
        elif 'TEXT' in obj_map:
            if df.at[i, 'object_source'] == '':
                for item in temp:
                    if 'TEXT' in item:
                        df.at[i, 'object_source'] = item.split(':')[-1]
    elif 'GO' not in obj_ground and 'CHEBI' not in obj_ground and 'UP' not in obj_ground:
        temp = obj_map.split(',')
        if 'GO' in obj_map or 'CHEBI' in obj_map:
            for item in temp:
                if 'GO' in item or 'CHEBI' in item:
                    df.at[i, 'obj_reach_grounding'] = item
        elif 'UP' in obj_map:
            for item in temp:
                if 'UP' in item:
                    df.at[i, 'obj_reach_grounding'] = item
        elif 'TEXT' in obj_map:
            if df.at[i, 'object_source'] == '':
                for item in temp:
                    if 'TEXT' in item:
                        df.at[i, 'object_source'] = item.split(':')[-1]

# %%
df.loc[df['subject_name'] == 'mitragynine']
# Out:
#      seq      pmid subject_cui subject_name      subject_type subject_source  \
# 130  130  31874991    C0066619  mitragynine  ['orch', 'phsu']    Mitragynine
# 131  131  31874991    C0066619  mitragynine  ['orch', 'phsu']    Mitragynine
# 132  132  16107269    C0066619  mitragynine  ['orch', 'phsu']    Mitragynine
# 133  133  25262913    C0066619  mitragynine  ['orch', 'phsu']    Mitragynine
# 134  134  23274770    C0066619  mitragynine  ['orch', 'phsu']    Mitragynine
# ..   ...       ...         ...          ...               ...            ...
# 446  446  30604191    C0066619  mitragynine  ['orch', 'phsu']    Mitragynine
# 447  447  27260674    C0066619  mitragynine  ['orch', 'phsu']    Mitragynine
# 448  448  24174816    C0066619  mitragynine  ['orch', 'phsu']    Mitragynine
# 449  449  16107269    C0066619  mitragynine  ['orch', 'phsu']    Mitragynine
# 450  450  24841968    C0066619  mitragynine  ['orch', 'phsu']    Mitragynine
#
#                                         subj_map_reach   predicate  \
# 130  {'CHEBI': 'CHEBI:6956', 'TEXT': 'Mitragynine',...  Activation
# 131  {'CHEBI': 'CHEBI:6956', 'TEXT': 'mitragynine',...  Activation
# 132  {'CHEBI': 'CHEBI:6956', 'TEXT': 'mitragynine',...  Activation
# 133  {'CHEBI': 'CHEBI:6956', 'TEXT': 'mitragynine',...  Activation
# 134  {'CHEBI': 'CHEBI:6956', 'TEXT': 'mitragynine',...  Activation
# ..                                                 ...         ...
# 446  {'CHEBI': 'CHEBI:6956', 'TEXT': 'mitragynine',...  Inhibition
# 447  {'CHEBI': 'CHEBI:6956', 'TEXT': 'mitragynine',...  Inhibition
# 448  {'CHEBI': 'CHEBI:6956', 'TEXT': 'Mitragynine',...  Inhibition
# 449  {'CHEBI': 'CHEBI:6956', 'TEXT': 'mitragynine',...  Inhibition
# 450  {'CHEBI': 'CHEBI:6956', 'TEXT': 'mitragynine',...  Inhibition
#
#         object_source object_cui  ...       object_type  \
# 130      hERG1a-Hsp90   C0243044  ...  ['aapp', 'bacs']
# 131         hERG1a/1b   C0450345  ...          ['inpr']
# 132  opioid receptors   C0034801  ...  ['aapp', 'rcpt']
# 133               paw   C0687080  ...          ['bpoc']
# 134              'ﬁ'}             ...
# ..                ...        ...  ...               ...
# 446             ABCB1   C0369773  ...  ['aapp', 'imft']
# 447             KCNH2   C1416572  ...          ['gngm']
# 448             PSME3   C0032831  ...  ['inch', 'phsu']
# 449     Neuroblastoma   C0027819  ...          ['neop']
# 450              STE6   C0242643  ...  ['aapp', 'bacs']
#
#                                          obj_map_reach belief  \
# 130                           {'TEXT': 'hERG1a-Hsp90'}  0.650
# 131                              {'TEXT': 'hERG1a/1b'}  0.650
# 132                       {'TEXT': 'opioid receptors'}  0.650
# 133                   {'PF': 'PF04721', 'TEXT': 'paw'}  0.650
# 134                                      {'TEXT': 'ﬁ'}  0.860
# ..                                                 ...    ...
# 446  {'HGNC': '40', 'UP': 'P08183', 'MESH': 'C51305...  0.650
# 447  {'UP': 'Q12809', 'TEXT': 'hERG', 'MESH': 'C000...  0.923
# 448  {'UP': 'P61289', 'TEXT': 'Ki', 'HGNC': '9570',...  0.650
# 449       {'MESH': 'D009447', 'TEXT': 'neuroblastoma'}  0.860
# 450         {'UP': 'P12866', 'TEXT': 'P-glycoprotein'}  0.860
#
#                                               sentence         year  \
# 130  Mitragynine, an euphoric compound inhibits hER...  2019 Dec 24
# 131  Interestingly, mitragynine elicited a dose-dep...  2019 Dec 24
# 132  We reported that mitragynine stimulates opioid...  2005 Nov 26
# 133  We found that mitragynine withdrawal induced a...     2016 Jan
# 134  Importantly, mitragynine may produce a clinica...     2013 Mar
# ..                                                 ...          ...
# 446  In conclusion, mitragynine inhibits the P-gp t...     2019 Apr
# 447  Tyr652 and speciﬁcally, Phe656 in the S6 domai...  2016 Aug 15
# 448  Mitragynine noncompetitively inhibits CYP2C9 a...     2013 Oct
# 449  By using the patch-clamp technique, mitragynin...  2005 Nov 26
# 450  Mitragynine and 7-hydroxy- mitragynine inhibit...     2014 May
#
#     subject_score object_score umls_flag     subj_reach_grounding  \
# 130         14.64         16.3         1  ('CHEBI', 'CHEBI:6956')
# 131         14.64         3.68         1  ('CHEBI', 'CHEBI:6956')
# 132         14.64        24.11         1  ('CHEBI', 'CHEBI:6956')
# 133         14.64         5.18         1  ('CHEBI', 'CHEBI:6956')
# 134         14.64                      1  ('CHEBI', 'CHEBI:6956')
# ..            ...          ...       ...                      ...
# 446         14.64         3.68         1  ('CHEBI', 'CHEBI:6956')
# 447         14.64         5.18         1  ('CHEBI', 'CHEBI:6956')
# 448         14.64        14.64         1  ('CHEBI', 'CHEBI:6956')
# 449         14.64        27.26         1  ('CHEBI', 'CHEBI:6956')
# 450         14.64        30.42         1  ('CHEBI', 'CHEBI:6956')
#
#      obj_reach_grounding
# 130         (None, None)
# 131         (None, None)
# 132         (None, None)
# 133         (None, None)
# 134         (None, None)
# ..                   ...
# 446       'UP': 'P08183'
# 447      {'UP': 'Q12809'
# 448      {'UP': 'P61289'
# 449  ('MESH', 'D009447')
# 450     ('UP', 'P12866')
#
# [66 rows x 21 columns]

# %%
df = df[['subject_cui', 'subject_name', 'subject_source', 'predicate', 'object_source',
       'object_cui', 'object_name', 'subj_reach_grounding', 'obj_reach_grounding', 'pmid', 
           'year', 'belief', 'sentence']]

# %%
df['predicate_obo'] = None
df['subject_obo'] = None
df['object_obo'] = None

# %%
df.head()
# Out:
#   subject_cui                              subject_name       subject_source  \
# 0    C0033684                                  Proteins   AATP1 gene product
# 1    C0596902               Membrane_Transport_Proteins  ATP/ADP transporter
# 2    C0001473                 Adenosine_Triphosphatases               ATPase
# 3    C3816745                                        1+             AtPHT5;1
# 4    C0795974  Hereditary_macular_epidermolysis_bullosa                EBM-2
#
#     predicate         object_source object_cui  \
# 0  Activation  ATP/ADP\ntransporter   C2744579
# 1  Activation                   ATP   C2744579
# 2  Activation                   ATP   C2744579
# 3  Activation              SERPINA1   C0429863
# 4  Activation          RBEC barrier   C1706912
#
#                                      object_name subj_reach_grounding  \
# 0                          ATP8A2_protein,_human         (None, None)
# 1                          ATP8A2_protein,_human         (None, None)
# 2                          ATP8A2_protein,_human         (None, None)
# 3  Pulsatility_index,_arterial_velocity_waveform         (None, None)
# 4                                        BARRIER         (None, None)
#
#         obj_reach_grounding      pmid         year  belief  \
# 0              (None, None)   9545295  1998 Apr 17    0.65
# 1  ('CHEBI', 'CHEBI:15422')   9545295  1998 Apr 17    0.65
# 2  ('CHEBI', 'CHEBI:15422')  17628447     2007 Sep    0.65
# 3           {'UP': 'P01009'  29966288  2018 Jun 29    0.65
# 4              (None, None)  23773766  2013 Jun 18    0.65
#
#                                             sentence predicate_obo  \
# 0  The analysis of both,\ntopological arrangement...          None
# 1  ATP import into all types of plastids is media...          None
# 2  Proton translocation is crucial in maintaining...          None
# 3  The authors found that AtPHT5;1 mediated Pi in...          None
# 4  Experimentally determined hydrodynamic radii a...          None
#
#   subject_obo object_obo
# 0        None       None
# 1        None       None
# 2        None       None
# 3        None       None
# 4        None       None

# %%
go_hpo_map = pd.read_csv('cui_to_ontology_maps/go_hpo_map.csv')

# %%
go_hpo_map.index
# Out:
# RangeIndex(start=0, stop=90376, step=1)

# %%
go_hpo_mapping_dict = {}
for i in range(len(go_hpo_map.index)):
    cui = go_hpo_map.at[i,'cui']
    if cui not in go_hpo_mapping_dict:
        go_hpo_mapping_dict[cui] = []
    code = go_hpo_map.at[i, 'code']
    code = code.replace(':', '_')
    go_hpo_mapping_dict[cui].append(code)
print(len(go_hpo_mapping_dict))
# Out:
# 87745

# %%
import pickle
with open('cui_to_ontology_maps/go_hpo_map_dict.pickle', 'wb') as filep:
    pickle.dump(go_hpo_mapping_dict, filep)

# %%
#taking only first mapped for now -- assess if that option is the best (how?)

# %%
go_hpo_mapping_dict['C0001122']
# Out:
# ['HP_0001941']

# %%
import numpy as np

# %%
df = df.fillna('')

# %%
#if subject_name or object_name is '', take TEXT from grounding and use

# %%
#map cui to reach grounding
reach_grounding_dict = {}
for i in range(len(df.index)):
    sub_cui = df.at[i, 'subject_cui']
    sub_source = df.at[i, 'subject_source']
    obj_cui = df.at[i, 'object_cui']
    obj_source = df.at[i, 'object_source']
    sub_ground = df.at[i, 'subj_reach_grounding']
    obj_ground = df.at[i, 'obj_reach_grounding']
    sub_key = i
    obj_key = i
    if sub_cui != '':
        sub_key = sub_cui
    elif sub_source != '':
        sub_key = sub_source
    if obj_cui != '':
        obj_key = obj_cui
    elif obj_source != '':
        obj_key = obj_source
    if sub_key not in reach_grounding_dict:
        reach_grounding_dict[sub_key] = []
    if obj_key not in reach_grounding_dict:
        reach_grounding_dict[obj_key] = []
    if sub_ground != np.nan:
        if 'CHEBI' in sub_ground or 'GO' in sub_ground:
            subject_map = sub_ground.split("'")[-2]
            subject_map = subject_map.replace(':', '_')
            reach_grounding_dict[sub_key].append(subject_map)
        elif 'UP' in sub_ground:
            subject_map = sub_ground.split("'")[-2]
            subject_map = 'PR_' + subject_map
            reach_grounding_dict[sub_key].append(subject_map)
    if obj_ground != np.nan:
        if 'CHEBI' in obj_ground or 'GO' in obj_ground:
            object_map = obj_ground.split("'")[-2]
            object_map = object_map.replace(':', '_')
            reach_grounding_dict[obj_key].append(object_map)
        elif 'UP' in obj_ground:
            object_map = obj_ground.split("'")[-2]
            object_map = 'PR_' + object_map
            reach_grounding_dict[obj_key].append(object_map)
print(len(reach_grounding_dict))
# Out:
# 379

# %%
predMapD = {
    'regulateactivity':'RO_0011002',
    'regulateamount':'RO_0011003',
    'phosphorylation':'RO_0002447',
    'dephosphorylation':'GO_0006470',
    'ubiquitination':'RO_0002480',
    'deubiquitination':'GO_0016579',
    'sumoylation':'RO_0002436',
    'desumoylation':'RO_0002436',
    'hydroxylation':'GO_0018126',
    'dehydroxylation':'RO_0002436',
    'acetylation':'GO_0006473',
    'deacetylation':'GO_0006476',
    'glycosylation':'GO_0006486',
    'deglycosylation':'GO_0006517',
    'farnesylation':'RO_0002436',
    'defarnesylation':'RO_0002436',
    'geranylgeranylation':'RO_0002436',
    'degeranylgeranylation':'RO_0002436',
    'palmitoylation':'RO_0002436',
    'depalmitoylation':'RO_0002436',
    'myristoylation':'RO_0002436',
    'demyristoylation':'RO_0002436',
    'ribosylation':'RO_0002436',
    'deribosylation':'RO_0002436',
    'methylation':'GO_0006479',
    'demethylation':'GO_0006482',
    'activation':'RO_0002448',
    'inhibition':'RO_0002449',
    'increaseamount':'RO_0011009',
    'decreaseamount':'RO_0011010'
}
'''predMapD_old = {
    'regulateactivity':'RO_0002436',
    'regulateamount':'RO_0002436',
    'phosphorylation':'RO_0002447',
    'dephosphorylation':'GO_0006470',
    'ubiquitination':'RO_0002480',
    'deubiquitination':'GO_0016579',
    'sumoylation':'RO_0002436',
    'desumoylation':'RO_0002436',
    'hydroxylation':'GO_0018126',
    'dehydroxylation':'RO_0002436',
    'acetylation':'GO_0006473',
    'deacetylation':'GO_0006476',
    'glycosylation':'GO_0006486',
    'deglycosylation':'GO_0006517',
    'farnesylation':'RO_0002436',
    'defarnesylation':'RO_0002436',
    'geranylgeranylation':'RO_0002436',
    'degeranylgeranylation':'RO_0002436',
    'palmitoylation':'RO_0002436',
    'depalmitoylation':'RO_0002436',
    'myristoylation':'RO_0002436',
    'demyristoylation':'RO_0002436',
    'ribosylation':'RO_0002436',
    'deribosylation':'RO_0002436',
    'methylation':'GO_0006479',
    'demethylation':'GO_0006482',
    'activation':'RO_0002436',
    'inhibition':'RO_0002449',
    'increaseamount':'RO_0002213',
    'decreaseamount':'RO_0002212'
}'''
# Out:
# "predMapD_old = {\n    'regulateactivity':'RO_0002436',\n    'regulateamount':'RO_0002436',\n    'phosphorylation':'RO_0002447',\n    'dephosphorylation':'GO_0006470',\n    'ubiquitination':'RO_0002480',\n    'deubiquitination':'GO_0016579',\n    'sumoylation':'RO_0002436',\n    'desumoylation':'RO_0002436',\n    'hydroxylation':'GO_0018126',\n    'dehydroxylation':'RO_0002436',\n    'acetylation':'GO_0006473',\n    'deacetylation':'GO_0006476',\n    'glycosylation':'GO_0006486',\n    'deglycosylation':'GO_0006517',\n    'farnesylation':'RO_0002436',\n    'defarnesylation':'RO_0002436',\n    'geranylgeranylation':'RO_0002436',\n    'degeranylgeranylation':'RO_0002436',\n    'palmitoylation':'RO_0002436',\n    'depalmitoylation':'RO_0002436',\n    'myristoylation':'RO_0002436',\n    'demyristoylation':'RO_0002436',\n    'ribosylation':'RO_0002436',\n    'deribosylation':'RO_0002436',\n    'methylation':'GO_0006479',\n    'demethylation':'GO_0006482',\n    'activation':'RO_0002436',\n    'inhibition':'RO_0002449',\n    'increaseamount':'RO_0002213',\n    'decreaseamount':'RO_0002212'\n}"

# %%
#if reach_grounding has multiple values, currently only first one is taken -- assess if this is the best option
def get_obo_mapping(row, col):
    if col == 'subject':
        cui = row['subject_cui']
        source = row['subject_source']
    elif col == 'object':
        cui = row['object_cui']
        source = row['object_source']
    else:
        print('specify is subject or object mapping required')
        exit(0)
    if cui in go_hpo_mapping_dict:
        if len(go_hpo_mapping_dict):
            return go_hpo_mapping_dict[cui][0]
    if cui in reach_grounding_dict:
        if len(reach_grounding_dict[cui]):
            return reach_grounding_dict[cui][0]
    if source in reach_grounding_dict:
        if len(reach_grounding_dict[source]):
            return reach_grounding_dict[source][0]
    return ''

# %%
def relation_mapping(row):
    rel = row['predicate'].lower()
    if rel in predMapD:
        return predMapD[rel]
    else:
        return ''

# %%
df['predicate_obo'] = df.apply(relation_mapping, axis=1)
df.head()
# Out:
#   subject_cui                              subject_name       subject_source  \
# 0    C0033684                                  Proteins   AATP1 gene product
# 1    C0596902               Membrane_Transport_Proteins  ATP/ADP transporter
# 2    C0001473                 Adenosine_Triphosphatases               ATPase
# 3    C3816745                                        1+             AtPHT5;1
# 4    C0795974  Hereditary_macular_epidermolysis_bullosa                EBM-2
#
#     predicate         object_source object_cui  \
# 0  Activation  ATP/ADP\ntransporter   C2744579
# 1  Activation                   ATP   C2744579
# 2  Activation                   ATP   C2744579
# 3  Activation              SERPINA1   C0429863
# 4  Activation          RBEC barrier   C1706912
#
#                                      object_name subj_reach_grounding  \
# 0                          ATP8A2_protein,_human         (None, None)
# 1                          ATP8A2_protein,_human         (None, None)
# 2                          ATP8A2_protein,_human         (None, None)
# 3  Pulsatility_index,_arterial_velocity_waveform         (None, None)
# 4                                        BARRIER         (None, None)
#
#         obj_reach_grounding      pmid         year  belief  \
# 0              (None, None)   9545295  1998 Apr 17    0.65
# 1  ('CHEBI', 'CHEBI:15422')   9545295  1998 Apr 17    0.65
# 2  ('CHEBI', 'CHEBI:15422')  17628447     2007 Sep    0.65
# 3           {'UP': 'P01009'  29966288  2018 Jun 29    0.65
# 4              (None, None)  23773766  2013 Jun 18    0.65
#
#                                             sentence predicate_obo  \
# 0  The analysis of both,\ntopological arrangement...    RO_0002436
# 1  ATP import into all types of plastids is media...    RO_0002436
# 2  Proton translocation is crucial in maintaining...    RO_0002436
# 3  The authors found that AtPHT5;1 mediated Pi in...    RO_0002436
# 4  Experimentally determined hydrodynamic radii a...    RO_0002436
#
#   subject_obo object_obo
# 0
# 1
# 2
# 3
# 4

# %%
#MAPPING
df['subject_obo'] = df.apply(get_obo_mapping, axis=1, col='subject')
df.head()
# Out:
#   subject_cui                              subject_name       subject_source  \
# 0    C0033684                                  Proteins   AATP1 gene product
# 1    C0596902               Membrane_Transport_Proteins  ATP/ADP transporter
# 2    C0001473                 Adenosine_Triphosphatases               ATPase
# 3    C3816745                                        1+             AtPHT5;1
# 4    C0795974  Hereditary_macular_epidermolysis_bullosa                EBM-2
#
#     predicate         object_source object_cui  \
# 0  Activation  ATP/ADP\ntransporter   C2744579
# 1  Activation                   ATP   C2744579
# 2  Activation                   ATP   C2744579
# 3  Activation              SERPINA1   C0429863
# 4  Activation          RBEC barrier   C1706912
#
#                                      object_name subj_reach_grounding  \
# 0                          ATP8A2_protein,_human         (None, None)
# 1                          ATP8A2_protein,_human         (None, None)
# 2                          ATP8A2_protein,_human         (None, None)
# 3  Pulsatility_index,_arterial_velocity_waveform         (None, None)
# 4                                        BARRIER         (None, None)
#
#         obj_reach_grounding      pmid         year  belief  \
# 0              (None, None)   9545295  1998 Apr 17    0.65
# 1  ('CHEBI', 'CHEBI:15422')   9545295  1998 Apr 17    0.65
# 2  ('CHEBI', 'CHEBI:15422')  17628447     2007 Sep    0.65
# 3           {'UP': 'P01009'  29966288  2018 Jun 29    0.65
# 4              (None, None)  23773766  2013 Jun 18    0.65
#
#                                             sentence predicate_obo  \
# 0  The analysis of both,\ntopological arrangement...    RO_0002436
# 1  ATP import into all types of plastids is media...    RO_0002436
# 2  Proton translocation is crucial in maintaining...    RO_0002436
# 3  The authors found that AtPHT5;1 mediated Pi in...    RO_0002436
# 4  Experimentally determined hydrodynamic radii a...    RO_0002436
#
#   subject_obo object_obo
# 0
# 1
# 2
# 3   PR_Q8VYM2
# 4

# %%
df['object_obo'] = df.apply(get_obo_mapping, axis=1, col='object')
df.head()
# Out:
#   subject_cui                              subject_name       subject_source  \
# 0    C0033684                                  Proteins   AATP1 gene product
# 1    C0596902               Membrane_Transport_Proteins  ATP/ADP transporter
# 2    C0001473                 Adenosine_Triphosphatases               ATPase
# 3    C3816745                                        1+             AtPHT5;1
# 4    C0795974  Hereditary_macular_epidermolysis_bullosa                EBM-2
#
#     predicate         object_source object_cui  \
# 0  Activation  ATP/ADP\ntransporter   C2744579
# 1  Activation                   ATP   C2744579
# 2  Activation                   ATP   C2744579
# 3  Activation              SERPINA1   C0429863
# 4  Activation          RBEC barrier   C1706912
#
#                                      object_name subj_reach_grounding  \
# 0                          ATP8A2_protein,_human         (None, None)
# 1                          ATP8A2_protein,_human         (None, None)
# 2                          ATP8A2_protein,_human         (None, None)
# 3  Pulsatility_index,_arterial_velocity_waveform         (None, None)
# 4                                        BARRIER         (None, None)
#
#         obj_reach_grounding      pmid         year  belief  \
# 0              (None, None)   9545295  1998 Apr 17    0.65
# 1  ('CHEBI', 'CHEBI:15422')   9545295  1998 Apr 17    0.65
# 2  ('CHEBI', 'CHEBI:15422')  17628447     2007 Sep    0.65
# 3           {'UP': 'P01009'  29966288  2018 Jun 29    0.65
# 4              (None, None)  23773766  2013 Jun 18    0.65
#
#                                             sentence predicate_obo  \
# 0  The analysis of both,\ntopological arrangement...    RO_0002436
# 1  ATP import into all types of plastids is media...    RO_0002436
# 2  Proton translocation is crucial in maintaining...    RO_0002436
# 3  The authors found that AtPHT5;1 mediated Pi in...    RO_0002436
# 4  Experimentally determined hydrodynamic radii a...    RO_0002436
#
#   subject_obo   object_obo
# 0              CHEBI_15422
# 1              CHEBI_15422
# 2              CHEBI_15422
# 3   PR_Q8VYM2    PR_P01009
# 4

# %%
df.loc[df['object_obo'] == 'PR_P69345']
# Out:
# Empty DataFrame
# Columns: [subject_cui, subject_name, subject_source, predicate, object_source, object_cui, object_name, subj_reach_grounding, obj_reach_grounding, pmid, year, belief, sentence, predicate_obo, subject_obo, object_obo]
# Index: []

# %%
#do we need bioportal mapping? -- yes. Get unmapped CUIs and strings
unmapped_cui = []
unmapped_string_umls = []
unmapped_string_reach = []
for i in range(len(df.index)):
    if df.at[i, 'subject_obo'] == '':
        subcui = df.at[i, 'subject_cui']
        if subcui not in unmapped_cui:
            unmapped_cui.append(df.at[i, 'subject_cui'])
            unmapped_string_umls.append(df.at[i, 'subject_name'])
        if subcui == '':
            unmapped_string_reach.append(df.at[i, 'subject_source'])
    if df.at[i, 'object_obo'] == '':
        objcui = df.at[i, 'object_cui']
        if objcui not in unmapped_cui:
            unmapped_cui.append(df.at[i, 'object_cui'])
            unmapped_string_umls.append(df.at[i, 'object_name'])
        if objcui == '':
            unmapped_string_reach.append(df.at[i, 'object_source'])

# %%
print(len(unmapped_cui))
print(len(unmapped_string_umls))
print(len(unmapped_string_reach))
# Out:
# 86
# 86
# 100

# %%
unmapped_string_reach[:20]
# Out:
# ['EGM-2',
#  'floppase',
#  'Gharib',
#  " 'ﬁ'}",
#  " 'ﬁ'}",
#  'NPDPA',
#  'OXA-',
#  'SFB 171',
#  'Salomon D',
#  " 'Ψ'}",
#  'TNF  stimulation antibody',
#  'a5GA- BAAR',
#  'hBCRP',
#  " 'µ'}",
#  " 'η'}",
#  " 'ﬁ'}",
#  'APD50',
#  " 'ﬁ'}",
#  'APD90',
#  " 'ﬁ'}"]

# %%
unmapped_string_umls[:20]
# Out:
# ['Proteins',
#  'Membrane_Transport_Proteins',
#  'Adenosine_Triphosphatases',
#  'Pulsatility_index,_arterial_velocity_waveform',
#  'Hereditary_macular_epidermolysis_bullosa',
#  'BARRIER',
#  'Enzymes',
#  'Methamphetamine',
#  'moira_protein,_Drosophila',
#  'National_Institute_on_Deafness_and_Other_Communication_Disorders_(U.S.)',
#  'Pyruvate_Kinase',
#  'N-Methyl-D-Aspartate_Receptors',
#  'Poisoning_aspects',
#  '+2',
#  'ABCB1_protein,_human',
#  'Inhibitor',
#  'Connexins',
#  'Thrombocythemia,_Essential',
#  'SLC22A12_gene',
#  'GABA-A_Receptor']

# %%
unmapped_string_umls_new = []
for item in unmapped_string_umls:
    item = item.replace('_', ' ')
    unmapped_string_umls_new.append(item.upper())

# %%
unmapped_string_umls_new[:20]
# Out:
# ['PROTEINS',
#  'MEMBRANE TRANSPORT PROTEINS',
#  'ADENOSINE TRIPHOSPHATASES',
#  'PULSATILITY INDEX, ARTERIAL VELOCITY WAVEFORM',
#  'HEREDITARY MACULAR EPIDERMOLYSIS BULLOSA',
#  'BARRIER',
#  'ENZYMES',
#  'METHAMPHETAMINE',
#  'MOIRA PROTEIN, DROSOPHILA',
#  'NATIONAL INSTITUTE ON DEAFNESS AND OTHER COMMUNICATION DISORDERS (U.S.)',
#  'PYRUVATE KINASE',
#  'N-METHYL-D-ASPARTATE RECEPTORS',
#  'POISONING ASPECTS',
#  '+2',
#  'ABCB1 PROTEIN, HUMAN',
#  'INHIBITOR',
#  'CONNEXINS',
#  'THROMBOCYTHEMIA, ESSENTIAL',
#  'SLC22A12 GENE',
#  'GABA-A RECEPTOR']

# %%
unmapped_cui[:20]
# Out:
# ['C0033684',
#  'C0596902',
#  'C0001473',
#  'C0429863',
#  'C0795974',
#  'C1706912',
#  'C0014442',
#  'C0025611',
#  'C1138348',
#  'C1955978',
#  'C0034348',
#  'C0080093',
#  'C0032344',
#  'C0740116',
#  'C1738970',
#  'C1999216',
#  'C0110611',
#  'C0040028',
#  'C1425219',
#  'C0034807']

# %%
unmapped_string_reach_new = []
for item in unmapped_string_reach:
    item = item.strip()
    item = item.replace('_', ' ')
    item = item.replace("'", '')
    item = item.replace('{', '')
    item = item.replace('}', '')
    unmapped_string_reach_new.append(item.upper())
unmapped_string_reach_new[:20]
# Out:
# ['EGM-2',
#  'FLOPPASE',
#  'GHARIB',
#  'FI',
#  'FI',
#  'NPDPA',
#  'OXA-',
#  'SFB 171',
#  'SALOMON D',
#  'Ψ',
#  'TNF  STIMULATION ANTIBODY',
#  'A5GA- BAAR',
#  'HBCRP',
#  'Μ',
#  'Η',
#  'FI',
#  'APD50',
#  'FI',
#  'APD90',
#  'FI']

# %%
with open('cui_to_ontology_maps/unmapped_umls_stringsv2.txt', 'w') as file1:
    for item in unmapped_string_umls_new:
        file1.write(item)
        file1.write('\n')
with open('cui_to_ontology_maps/unmapped_umls_cuiv2.txt', 'w') as file2:
    for item in unmapped_cui:
        file2.write(item)
        file2.write('\n')
with open('cui_to_ontology_maps/unmapped_reach_textv2.txt', 'w') as file2:
    for item in unmapped_string_reach_new:
        file2.write(item)
        file2.write('\n')

# %%
#Bioportal mappings - load and use (run curl query and use json response)
# Process Bioportal annotator response
bioportal_map_dict = {}
import json
f = open('cui_to_ontology_maps/unmapped_strings_annotator_responsev2.json','r')
map_d_l = json.load(f)
f.close()

# all unmapped strings and CUIs
strToCuiD = {}
cuiToStrD = {}
#len = 1487
for i in range(len(unmapped_cui)):
    s = unmapped_string_umls_new[i]
    cui = unmapped_cui[i]
    strToCuiD[s.upper()] = cui
    cuiToStrD[cui] = s.upper()

for d in map_d_l:
    mapped_to = d['annotatedClass']['@id']
    for mapped_from_d in d['annotations']:
            if not strToCuiD.get(mapped_from_d['text'].upper()):
                continue
            else:
                cui = strToCuiD[mapped_from_d['text'].upper()]
                if not bioportal_map_dict.get(cui):
                    bioportal_map_dict[cui] = [mapped_to]
                else:
                    if mapped_to not in bioportal_map_dict[cui]:
                        bioportal_map_dict[cui].append(mapped_to)
print(len(bioportal_map_dict))
# Out:
# 21

# %%
for key in bioportal_map_dict:
    print(key)
    print(bioportal_map_dict[key])
    break
# Out:
# C0033684
# ['http://purl.obolibrary.org/obo/CHEBI_36080']

# %%
map_d_l[0]['annotations']
# Out:
# [{'from': 1, 'to': 8, 'matchType': 'SYN', 'text': 'PROTEINS'},
#  {'from': 29, 'to': 36, 'matchType': 'SYN', 'text': 'PROTEINS'},
#  {'from': 189, 'to': 195, 'matchType': 'PREF', 'text': 'PROTEIN'},
#  {'from': 355, 'to': 361, 'matchType': 'PREF', 'text': 'PROTEIN'},
#  {'from': 572, 'to': 578, 'matchType': 'PREF', 'text': 'PROTEIN'},
#  {'from': 617, 'to': 623, 'matchType': 'PREF', 'text': 'PROTEIN'},
#  {'from': 691, 'to': 697, 'matchType': 'PREF', 'text': 'PROTEIN'},
#  {'from': 946, 'to': 952, 'matchType': 'PREF', 'text': 'PROTEIN'},
#  {'from': 1111, 'to': 1118, 'matchType': 'SYN', 'text': 'PROTEINS'},
#  {'from': 1218, 'to': 1225, 'matchType': 'SYN', 'text': 'PROTEINS'},
#  {'from': 1675, 'to': 1681, 'matchType': 'PREF', 'text': 'PROTEIN'},
#  {'from': 1806, 'to': 1812, 'matchType': 'PREF', 'text': 'PROTEIN'},
#  {'from': 1871, 'to': 1877, 'matchType': 'PREF', 'text': 'PROTEIN'},
#  {'from': 1989, 'to': 1995, 'matchType': 'PREF', 'text': 'PROTEIN'},
#  {'from': 2015, 'to': 2022, 'matchType': 'SYN', 'text': 'PROTEINS'},
#  {'from': 2098, 'to': 2104, 'matchType': 'PREF', 'text': 'PROTEIN'},
#  {'from': 2976, 'to': 2982, 'matchType': 'PREF', 'text': 'PROTEIN'}]

# %%
bioportal_mappings = {}
for item in map_d_l:
    mapped_to = item['annotatedClass']['@id']
    for mapped_from_d in item['annotations']:
        if mapped_from_d['text'] not in bioportal_mappings:
            bioportal_mappings[mapped_from_d['text']] = mapped_to
len(bioportal_mappings)
# Out:
# 143

# %%
strToBioMap = {}
for key in strToCuiD:
    original_text = key
    strToBioMap[original_text] = []
    for key_bioportal in bioportal_mappings:
        if key_bioportal in original_text:
            strToBioMap[original_text].append((key_bioportal, bioportal_mappings[key_bioportal]))
len(strToBioMap)
# Out:
# 86

# %%
for key in strToBioMap:
    print(key)
    print(strToBioMap[key])
    break
# Out:
# PROTEINS
# [('PROTEINS', 'http://purl.obolibrary.org/obo/CHEBI_36080'), ('PROTEIN', 'http://purl.obolibrary.org/obo/CHEBI_36080')]

# %% [markdown]
# **skip next 3 cells if not manually reviewing mappings**

# %%
##manually assessing if the mapping is correct for non-exact matches
##do not assess if already mapped in bioportal_map_dict
df_list = []
for key in strToBioMap:
    cui = strToCuiD[key]
    if cui in bioportal_map_dict:
        continue
    else:
        original_text = key
        df_list.append([cui, original_text, strToBioMap[key]])
len(df_list)
# Out:
# 138

# %%
df_ass = pd.DataFrame(df_list, columns = ['cui', 'original_text', 'bioportal_mappings'])
df_ass.head()
# Out:
#         cui                                  original_text  \
# 0  C0596902                    MEMBRANE TRANSPORT PROTEINS
# 1  C0001473                      ADENOSINE TRIPHOSPHATASES
# 2  C0429863  PULSATILITY INDEX, ARTERIAL VELOCITY WAVEFORM
# 3  C0795974       HEREDITARY MACULAR EPIDERMOLYSIS BULLOSA
# 4  C1706912                                        BARRIER
#
#                                   bioportal_mappings
# 0  [(PROTEINS, http://purl.obolibrary.org/obo/CHE...
# 1  [(ADENOSINE, http://purl.obolibrary.org/obo/CH...
# 2  [(VELOCITY, http://purl.obolibrary.org/obo/CHE...
# 3  [(HEREDITARY, http://purl.obolibrary.org/obo/M...
# 4                                                 []

# %%
df_ass.to_csv('cui_to_ontology_maps/bioportal_mappings_unlinked.tsv', index=False, sep='\t')

# %%
##use correct mappings and add to bioportal_map_dict
#if no mapping found, remove triple and assume not-relevant to domain etc.
df_map = pd.read_csv('cui_to_ontology_maps/bioportal_mappings_unlinked_reviewedv2.tsv', sep='\t')
df_map.head()
# Out:
#         cui                                  original_text  \
# 0  C0596902                    MEMBRANE TRANSPORT PROTEINS
# 1  C0001473                      ADENOSINE TRIPHOSPHATASES
# 2  C0429863  PULSATILITY INDEX, ARTERIAL VELOCITY WAVEFORM
# 3  C0795974       HEREDITARY MACULAR EPIDERMOLYSIS BULLOSA
# 4  C1706912                                        BARRIER
#
#                                   bioportal_mappings
# 0  MEMBRANE TRANSPORT', 'http://purl.obolibrary.o...
# 1  [('ADENOSINE', 'http://purl.obolibrary.org/obo...
# 2  [('VELOCITY', 'http://purl.obolibrary.org/obo/...
# 3  'EPIDERMOLYSIS BULLOSA', 'http://purl.obolibra...
# 4                                                 []

# %%
df_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   cui                 138 non-null    object
#  1   original_text       138 non-null    object
#  2   bioportal_mappings  132 non-null    object
# dtypes: object(3)
# memory usage: 3.4+ KB

# %%
#remove rows with no mapping
df_map = df_map.dropna(subset = ['bioportal_mappings'])
df_map = df_map.reset_index()
df_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               132 non-null    int64
#  1   cui                 132 non-null    object
#  2   original_text       132 non-null    object
#  3   bioportal_mappings  132 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 4.2+ KB

# %%
df.head()
# Out:
#   subject_cui                              subject_name       subject_source  \
# 0    C0033684                                  Proteins   AATP1 gene product
# 1    C0596902               Membrane_Transport_Proteins  ATP/ADP transporter
# 2    C0001473                 Adenosine_Triphosphatases               ATPase
# 3    C3816745                                        1+             AtPHT5;1
# 4    C0795974  Hereditary_macular_epidermolysis_bullosa                EBM-2
#
#     predicate         object_source object_cui  \
# 0  Activation  ATP/ADP\ntransporter   C2744579
# 1  Activation                   ATP   C2744579
# 2  Activation                   ATP   C2744579
# 3  Activation              SERPINA1   C0429863
# 4  Activation          RBEC barrier   C1706912
#
#                                      object_name subj_reach_grounding  \
# 0                          ATP8A2_protein,_human         (None, None)
# 1                          ATP8A2_protein,_human         (None, None)
# 2                          ATP8A2_protein,_human         (None, None)
# 3  Pulsatility_index,_arterial_velocity_waveform         (None, None)
# 4                                        BARRIER         (None, None)
#
#         obj_reach_grounding      pmid         year  belief  \
# 0              (None, None)   9545295  1998 Apr 17    0.65
# 1  ('CHEBI', 'CHEBI:15422')   9545295  1998 Apr 17    0.65
# 2  ('CHEBI', 'CHEBI:15422')  17628447     2007 Sep    0.65
# 3           {'UP': 'P01009'  29966288  2018 Jun 29    0.65
# 4              (None, None)  23773766  2013 Jun 18    0.65
#
#                                             sentence predicate_obo  \
# 0  The analysis of both,\ntopological arrangement...    RO_0002436
# 1  ATP import into all types of plastids is media...    RO_0002436
# 2  Proton translocation is crucial in maintaining...    RO_0002436
# 3  The authors found that AtPHT5;1 mediated Pi in...    RO_0002436
# 4  Experimentally determined hydrodynamic radii a...    RO_0002436
#
#   subject_obo   object_obo
# 0              CHEBI_15422
# 1              CHEBI_15422
# 2              CHEBI_15422
# 3   PR_Q8VYM2    PR_P01009
# 4

# %%
df.iloc[0].subject_obo
# Out:
# ''

# %%
#key is CUI and value is OBO identifier
#increased bioportal mappings from 337 to 1287
for i in range(len(df_map.index)):
    cui = df_map.at[i, 'cui']
    mapping = df_map.at[i, 'bioportal_mappings']
    mapping_list = mapping.split(',')
    mapped_obo = mapping_list[-1].strip()
    mapped_obo = mapped_obo.replace("'", '')
    if cui not in bioportal_map_dict:
        bioportal_map_dict[cui] = mapped_obo
len(bioportal_map_dict)
# Out:
# 153

# %%
#get bioportal mappings and add to df
def get_obo_bioportal_mapping(row, col):
    if col == 'subject':
        cui = row['subject_cui']
        mapping = row['subject_obo']
    elif col == 'object':
        cui = row['object_cui']
        mapping = row['object_obo']
    else:
        print('specify if subject or object mapping required')
        exit(0)
    if mapping == '':
        if cui in bioportal_map_dict:
            return bioportal_map_dict[cui]
    else:
        return mapping

# %%
df['subject_obo'] = df.apply(get_obo_bioportal_mapping, axis=1, col='subject')
df.head()
# Out:
#   subject_cui                              subject_name       subject_source  \
# 0    C0033684                                  Proteins   AATP1 gene product
# 1    C0596902               Membrane_Transport_Proteins  ATP/ADP transporter
# 2    C0001473                 Adenosine_Triphosphatases               ATPase
# 3    C3816745                                        1+             AtPHT5;1
# 4    C0795974  Hereditary_macular_epidermolysis_bullosa                EBM-2
#
#     predicate         object_source object_cui  \
# 0  Activation  ATP/ADP\ntransporter   C2744579
# 1  Activation                   ATP   C2744579
# 2  Activation                   ATP   C2744579
# 3  Activation              SERPINA1   C0429863
# 4  Activation          RBEC barrier   C1706912
#
#                                      object_name subj_reach_grounding  \
# 0                          ATP8A2_protein,_human         (None, None)
# 1                          ATP8A2_protein,_human         (None, None)
# 2                          ATP8A2_protein,_human         (None, None)
# 3  Pulsatility_index,_arterial_velocity_waveform         (None, None)
# 4                                        BARRIER         (None, None)
#
#         obj_reach_grounding      pmid         year  belief  \
# 0              (None, None)   9545295  1998 Apr 17    0.65
# 1  ('CHEBI', 'CHEBI:15422')   9545295  1998 Apr 17    0.65
# 2  ('CHEBI', 'CHEBI:15422')  17628447     2007 Sep    0.65
# 3           {'UP': 'P01009'  29966288  2018 Jun 29    0.65
# 4              (None, None)  23773766  2013 Jun 18    0.65
#
#                                             sentence predicate_obo  \
# 0  The analysis of both,\ntopological arrangement...    RO_0002436
# 1  ATP import into all types of plastids is media...    RO_0002436
# 2  Proton translocation is crucial in maintaining...    RO_0002436
# 3  The authors found that AtPHT5;1 mediated Pi in...    RO_0002436
# 4  Experimentally determined hydrodynamic radii a...    RO_0002436
#
#                                     subject_obo   object_obo
# 0  [http://purl.obolibrary.org/obo/CHEBI_36080]  CHEBI_15422
# 1     http://purl.obolibrary.org/obo/GO_0055085  CHEBI_15422
# 2    http://purl.obolibrary.org/obo/CHEBI_16335  CHEBI_15422
# 3                                     PR_Q8VYM2    PR_P01009
# 4      http://purl.obolibrary.org/obo/DOID_2730

# %%
df['object_obo'] = df.apply(get_obo_bioportal_mapping, axis=1, col='object')
df.head()
# Out:
#   subject_cui                              subject_name       subject_source  \
# 0    C0033684                                  Proteins   AATP1 gene product
# 1    C0596902               Membrane_Transport_Proteins  ATP/ADP transporter
# 2    C0001473                 Adenosine_Triphosphatases               ATPase
# 3    C3816745                                        1+             AtPHT5;1
# 4    C0795974  Hereditary_macular_epidermolysis_bullosa                EBM-2
#
#     predicate         object_source object_cui  \
# 0  Activation  ATP/ADP\ntransporter   C2744579
# 1  Activation                   ATP   C2744579
# 2  Activation                   ATP   C2744579
# 3  Activation              SERPINA1   C0429863
# 4  Activation          RBEC barrier   C1706912
#
#                                      object_name subj_reach_grounding  \
# 0                          ATP8A2_protein,_human         (None, None)
# 1                          ATP8A2_protein,_human         (None, None)
# 2                          ATP8A2_protein,_human         (None, None)
# 3  Pulsatility_index,_arterial_velocity_waveform         (None, None)
# 4                                        BARRIER         (None, None)
#
#         obj_reach_grounding      pmid         year  belief  \
# 0              (None, None)   9545295  1998 Apr 17    0.65
# 1  ('CHEBI', 'CHEBI:15422')   9545295  1998 Apr 17    0.65
# 2  ('CHEBI', 'CHEBI:15422')  17628447     2007 Sep    0.65
# 3           {'UP': 'P01009'  29966288  2018 Jun 29    0.65
# 4              (None, None)  23773766  2013 Jun 18    0.65
#
#                                             sentence predicate_obo  \
# 0  The analysis of both,\ntopological arrangement...    RO_0002436
# 1  ATP import into all types of plastids is media...    RO_0002436
# 2  Proton translocation is crucial in maintaining...    RO_0002436
# 3  The authors found that AtPHT5;1 mediated Pi in...    RO_0002436
# 4  Experimentally determined hydrodynamic radii a...    RO_0002436
#
#                                     subject_obo   object_obo
# 0  [http://purl.obolibrary.org/obo/CHEBI_36080]  CHEBI_15422
# 1     http://purl.obolibrary.org/obo/GO_0055085  CHEBI_15422
# 2    http://purl.obolibrary.org/obo/CHEBI_16335  CHEBI_15422
# 3                                     PR_Q8VYM2    PR_P01009
# 4      http://purl.obolibrary.org/obo/DOID_2730           []

# %%
df.head(10)
# Out:
#   subject_cui                              subject_name       subject_source  \
# 0    C0033684                                  Proteins   AATP1 gene product
# 1    C0596902               Membrane_Transport_Proteins  ATP/ADP transporter
# 2    C0001473                 Adenosine_Triphosphatases               ATPase
# 3    C3816745                                        1+             AtPHT5;1
# 4    C0795974  Hereditary_macular_epidermolysis_bullosa                EBM-2
# 5                                                                      EGM-2
# 6    C0014442                                   Enzymes               Enzyme
# 7    C0014442                                   Enzymes               Enzyme
# 8    C0014442                                   Enzymes               Enzyme
# 9                                                                     Gharib
#
#     predicate               object_source object_cui  \
# 0  Activation        ATP/ADP\ntransporter   C2744579
# 1  Activation                         ATP   C2744579
# 2  Activation                         ATP   C2744579
# 3  Activation                    SERPINA1   C0429863
# 4  Activation                RBEC barrier   C1706912
# 5  Activation                RBEC barrier   C1706912
# 6  Activation                    floppase
# 7  Activation  phospholipid translocation   C2247788
# 8  Activation                        P4HB
# 9  Activation       inflammatory response   C0021368
#
#                                      object_name subj_reach_grounding  \
# 0                          ATP8A2_protein,_human         (None, None)
# 1                          ATP8A2_protein,_human         (None, None)
# 2                          ATP8A2_protein,_human         (None, None)
# 3  Pulsatility_index,_arterial_velocity_waveform         (None, None)
# 4                                        BARRIER         (None, None)
# 5                                        BARRIER         (None, None)
# 6                                                        (None, None)
# 7                                       flippase         (None, None)
# 8                                                        (None, None)
# 9                                   Inflammation         (None, None)
#
#         obj_reach_grounding      pmid         year  belief  \
# 0              (None, None)   9545295  1998 Apr 17    0.65
# 1  ('CHEBI', 'CHEBI:15422')   9545295  1998 Apr 17    0.65
# 2  ('CHEBI', 'CHEBI:15422')  17628447     2007 Sep    0.65
# 3           {'UP': 'P01009'  29966288  2018 Jun 29    0.65
# 4              (None, None)  23773766  2013 Jun 18    0.65
# 5              (None, None)  23773766  2013 Jun 18    0.65
# 6              (None, None)  24867949   2014 Jul 4    0.65
# 7      ('GO', 'GO:0045332')  24867949   2014 Jul 4    0.65
# 8           {'UP': 'P07237'  24867949   2014 Jul 4    0.65
# 9      ('GO', 'GO:0006954')  24867949   2014 Jul 4    0.65
#
#                                             sentence predicate_obo  \
# 0  The analysis of both,\ntopological arrangement...    RO_0002436
# 1  ATP import into all types of plastids is media...    RO_0002436
# 2  Proton translocation is crucial in maintaining...    RO_0002436
# 3  The authors found that AtPHT5;1 mediated Pi in...    RO_0002436
# 4  Experimentally determined hydrodynamic radii a...    RO_0002436
# 5  Experimentally determined hydrodynamic radii a...    RO_0002436
# 6  Enzyme activation was also abrogated by inhibi...    RO_0002436
# 7  Enzyme activation was also abrogated by inhibi...    RO_0002436
# 8  Enzyme activation was also abrogated by inhibi...    RO_0002436
# 9  Gharib, B., Hanna, S., Abdallahi, O. M. S., Le...    RO_0002436
#
#                                     subject_obo   object_obo
# 0  [http://purl.obolibrary.org/obo/CHEBI_36080]  CHEBI_15422
# 1     http://purl.obolibrary.org/obo/GO_0055085  CHEBI_15422
# 2    http://purl.obolibrary.org/obo/CHEBI_16335  CHEBI_15422
# 3                                     PR_Q8VYM2    PR_P01009
# 4      http://purl.obolibrary.org/obo/DOID_2730           []
# 5                                          None           []
# 6                                            []         None
# 7                                            []   GO_0045332
# 8                                            []    PR_P07237
# 9                                          None   GO_0006954

# %%
#drop rows with [] mapping
df = df.loc[df['subject_obo'] != '[]']
df = df.loc[df['object_obo'] != '[]']
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#   subject_cui                 subject_name       subject_source   predicate  \
# 0    C0033684                     Proteins   AATP1 gene product  Activation
# 1    C0596902  Membrane_Transport_Proteins  ATP/ADP transporter  Activation
# 2    C0001473    Adenosine_Triphosphatases               ATPase  Activation
# 3    C3816745                           1+             AtPHT5;1  Activation
# 4                                                        Gharib  Activation
#
#            object_source object_cui  \
# 0   ATP/ADP\ntransporter   C2744579
# 1                    ATP   C2744579
# 2                    ATP   C2744579
# 3               SERPINA1   C0429863
# 4  inflammatory response   C0021368
#
#                                      object_name subj_reach_grounding  \
# 0                          ATP8A2_protein,_human         (None, None)
# 1                          ATP8A2_protein,_human         (None, None)
# 2                          ATP8A2_protein,_human         (None, None)
# 3  Pulsatility_index,_arterial_velocity_waveform         (None, None)
# 4                                   Inflammation         (None, None)
#
#         obj_reach_grounding      pmid         year  belief  \
# 0              (None, None)   9545295  1998 Apr 17    0.65
# 1  ('CHEBI', 'CHEBI:15422')   9545295  1998 Apr 17    0.65
# 2  ('CHEBI', 'CHEBI:15422')  17628447     2007 Sep    0.65
# 3           {'UP': 'P01009'  29966288  2018 Jun 29    0.65
# 4      ('GO', 'GO:0006954')  24867949   2014 Jul 4    0.65
#
#                                             sentence predicate_obo  \
# 0  The analysis of both,\ntopological arrangement...    RO_0002436
# 1  ATP import into all types of plastids is media...    RO_0002436
# 2  Proton translocation is crucial in maintaining...    RO_0002436
# 3  The authors found that AtPHT5;1 mediated Pi in...    RO_0002436
# 4  Gharib, B., Hanna, S., Abdallahi, O. M. S., Le...    RO_0002436
#
#                                     subject_obo   object_obo
# 0  [http://purl.obolibrary.org/obo/CHEBI_36080]  CHEBI_15422
# 1     http://purl.obolibrary.org/obo/GO_0055085  CHEBI_15422
# 2    http://purl.obolibrary.org/obo/CHEBI_16335  CHEBI_15422
# 3                                     PR_Q8VYM2    PR_P01009
# 4                                          None   GO_0006954

# %%
def add_prefix(row, col):
    obo_prefix = 'http://purl.obolibrary.org/obo/'
    if col == 'predicate':
        predicate_obo = row['predicate_obo']
        return obo_prefix+predicate_obo
    elif col == 'subject':
        subject_obo = row['subject_obo']
        if isinstance(subject_obo, list) and subject_obo:
            subject_obo = subject_obo[0]
        if subject_obo == None:
            return ''
        subject_obo = subject_obo.replace(']', '')
        subject_obo = subject_obo.replace('[', '')
        subject_obo = subject_obo.replace(')', '')
        subject_obo = subject_obo.replace('(', '')
        if 'http' not in subject_obo:
            return obo_prefix+subject_obo
        else:
            return subject_obo
    elif col == 'object':
        object_obo = row['object_obo']
        if isinstance(object_obo, list) and object_obo:
            object_obo = object_obo[0]
        if object_obo == None:
            return ''
        object_obo = object_obo.replace(']', '')
        object_obo = object_obo.replace('[', '')
        object_obo = object_obo.replace(')', '')
        object_obo = object_obo.replace('(', '')
        if 'http' not in object_obo:
            return obo_prefix+object_obo
        else:
            return object_obo

# %%
#add OBO identifiers to the OBO mappings (where not present) - see df
#drop rows with no mappings
df['subject_obo'] = df.apply(add_prefix, axis=1, col='subject')
df['object_obo'] = df.apply(add_prefix, axis=1, col='object')
df['predicate_obo'] = df.apply(add_prefix, axis=1, col='predicate')

# %%
df.head(20)
# Out:
#    subject_cui                                       subject_name  \
# 0     C0033684                                           Proteins
# 1     C0596902                        Membrane_Transport_Proteins
# 2     C0001473                          Adenosine_Triphosphatases
# 3     C3816745                                                 1+
# 4
# 5     C0025611                                    Methamphetamine
# 6     C1138348                          moira_protein,_Drosophila
# 7     C1955978  National_Institute_on_Deafness_and_Other_Commu...
# 8     C0080093                     N-Methyl-D-Aspartate_Receptors
# 9     C0080093                     N-Methyl-D-Aspartate_Receptors
# 10    C0080093                     N-Methyl-D-Aspartate_Receptors
# 11
# 12
# 13    C1999216                                          Inhibitor
# 14
# 15
# 16    C0040028                         Thrombocythemia,_Essential
# 17
# 18
# 19    C0242821                                         Human_body
#
#                subject_source   predicate          object_source object_cui  \
# 0          AATP1 gene product  Activation   ATP/ADP\ntransporter   C2744579
# 1         ATP/ADP transporter  Activation                    ATP   C2744579
# 2                      ATPase  Activation                    ATP   C2744579
# 3                    AtPHT5;1  Activation               SERPINA1   C0429863
# 4                      Gharib  Activation  inflammatory response   C0021368
# 5                        METH  Activation                   'ﬁ'}
# 6                         MOR  Activation                   'ﬁ'}
# 7        NIDCD training grant  Activation                     PK   C0034348
# 8               NMDA-receptor  Activation               diazepam   C0012010
# 9                       NMDAR  Activation        carbon monoxide   C3245499
# 10                      NMDAR  Activation              Poisoning   C0032344
# 11                      NPDPA  Activation                    ATP   C2744579
# 12                       OXA-  Activation      apoptotic process   C0162638
# 13              P2X inhibitor  Activation                    ATP   C2744579
# 14                    SFB 171  Activation   biosynthetic process   C0220781
# 15                  Salomon D  Activation                     GJ   C0110611
# 16        Silvi et al.,31b,32  Activation                   'Ψ'}
# 17  TNF  stimulation antibody  Activation               SLC22A12   C1425219
# 18                 a5GA- BAAR  Activation   tonic GABAA receptor   C0034807
# 19         anti- body IgG#105  Activation                  P2RX4   C1418213
#
#                                       object_name subj_reach_grounding  \
# 0                           ATP8A2_protein,_human         (None, None)
# 1                           ATP8A2_protein,_human         (None, None)
# 2                           ATP8A2_protein,_human         (None, None)
# 3   Pulsatility_index,_arterial_velocity_waveform         (None, None)
# 4                                    Inflammation         (None, None)
# 5                                                         (None, None)
# 6                                                         (None, None)
# 7                                 Pyruvate_Kinase         (None, None)
# 8                                        Diazepam         (None, None)
# 9                                        Colombia         (None, None)
# 10                              Poisoning_aspects         (None, None)
# 11                          ATP8A2_protein,_human         (None, None)
# 12                                      Apoptosis         (None, None)
# 13                          ATP8A2_protein,_human         (None, None)
# 14                                      Anabolism         (None, None)
# 15                                      Connexins         (None, None)
# 16                                                        (None, None)
# 17                                  SLC22A12_gene         (None, None)
# 18                                GABA-A_Receptor         (None, None)
# 19                                     P2RX4_gene         (None, None)
#
#          obj_reach_grounding      pmid         year  belief  \
# 0               (None, None)   9545295  1998 Apr 17    0.65
# 1   ('CHEBI', 'CHEBI:15422')   9545295  1998 Apr 17    0.65
# 2   ('CHEBI', 'CHEBI:15422')  17628447     2007 Sep    0.65
# 3            {'UP': 'P01009'  29966288  2018 Jun 29    0.65
# 4       ('GO', 'GO:0006954')  24867949   2014 Jul 4    0.65
# 5               (None, None)  25262913     2016 Jan    0.65
# 6               (None, None)  25262913     2016 Jan    0.65
# 7               (None, None)  20665236     2010 Aug    0.65
# 8   ('CHEBI', 'CHEBI:49575')  15509230     2004 Nov    0.65
# 9   ('CHEBI', 'CHEBI:17245')  14761684   2004 Feb 1    0.65
# 10       ('MESH', 'D011041')  14761684   2004 Feb 1    0.65
# 11  ('CHEBI', 'CHEBI:15422')  25637762   2015 Apr 1    0.65
# 12      ('GO', 'GO:0006915')  29436100     2018 May    0.65
# 13  ('CHEBI', 'CHEBI:15422')  31045747     2019 Sep    0.65
# 14      ('GO', 'GO:0009058')   9545295  1998 Apr 17    0.65
# 15       'HGNC_GROUP': '314'  10084314     1999 Mar    0.65
# 16              (None, None)  26574358  2015 Apr 14    0.65
# 17           {'UP': 'Q96S37'  22426328   2012 May 2    0.65
# 18              (None, None)  16930441     2006 Aug    0.65
# 19           {'UP': 'Q99571'  31045747     2019 Sep    0.65
#
#                                              sentence  \
# 0   The analysis of both,\ntopological arrangement...
# 1   ATP import into all types of plastids is media...
# 2   Proton translocation is crucial in maintaining...
# 3   The authors found that AtPHT5;1 mediated Pi in...
# 4   Gharib, B., Hanna, S., Abdallahi, O. M. S., Le...
# 5   METH and MOR induced a signiﬁcant conditioned ...
# 6   METH and MOR induced a signiﬁcant conditioned ...
# 7   PK was supported by NIDCD training grant T32 D...
# 8   Furthermore, N-methyl-D-aspartate (NMDA)-recep...
# 9   Oxidative stress has been reported to stimulat...
# 10  Oxidative stress has been reported to stimulat...
# 11  Benzedrone,  diclo- fensine,  glaucine,  naphy...
# 12  in Parental cell In addition, In sum, our expe...
# 13  Addition of IgG#151-LO or the nonselective P2X...
# 14  Since IPTG induction al-\nlowed synthesis of a...
# 15  J Invest Dermatol 111:72–76, 1998\nMasgrau-Pey...
# 16  In this way, it is possible to ﬁnd monosynapti...
# 17  TNF˛ stimulation antibody  blocks  ferritin  d...
# 18  a5-containing GABAA receptors (a5GA- BAAR) con...
# 19  The P2X4-potentiating anti- body IgG#105 ident...
#
#                                 predicate_obo  \
# 0   http://purl.obolibrary.org/obo/RO_0002436
# 1   http://purl.obolibrary.org/obo/RO_0002436
# 2   http://purl.obolibrary.org/obo/RO_0002436
# 3   http://purl.obolibrary.org/obo/RO_0002436
# 4   http://purl.obolibrary.org/obo/RO_0002436
# 5   http://purl.obolibrary.org/obo/RO_0002436
# 6   http://purl.obolibrary.org/obo/RO_0002436
# 7   http://purl.obolibrary.org/obo/RO_0002436
# 8   http://purl.obolibrary.org/obo/RO_0002436
# 9   http://purl.obolibrary.org/obo/RO_0002436
# 10  http://purl.obolibrary.org/obo/RO_0002436
# 11  http://purl.obolibrary.org/obo/RO_0002436
# 12  http://purl.obolibrary.org/obo/RO_0002436
# 13  http://purl.obolibrary.org/obo/RO_0002436
# 14  http://purl.obolibrary.org/obo/RO_0002436
# 15  http://purl.obolibrary.org/obo/RO_0002436
# 16  http://purl.obolibrary.org/obo/RO_0002436
# 17  http://purl.obolibrary.org/obo/RO_0002436
# 18  http://purl.obolibrary.org/obo/RO_0002436
# 19  http://purl.obolibrary.org/obo/RO_0002436
#
#                                       subject_obo  \
# 0      http://purl.obolibrary.org/obo/CHEBI_36080
# 1       http://purl.obolibrary.org/obo/GO_0055085
# 2      http://purl.obolibrary.org/obo/CHEBI_16335
# 3        http://purl.obolibrary.org/obo/PR_Q8VYM2
# 4
# 5       http://purl.obolibrary.org/obo/CHEBI_6809
# 6     http://purl.obolibrary.org/obo/NCBITaxon_72
# 7    http://purl.obolibrary.org/obo/MONDO_0005365
# 8      http://purl.obolibrary.org/obo/CHEBI_31882
# 9      http://purl.obolibrary.org/obo/CHEBI_31882
# 10     http://purl.obolibrary.org/obo/CHEBI_31882
# 11
# 12
# 13     http://purl.obolibrary.org/obo/CHEBI_35222
# 14
# 15
# 16       http://purl.obolibrary.org/obo/PR_O43934
# 17
# 18
# 19  http://purl.obolibrary.org/obo/UBERON_0013702
#
#                                       object_obo
# 0     http://purl.obolibrary.org/obo/CHEBI_15422
# 1     http://purl.obolibrary.org/obo/CHEBI_15422
# 2     http://purl.obolibrary.org/obo/CHEBI_15422
# 3       http://purl.obolibrary.org/obo/PR_P01009
# 4      http://purl.obolibrary.org/obo/GO_0006954
# 5
# 6
# 7     http://purl.obolibrary.org/obo/CHEBI_15361
# 8     http://purl.obolibrary.org/obo/CHEBI_49575
# 9     http://purl.obolibrary.org/obo/CHEBI_17245
# 10  http://purl.obolibrary.org/obo/MONDO_0029000
# 11    http://purl.obolibrary.org/obo/CHEBI_15422
# 12     http://purl.obolibrary.org/obo/GO_0006915
# 13    http://purl.obolibrary.org/obo/CHEBI_15422
# 14     http://purl.obolibrary.org/obo/GO_0009058
# 15         http://purl.obolibrary.org/obo/PR_314
# 16
# 17      http://purl.obolibrary.org/obo/PR_Q96S37
# 18    http://purl.obolibrary.org/obo/CHEBI_16865
# 19      http://purl.obolibrary.org/obo/PR_Q99571

# %%
obo_prefix = 'http://purl.obolibrary.org/obo/'

# %%
#remove all rows with blank obo mappings and only prefix rows
df_new = df[df['subject_obo'] != '']
df_new = df_new[df_new['subject_obo'] != obo_prefix]
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 411 entries, 0 to 461
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   subject_cui           411 non-null    object
#  1   subject_name          411 non-null    object
#  2   subject_source        411 non-null    object
#  3   predicate             411 non-null    object
#  4   object_source         411 non-null    object
#  5   object_cui            411 non-null    object
#  6   object_name           411 non-null    object
#  7   subj_reach_grounding  411 non-null    object
#  8   obj_reach_grounding   411 non-null    object
#  9   pmid                  411 non-null    int64
#  10  year                  411 non-null    object
#  11  belief                411 non-null    float64
#  12  sentence              411 non-null    object
#  13  predicate_obo         411 non-null    object
#  14  subject_obo           411 non-null    object
#  15  object_obo            411 non-null    object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 54.6+ KB

# %%
df_new = df_new[df_new['object_obo'] != '']
df_new = df_new[df_new['object_obo'] != obo_prefix]
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 368 entries, 0 to 461
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   subject_cui           368 non-null    object
#  1   subject_name          368 non-null    object
#  2   subject_source        368 non-null    object
#  3   predicate             368 non-null    object
#  4   object_source         368 non-null    object
#  5   object_cui            368 non-null    object
#  6   object_name           368 non-null    object
#  7   subj_reach_grounding  368 non-null    object
#  8   obj_reach_grounding   368 non-null    object
#  9   pmid                  368 non-null    int64
#  10  year                  368 non-null    object
#  11  belief                368 non-null    float64
#  12  sentence              368 non-null    object
#  13  predicate_obo         368 non-null    object
#  14  subject_obo           368 non-null    object
#  15  object_obo            368 non-null    object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 48.9+ KB

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 368 entries, 0 to 461
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   subject_cui           368 non-null    object
#  1   subject_name          368 non-null    object
#  2   subject_source        368 non-null    object
#  3   predicate             368 non-null    object
#  4   object_source         368 non-null    object
#  5   object_cui            368 non-null    object
#  6   object_name           368 non-null    object
#  7   subj_reach_grounding  368 non-null    object
#  8   obj_reach_grounding   368 non-null    object
#  9   pmid                  368 non-null    int64
#  10  year                  368 non-null    object
#  11  belief                368 non-null    float64
#  12  sentence              368 non-null    object
#  13  predicate_obo         368 non-null    object
#  14  subject_obo           368 non-null    object
#  15  object_obo            368 non-null    object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 48.9+ KB

# %%
df_new = df_new.drop_duplicates()
df_new.head()
# Out:
#   subject_cui                                       subject_name  \
# 0    C0033684                                           Proteins
# 1    C0596902                        Membrane_Transport_Proteins
# 2    C0001473                          Adenosine_Triphosphatases
# 3    C3816745                                                 1+
# 7    C1955978  National_Institute_on_Deafness_and_Other_Commu...
#
#          subject_source   predicate         object_source object_cui  \
# 0    AATP1 gene product  Activation  ATP/ADP\ntransporter   C2744579
# 1   ATP/ADP transporter  Activation                   ATP   C2744579
# 2                ATPase  Activation                   ATP   C2744579
# 3              AtPHT5;1  Activation              SERPINA1   C0429863
# 7  NIDCD training grant  Activation                    PK   C0034348
#
#                                      object_name subj_reach_grounding  \
# 0                          ATP8A2_protein,_human         (None, None)
# 1                          ATP8A2_protein,_human         (None, None)
# 2                          ATP8A2_protein,_human         (None, None)
# 3  Pulsatility_index,_arterial_velocity_waveform         (None, None)
# 7                                Pyruvate_Kinase         (None, None)
#
#         obj_reach_grounding      pmid         year  belief  \
# 0              (None, None)   9545295  1998 Apr 17    0.65
# 1  ('CHEBI', 'CHEBI:15422')   9545295  1998 Apr 17    0.65
# 2  ('CHEBI', 'CHEBI:15422')  17628447     2007 Sep    0.65
# 3           {'UP': 'P01009'  29966288  2018 Jun 29    0.65
# 7              (None, None)  20665236     2010 Aug    0.65
#
#                                             sentence  \
# 0  The analysis of both,\ntopological arrangement...
# 1  ATP import into all types of plastids is media...
# 2  Proton translocation is crucial in maintaining...
# 3  The authors found that AtPHT5;1 mediated Pi in...
# 7  PK was supported by NIDCD training grant T32 D...
#
#                                predicate_obo  \
# 0  http://purl.obolibrary.org/obo/RO_0002436
# 1  http://purl.obolibrary.org/obo/RO_0002436
# 2  http://purl.obolibrary.org/obo/RO_0002436
# 3  http://purl.obolibrary.org/obo/RO_0002436
# 7  http://purl.obolibrary.org/obo/RO_0002436
#
#                                     subject_obo  \
# 0    http://purl.obolibrary.org/obo/CHEBI_36080
# 1     http://purl.obolibrary.org/obo/GO_0055085
# 2    http://purl.obolibrary.org/obo/CHEBI_16335
# 3      http://purl.obolibrary.org/obo/PR_Q8VYM2
# 7  http://purl.obolibrary.org/obo/MONDO_0005365
#
#                                    object_obo
# 0  http://purl.obolibrary.org/obo/CHEBI_15422
# 1  http://purl.obolibrary.org/obo/CHEBI_15422
# 2  http://purl.obolibrary.org/obo/CHEBI_15422
# 3    http://purl.obolibrary.org/obo/PR_P01009
# 7  http://purl.obolibrary.org/obo/CHEBI_15361

# %%
#save all mapping dict and labels as node labels file --use the dictionaries or the dataframe
#(go_hpo, bioportal, predmap, )
df_new.to_csv('predication_files/kratom_pmid_all_predicates_umls_processed.tsv', sep='\t', index=False)

# %%
df_new = df_new.reset_index(drop=True)
df_new.head()
# Out:
#   subject_cui                                       subject_name  \
# 0    C0033684                                           Proteins
# 1    C0596902                        Membrane_Transport_Proteins
# 2    C0001473                          Adenosine_Triphosphatases
# 3    C3816745                                                 1+
# 4    C1955978  National_Institute_on_Deafness_and_Other_Commu...
#
#          subject_source   predicate         object_source object_cui  \
# 0    AATP1 gene product  Activation  ATP/ADP\ntransporter   C2744579
# 1   ATP/ADP transporter  Activation                   ATP   C2744579
# 2                ATPase  Activation                   ATP   C2744579
# 3              AtPHT5;1  Activation              SERPINA1   C0429863
# 4  NIDCD training grant  Activation                    PK   C0034348
#
#                                      object_name subj_reach_grounding  \
# 0                          ATP8A2_protein,_human         (None, None)
# 1                          ATP8A2_protein,_human         (None, None)
# 2                          ATP8A2_protein,_human         (None, None)
# 3  Pulsatility_index,_arterial_velocity_waveform         (None, None)
# 4                                Pyruvate_Kinase         (None, None)
#
#         obj_reach_grounding      pmid         year  belief  \
# 0              (None, None)   9545295  1998 Apr 17    0.65
# 1  ('CHEBI', 'CHEBI:15422')   9545295  1998 Apr 17    0.65
# 2  ('CHEBI', 'CHEBI:15422')  17628447     2007 Sep    0.65
# 3           {'UP': 'P01009'  29966288  2018 Jun 29    0.65
# 4              (None, None)  20665236     2010 Aug    0.65
#
#                                             sentence  \
# 0  The analysis of both,\ntopological arrangement...
# 1  ATP import into all types of plastids is media...
# 2  Proton translocation is crucial in maintaining...
# 3  The authors found that AtPHT5;1 mediated Pi in...
# 4  PK was supported by NIDCD training grant T32 D...
#
#                                predicate_obo  \
# 0  http://purl.obolibrary.org/obo/RO_0002436
# 1  http://purl.obolibrary.org/obo/RO_0002436
# 2  http://purl.obolibrary.org/obo/RO_0002436
# 3  http://purl.obolibrary.org/obo/RO_0002436
# 4  http://purl.obolibrary.org/obo/RO_0002436
#
#                                     subject_obo  \
# 0    http://purl.obolibrary.org/obo/CHEBI_36080
# 1     http://purl.obolibrary.org/obo/GO_0055085
# 2    http://purl.obolibrary.org/obo/CHEBI_16335
# 3      http://purl.obolibrary.org/obo/PR_Q8VYM2
# 4  http://purl.obolibrary.org/obo/MONDO_0005365
#
#                                    object_obo
# 0  http://purl.obolibrary.org/obo/CHEBI_15422
# 1  http://purl.obolibrary.org/obo/CHEBI_15422
# 2  http://purl.obolibrary.org/obo/CHEBI_15422
# 3    http://purl.obolibrary.org/obo/PR_P01009
# 4  http://purl.obolibrary.org/obo/CHEBI_15361

# %%
##fix mappings for predicates
df_new = pd.read_csv('predication_files/kratom_pmid_all_predicates_umls_processed.tsv', sep='\t')
df_new.head()
# Out:
#   subject_cui                                       subject_name  \
# 0    C0033684                                           Proteins
# 1    C0596902                        Membrane_Transport_Proteins
# 2    C0001473                          Adenosine_Triphosphatases
# 3    C3816745                                                 1+
# 4    C1955978  National_Institute_on_Deafness_and_Other_Commu...
#
#          subject_source   predicate         object_source object_cui  \
# 0    AATP1 gene product  Activation  ATP/ADP\ntransporter   C2744579
# 1   ATP/ADP transporter  Activation                   ATP   C2744579
# 2                ATPase  Activation                   ATP   C2744579
# 3              AtPHT5;1  Activation              SERPINA1   C0429863
# 4  NIDCD training grant  Activation                    PK   C0034348
#
#                                      object_name subj_reach_grounding  \
# 0                          ATP8A2_protein,_human         (None, None)
# 1                          ATP8A2_protein,_human         (None, None)
# 2                          ATP8A2_protein,_human         (None, None)
# 3  Pulsatility_index,_arterial_velocity_waveform         (None, None)
# 4                                Pyruvate_Kinase         (None, None)
#
#         obj_reach_grounding      pmid         year  belief  \
# 0              (None, None)   9545295  1998 Apr 17    0.65
# 1  ('CHEBI', 'CHEBI:15422')   9545295  1998 Apr 17    0.65
# 2  ('CHEBI', 'CHEBI:15422')  17628447     2007 Sep    0.65
# 3           {'UP': 'P01009'  29966288  2018 Jun 29    0.65
# 4              (None, None)  20665236     2010 Aug    0.65
#
#                                             sentence  \
# 0  The analysis of both,\ntopological arrangement...
# 1  ATP import into all types of plastids is media...
# 2  Proton translocation is crucial in maintaining...
# 3  The authors found that AtPHT5;1 mediated Pi in...
# 4  PK was supported by NIDCD training grant T32 D...
#
#                                predicate_obo  \
# 0  http://purl.obolibrary.org/obo/RO_0002436
# 1  http://purl.obolibrary.org/obo/RO_0002436
# 2  http://purl.obolibrary.org/obo/RO_0002436
# 3  http://purl.obolibrary.org/obo/RO_0002436
# 4  http://purl.obolibrary.org/obo/RO_0002436
#
#                                     subject_obo  \
# 0    http://purl.obolibrary.org/obo/CHEBI_36080
# 1     http://purl.obolibrary.org/obo/GO_0055085
# 2    http://purl.obolibrary.org/obo/CHEBI_16335
# 3      http://purl.obolibrary.org/obo/PR_Q8VYM2
# 4  http://purl.obolibrary.org/obo/MONDO_0005365
#
#                                    object_obo
# 0  http://purl.obolibrary.org/obo/CHEBI_15422
# 1  http://purl.obolibrary.org/obo/CHEBI_15422
# 2  http://purl.obolibrary.org/obo/CHEBI_15422
# 3    http://purl.obolibrary.org/obo/PR_P01009
# 4  http://purl.obolibrary.org/obo/CHEBI_15361

# %%
df_new.iloc[0]['predicate'].lower()
# Out:
# 'activation'

# %%
prefix = 'http://purl.obolibrary.org/obo/'
def fix_predicates(row):
    pred = row['predicate'].lower()
    pred_new = predMapD[pred]
    return prefix+pred_new

# %%
df_new['predicate_obo'] = ''
df_new.head()
# Out:
#   subject_cui                                       subject_name  \
# 0    C0033684                                           Proteins
# 1    C0596902                        Membrane_Transport_Proteins
# 2    C0001473                          Adenosine_Triphosphatases
# 3    C3816745                                                 1+
# 4    C1955978  National_Institute_on_Deafness_and_Other_Commu...
#
#          subject_source   predicate         object_source object_cui  \
# 0    AATP1 gene product  Activation  ATP/ADP\ntransporter   C2744579
# 1   ATP/ADP transporter  Activation                   ATP   C2744579
# 2                ATPase  Activation                   ATP   C2744579
# 3              AtPHT5;1  Activation              SERPINA1   C0429863
# 4  NIDCD training grant  Activation                    PK   C0034348
#
#                                      object_name subj_reach_grounding  \
# 0                          ATP8A2_protein,_human         (None, None)
# 1                          ATP8A2_protein,_human         (None, None)
# 2                          ATP8A2_protein,_human         (None, None)
# 3  Pulsatility_index,_arterial_velocity_waveform         (None, None)
# 4                                Pyruvate_Kinase         (None, None)
#
#         obj_reach_grounding      pmid         year  belief  \
# 0              (None, None)   9545295  1998 Apr 17    0.65
# 1  ('CHEBI', 'CHEBI:15422')   9545295  1998 Apr 17    0.65
# 2  ('CHEBI', 'CHEBI:15422')  17628447     2007 Sep    0.65
# 3           {'UP': 'P01009'  29966288  2018 Jun 29    0.65
# 4              (None, None)  20665236     2010 Aug    0.65
#
#                                             sentence predicate_obo  \
# 0  The analysis of both,\ntopological arrangement...
# 1  ATP import into all types of plastids is media...
# 2  Proton translocation is crucial in maintaining...
# 3  The authors found that AtPHT5;1 mediated Pi in...
# 4  PK was supported by NIDCD training grant T32 D...
#
#                                     subject_obo  \
# 0    http://purl.obolibrary.org/obo/CHEBI_36080
# 1     http://purl.obolibrary.org/obo/GO_0055085
# 2    http://purl.obolibrary.org/obo/CHEBI_16335
# 3      http://purl.obolibrary.org/obo/PR_Q8VYM2
# 4  http://purl.obolibrary.org/obo/MONDO_0005365
#
#                                    object_obo
# 0  http://purl.obolibrary.org/obo/CHEBI_15422
# 1  http://purl.obolibrary.org/obo/CHEBI_15422
# 2  http://purl.obolibrary.org/obo/CHEBI_15422
# 3    http://purl.obolibrary.org/obo/PR_P01009
# 4  http://purl.obolibrary.org/obo/CHEBI_15361

# %%
df_new['predicate_obo'] = df_new.apply(fix_predicates, axis=1)
df_new.head()
# Out:
#   subject_cui                                       subject_name  \
# 0    C0033684                                           Proteins
# 1    C0596902                        Membrane_Transport_Proteins
# 2    C0001473                          Adenosine_Triphosphatases
# 3    C3816745                                                 1+
# 4    C1955978  National_Institute_on_Deafness_and_Other_Commu...
#
#          subject_source   predicate         object_source object_cui  \
# 0    AATP1 gene product  Activation  ATP/ADP\ntransporter   C2744579
# 1   ATP/ADP transporter  Activation                   ATP   C2744579
# 2                ATPase  Activation                   ATP   C2744579
# 3              AtPHT5;1  Activation              SERPINA1   C0429863
# 4  NIDCD training grant  Activation                    PK   C0034348
#
#                                      object_name subj_reach_grounding  \
# 0                          ATP8A2_protein,_human         (None, None)
# 1                          ATP8A2_protein,_human         (None, None)
# 2                          ATP8A2_protein,_human         (None, None)
# 3  Pulsatility_index,_arterial_velocity_waveform         (None, None)
# 4                                Pyruvate_Kinase         (None, None)
#
#         obj_reach_grounding      pmid         year  belief  \
# 0              (None, None)   9545295  1998 Apr 17    0.65
# 1  ('CHEBI', 'CHEBI:15422')   9545295  1998 Apr 17    0.65
# 2  ('CHEBI', 'CHEBI:15422')  17628447     2007 Sep    0.65
# 3           {'UP': 'P01009'  29966288  2018 Jun 29    0.65
# 4              (None, None)  20665236     2010 Aug    0.65
#
#                                             sentence  \
# 0  The analysis of both,\ntopological arrangement...
# 1  ATP import into all types of plastids is media...
# 2  Proton translocation is crucial in maintaining...
# 3  The authors found that AtPHT5;1 mediated Pi in...
# 4  PK was supported by NIDCD training grant T32 D...
#
#                                predicate_obo  \
# 0  http://purl.obolibrary.org/obo/RO_0002448
# 1  http://purl.obolibrary.org/obo/RO_0002448
# 2  http://purl.obolibrary.org/obo/RO_0002448
# 3  http://purl.obolibrary.org/obo/RO_0002448
# 4  http://purl.obolibrary.org/obo/RO_0002448
#
#                                     subject_obo  \
# 0    http://purl.obolibrary.org/obo/CHEBI_36080
# 1     http://purl.obolibrary.org/obo/GO_0055085
# 2    http://purl.obolibrary.org/obo/CHEBI_16335
# 3      http://purl.obolibrary.org/obo/PR_Q8VYM2
# 4  http://purl.obolibrary.org/obo/MONDO_0005365
#
#                                    object_obo
# 0  http://purl.obolibrary.org/obo/CHEBI_15422
# 1  http://purl.obolibrary.org/obo/CHEBI_15422
# 2  http://purl.obolibrary.org/obo/CHEBI_15422
# 3    http://purl.obolibrary.org/obo/PR_P01009
# 4  http://purl.obolibrary.org/obo/CHEBI_15361

# %%
df_new.to_csv('predication_files/kratom_pmid_all_predicates_umls_processed.tsv', sep='\t', index=False)

# %%
import pandas as pd
df = pd.read_csv('predication_files/kratom_pmid_all_predicates_umls_processed_triples.tsv', sep='\t')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   subject_obo    368 non-null    object
#  1   predicate_obo  368 non-null    object
#  2   object_obo     368 non-null    object
# dtypes: object(3)
# memory usage: 8.8+ KB

# %%
df = df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 362 entries, 0 to 367
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   subject_obo    362 non-null    object
#  1   predicate_obo  362 non-null    object
#  2   object_obo     362 non-null    object
# dtypes: object(3)
# memory usage: 11.3+ KB

# %%
#Create networkx graph from triples
import glob
import hashlib
import json
import networkx as nx  # type: ignore
import os
import os.path

from collections import Counter  # type: ignore
from more_itertools import unique_everseen  # type: ignore
from rdflib import BNode, Graph, Literal, Namespace, URIRef  # type: ignore
from rdflib.namespace import OWL, RDF, RDFS  # type: ignore
from rdflib.plugins.serializers.nt import _quoteLiteral  # type: ignore
import subprocess

from tqdm import tqdm  # type: ignore
from typing import Dict, List, Optional, Set, Tuple, Union

# set-up environment variables
obo = Namespace('http://purl.obolibrary.org/obo/')
oboinowl = Namespace('http://www.geneontology.org/formats/oboInOwl#')
schema = Namespace('http://www.w3.org/2001/XMLSchema#')

# %%
dfres = df_new[['subject_obo', 'predicate_obo', 'object_obo']]
dfres.head()
# Out:
#                                     subject_obo  \
# 0    http://purl.obolibrary.org/obo/CHEBI_36080
# 1     http://purl.obolibrary.org/obo/GO_0055085
# 2    http://purl.obolibrary.org/obo/CHEBI_16335
# 3      http://purl.obolibrary.org/obo/PR_Q8VYM2
# 4  http://purl.obolibrary.org/obo/MONDO_0005365
#
#                                predicate_obo  \
# 0  http://purl.obolibrary.org/obo/RO_0002448
# 1  http://purl.obolibrary.org/obo/RO_0002448
# 2  http://purl.obolibrary.org/obo/RO_0002448
# 3  http://purl.obolibrary.org/obo/RO_0002448
# 4  http://purl.obolibrary.org/obo/RO_0002448
#
#                                    object_obo
# 0  http://purl.obolibrary.org/obo/CHEBI_15422
# 1  http://purl.obolibrary.org/obo/CHEBI_15422
# 2  http://purl.obolibrary.org/obo/CHEBI_15422
# 3    http://purl.obolibrary.org/obo/PR_P01009
# 4  http://purl.obolibrary.org/obo/CHEBI_15361

# %%
dfres.to_csv('predication_files/kratom_pmid_all_predicates_umls_processed_triples.tsv', sep='\t', index=False)

# %%
import pandas as pd
import numpy as np

# %%
dfres = pd.read_csv('predication_files/kratom_pmid_all_predicates_umls_processed.tsv', sep='\t')
dfres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   subject_cui           356 non-null    object
#  1   subject_name          356 non-null    object
#  2   subject_source        368 non-null    object
#  3   predicate             368 non-null    object
#  4   object_source         368 non-null    object
#  5   object_cui            359 non-null    object
#  6   object_name           359 non-null    object
#  7   subj_reach_grounding  368 non-null    object
#  8   obj_reach_grounding   368 non-null    object
#  9   pmid                  368 non-null    int64
#  10  year                  368 non-null    object
#  11  belief                368 non-null    float64
#  12  sentence              368 non-null    object
#  13  predicate_obo         368 non-null    object
#  14  subject_obo           368 non-null    object
#  15  object_obo            368 non-null    object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 46.1+ KB

# %%
dfres['predicate'].value_counts()
# Out:
# Activation          179
# Inhibition          141
# IncreaseAmount       24
# DecreaseAmount       22
# Phosphorylation       1
# Deubiquitination      1
# Name: predicate, dtype: int64

# %%
URIRef(dfres.iloc[0]['subject_obo'])
# Out:
# rdflib.term.URIRef('http://purl.obolibrary.org/obo/CHEBI_36080')

# %%
##TODO - take OBO label instead of UMLS preferred name in future
##Also map all unmapped reach strings - saved in cui to ontology maps

# %%
#create rdflib graph from dataframe triples and serialize as ntriples file
graph  = Graph()
pred_label = URIRef("http://www.w3.org/2000/01/rdf-schema#label")
for i in range(len(df_new.index)):
    subj = df_new.at[i, 'subject_obo']
    obj = df_new.at[i, 'object_obo']
    pred = df_new.at[i, 'predicate_obo']
    subj_node = URIRef(subj)
    obj_node = URIRef(obj)
    predicate = URIRef(pred)
    subj_name = df_new.at[i, 'subject_name']
    obj_name = df_new.at[i, 'object_name']
    graph.add((subj_node, predicate, obj_node))
    graph.add((subj_node, pred_label, Literal(subj_name)))
    graph.add((obj_node, pred_label, Literal(obj_name)))

# %%
graph.serialize('output_graphs/machineread_kratom_version2.nt', format='nt')

# %%
def n3(node: Union[URIRef, BNode, Literal]) -> str:
    """Method takes an RDFLib node of type BNode, URIRef, or Literal and serializes it to meet the RDF 1.1 NTriples
    format.
    Src: https://github.com/RDFLib/rdflib/blob/c11f7b503b50b7c3cdeec0f36261fa09b0615380/rdflib/plugins/serializers/nt.py
    Args:
        node: An RDFLib
    Returns:
        serialized_node: A string containing the serialized
    """
    if isinstance(node, Literal): serialized_node = "%s" % _quoteLiteral(node)
    else: serialized_node = "%s" % node.n3()
    return serialized_node

# %%
for s,p,o in tqdm(graph):
    x = str(s)
    y = str(p)
    z = str(o)
    break
# Out:
#   0%|          | 0/656 [00:00<?, ?it/s]

# %%
df_new.head()
# Out:
#   subject_cui                                       subject_name  \
# 0    C0033684                                           Proteins
# 1    C0596902                        Membrane_Transport_Proteins
# 2    C0001473                          Adenosine_Triphosphatases
# 3    C3816745                                                 1+
# 4    C1955978  National_Institute_on_Deafness_and_Other_Commu...
#
#          subject_source   predicate         object_source object_cui  \
# 0    AATP1 gene product  Activation  ATP/ADP\ntransporter   C2744579
# 1   ATP/ADP transporter  Activation                   ATP   C2744579
# 2                ATPase  Activation                   ATP   C2744579
# 3              AtPHT5;1  Activation              SERPINA1   C0429863
# 4  NIDCD training grant  Activation                    PK   C0034348
#
#                                      object_name subj_reach_grounding  \
# 0                          ATP8A2_protein,_human         (None, None)
# 1                          ATP8A2_protein,_human         (None, None)
# 2                          ATP8A2_protein,_human         (None, None)
# 3  Pulsatility_index,_arterial_velocity_waveform         (None, None)
# 4                                Pyruvate_Kinase         (None, None)
#
#         obj_reach_grounding      pmid         year  belief  \
# 0              (None, None)   9545295  1998 Apr 17    0.65
# 1  ('CHEBI', 'CHEBI:15422')   9545295  1998 Apr 17    0.65
# 2  ('CHEBI', 'CHEBI:15422')  17628447     2007 Sep    0.65
# 3           {'UP': 'P01009'  29966288  2018 Jun 29    0.65
# 4              (None, None)  20665236     2010 Aug    0.65
#
#                                             sentence  \
# 0  The analysis of both,\ntopological arrangement...
# 1  ATP import into all types of plastids is media...
# 2  Proton translocation is crucial in maintaining...
# 3  The authors found that AtPHT5;1 mediated Pi in...
# 4  PK was supported by NIDCD training grant T32 D...
#
#                                predicate_obo  \
# 0  http://purl.obolibrary.org/obo/RO_0002448
# 1  http://purl.obolibrary.org/obo/RO_0002448
# 2  http://purl.obolibrary.org/obo/RO_0002448
# 3  http://purl.obolibrary.org/obo/RO_0002448
# 4  http://purl.obolibrary.org/obo/RO_0002448
#
#                                     subject_obo  \
# 0    http://purl.obolibrary.org/obo/CHEBI_36080
# 1     http://purl.obolibrary.org/obo/GO_0055085
# 2    http://purl.obolibrary.org/obo/CHEBI_16335
# 3      http://purl.obolibrary.org/obo/PR_Q8VYM2
# 4  http://purl.obolibrary.org/obo/MONDO_0005365
#
#                                    object_obo
# 0  http://purl.obolibrary.org/obo/CHEBI_15422
# 1  http://purl.obolibrary.org/obo/CHEBI_15422
# 2  http://purl.obolibrary.org/obo/CHEBI_15422
# 3    http://purl.obolibrary.org/obo/PR_P01009
# 4  http://purl.obolibrary.org/obo/CHEBI_15361

# %%
x = 'http://purl.obolibrary.org/obo/PR_P69345' 
y = 'http://purl.obolibrary.org/obo/RO_0002449'
z = 'http://purl.obolibrary.org/obo/GO_0001508'

# %%
df_new.loc[(df_new['subject_obo'] == x) & (df_new['object_obo'] == z)  & (df_new['predicate_obo'] == y)]
# Out:
#     subject_cui subject_name subject_source   predicate     object_source  \
# 271                                     IKr  Inhibition  action potential
# 294                                    traf  Inhibition  action potential
# 297                                          Inhibition  action potential
#
#     object_cui        object_name subj_reach_grounding   obj_reach_grounding  \
# 271   C0001272  Action_Potentials         (None, None)  ('GO', 'GO:0001508')
# 294   C0001272  Action_Potentials         (None, None)  ('GO', 'GO:0001508')
# 297   C0001272  Action_Potentials         (None, None)  ('GO', 'GO:0001508')
#
#          pmid         year  belief  \
# 271  31874991  2019 Dec 24    0.65
# 294  27260674  2016 Aug 15    0.65
# 297  27260674  2016 Aug 15    0.65
#
#                                               sentence  \
# 271  Inhibition of IKr by a wide range of drug mole...
# 294  Pentamidine prolongs the cardiac action potent...
# 297  Pentamidine prolongs the cardiac action potent...
#
#                                  predicate_obo  \
# 271  http://purl.obolibrary.org/obo/RO_0002449
# 294  http://purl.obolibrary.org/obo/RO_0002449
# 297  http://purl.obolibrary.org/obo/RO_0002449
#
#                                   subject_obo  \
# 271  http://purl.obolibrary.org/obo/PR_P69345
# 294  http://purl.obolibrary.org/obo/PR_P69345
# 297  http://purl.obolibrary.org/obo/PR_P69345
#
#                                     object_obo
# 271  http://purl.obolibrary.org/obo/GO_0001508
# 294  http://purl.obolibrary.org/obo/GO_0001508
# 297  http://purl.obolibrary.org/obo/GO_0001508

# %%
df_new.loc[(df_new['subject_obo'] == x) & (df_new['object_obo'] == z)  & 
                               (df_new['predicate_obo'] == y)]['pmid'].values[0]
# Out:
# 31874991

# %%
#convert rdflib graph to multidigraph - code borrowed from PheKnowLator: kg_utils.py
#use the pred key to also create a dictionary with metadata about the edge - 
#pub_year, pmid, source graph, belief
nx_mdg = nx.MultiDiGraph()
for s, p, o in tqdm(graph):
    #do not save label predicate to gpickle
    subj = str(s)
    obj = str(o)
    pred = str(p)
    if pred == 'http://www.w3.org/2000/01/rdf-schema#label':
        continue
    else:

        pred_key = hashlib.md5('{}{}{}'.format(n3(s), n3(p), n3(o)).encode()).hexdigest()
        pmid = str(df_new.loc[(df_new['subject_obo'] == subj) & (df_new['object_obo'] == obj)  & 
                       (df_new['predicate_obo'] == pred)]['pmid'].values[0])
        timestamp = str(df_new.loc[(df_new['subject_obo'] == subj) & (df_new['object_obo'] == obj)  & 
                                   (df_new['predicate_obo'] == pred)]['year'].values[0])
        belief_score = df_new.loc[(df_new['subject_obo'] == subj) & (df_new['object_obo'] == obj)  & 
                                   (df_new['predicate_obo'] == pred)]['belief'].values[0]
        nx_mdg.add_node(s, key=n3(s))
        nx_mdg.add_node(o, key=n3(o))
        nx_mdg.add_edge(s, o, **{'key': p, 'predicate_key': pred_key, 'weight':0.0,
                                 'pmid': pmid, 'timestamp': timestamp, 'source_graph': 'machine_read',
                                'belief': belief_score})
nx.write_gpickle(nx_mdg, "output_graphs/machineread_kratom_version2.gpickle")
# Out:
# 100%|██████████| 656/656 [00:01<00:00, 380.07it/s]

# %%
triples = len(graph)
nodes = len(set(list(graph.subjects()) + list(graph.objects())))
rels = len(set(list(graph.predicates())))
print(triples, nodes, rels)
# Out:
# 656 556 7

# %%
#this should have less edges than rdflib graph after removing 'labels'
nodes = nx.number_of_nodes(nx_mdg)
edges = nx.number_of_edges(nx_mdg)
density = nx.density(nx_mdg)
avg_deg = float(edges)/nodes
print(nodes, edges, density, avg_deg)
# Out:
# 272 362 0.004911004992402865 1.3308823529411764

# %%
#figure out how to extract information from saved gpickle predicate dictionary - pmid,

# %%
NV = nx_mdg.nodes()
i = 0
for (k,v) in NV.items():
    if i==20:
        break
    print('{}:{}'.format(k,v))
    i=i+1
# Out:
# http://purl.obolibrary.org/obo/CHEBI_36856:{'key': '<http://purl.obolibrary.org/obo/CHEBI_36856>'}
# http://purl.obolibrary.org/obo/PR_Q05421:{'key': '<http://purl.obolibrary.org/obo/PR_Q05421>'}
# http://purl.obolibrary.org/obo/PR_Q5EG47:{'key': '<http://purl.obolibrary.org/obo/PR_Q5EG47>'}
# http://purl.obolibrary.org/obo/GO_0005243:{'key': '<http://purl.obolibrary.org/obo/GO_0005243>'}
# http://purl.obolibrary.org/obo/CHEBI_80961:{'key': '<http://purl.obolibrary.org/obo/CHEBI_80961>'}
# http://purl.obolibrary.org/obo/CHEBI_16856:{'key': '<http://purl.obolibrary.org/obo/CHEBI_16856>'}
# http://purl.obolibrary.org/obo/CHEBI_4911:{'key': '<http://purl.obolibrary.org/obo/CHEBI_4911>'}
# http://purl.obolibrary.org/obo/CHEBI_39124:{'key': '<http://purl.obolibrary.org/obo/CHEBI_39124>'}
# http://purl.obolibrary.org/obo/CHEBI_27881:{'key': '<http://purl.obolibrary.org/obo/CHEBI_27881>'}
# http://purl.obolibrary.org/obo/PR_000001044:{'key': '<http://purl.obolibrary.org/obo/PR_000001044>'}
# http://purl.obolibrary.org/obo/CHEBI_4806:{'key': '<http://purl.obolibrary.org/obo/CHEBI_4806>'}
# http://purl.obolibrary.org/obo/PR_F1LP90:{'key': '<http://purl.obolibrary.org/obo/PR_F1LP90>'}
# http://purl.obolibrary.org/obo/GO_0006351:{'key': '<http://purl.obolibrary.org/obo/GO_0006351>'}
# http://purl.obolibrary.org/obo/GO_0006954:{'key': '<http://purl.obolibrary.org/obo/GO_0006954>'}
# http://purl.obolibrary.org/obo/CHEBI_35026:{'key': '<http://purl.obolibrary.org/obo/CHEBI_35026>'}
# http://purl.obolibrary.org/obo/CHEBI_5441:{'key': '<http://purl.obolibrary.org/obo/CHEBI_5441>'}
# http://purl.obolibrary.org/obo/CHEBI_16234:{'key': '<http://purl.obolibrary.org/obo/CHEBI_16234>'}
# http://purl.obolibrary.org/obo/PR_000015224:{'key': '<http://purl.obolibrary.org/obo/PR_000015224>'}
# http://purl.obolibrary.org/obo/PR_Q9UKG1:{'key': '<http://purl.obolibrary.org/obo/PR_Q9UKG1>'}
# http://purl.obolibrary.org/obo/CHEBI_9506:{'key': '<http://purl.obolibrary.org/obo/CHEBI_9506>'}

# %%
i = -1
for (s,o,k,d) in nx_mdg.edges(data=True, keys=True):
    i+=1
    if i==2:
        break
    print(s)
    print(o)
    print(k)
    print(d)
# Out:
# http://purl.obolibrary.org/obo/CHEBI_36856
# http://purl.obolibrary.org/obo/PR_Q05421
# http://purl.obolibrary.org/obo/RO_0002449
# {'predicate_key': '92e324b79c1218fb412629e2cc185585', 'weight': 0.0, 'pmid': '29356593', 'timestamp': '2018 Feb', 'source_graph': 'machine_read'}
# http://purl.obolibrary.org/obo/CHEBI_36856
# http://purl.obolibrary.org/obo/PR_Q05421
# http://purl.obolibrary.org/obo/RO_0002436
# {'predicate_key': 'e79d4f1ccf29afa3b87bde913d61c4eb', 'weight': 0.0, 'pmid': '29356593', 'timestamp': '2018 Feb', 'source_graph': 'machine_read'}

# %%
#save node labels as dictionary
#key: URI, value is label
label_dict = {}
for i in range(len(df_new.index)):
    subj = str(df_new.at[i, 'subject_obo'])
    obj = str(df_new.at[i, 'object_obo'])
    pred = str(df_new.at[i, 'predicate_obo'])
    if subj not in label_dict:
        label_dict[subj] = {}
        label_dict[subj]['entity_type'] = 'NODES'
        label_dict[subj]['label'] = df_new.at[i, 'subject_name']
        label_dict[subj]['cui'] = df_new.at[i, 'subject_cui']
    if obj not in label_dict:
        label_dict[obj] = {}
        label_dict[obj]['entity_type'] = 'NODES'
        label_dict[obj]['label'] = df_new.at[i, 'object_name']
        label_dict[obj]['cui'] = df_new.at[i, 'object_cui']
    if pred not in label_dict:
        label_dict[pred] = {}
        label_dict[pred]['entity_type'] = 'RELATIONS'
        label_dict[pred]['label'] = df_new.at[i, 'predicate']
len(label_dict)
# Out:
# 278

# %%
import pickle
with open('output_graphs/machineread_kratom_version2_NodeLabels.pickle', 'wb') as file_p:
    pickle.dump(label_dict, file_p)

# %%
dfmap = pd.DataFrame.from_dict(label_dict, orient='index')
dfmap.head()
# Out:
#                                            entity_type  \
# http://purl.obolibrary.org/obo/CHEBI_36080       NODES
# http://purl.obolibrary.org/obo/CHEBI_15422       NODES
# http://purl.obolibrary.org/obo/RO_0002448    RELATIONS
# http://purl.obolibrary.org/obo/GO_0055085        NODES
# http://purl.obolibrary.org/obo/CHEBI_16335       NODES
#
#                                                                   label  \
# http://purl.obolibrary.org/obo/CHEBI_36080                     Proteins
# http://purl.obolibrary.org/obo/CHEBI_15422        ATP8A2_protein,_human
# http://purl.obolibrary.org/obo/RO_0002448                    Activation
# http://purl.obolibrary.org/obo/GO_0055085   Membrane_Transport_Proteins
# http://purl.obolibrary.org/obo/CHEBI_16335    Adenosine_Triphosphatases
#
#                                                  cui
# http://purl.obolibrary.org/obo/CHEBI_36080  C0033684
# http://purl.obolibrary.org/obo/CHEBI_15422  C2744579
# http://purl.obolibrary.org/obo/RO_0002448        NaN
# http://purl.obolibrary.org/obo/GO_0055085   C0596902
# http://purl.obolibrary.org/obo/CHEBI_16335  C0001473

# %%
dfmap = dfmap.reset_index()
dfmap.head()
# Out:
#                                         index entity_type  \
# 0  http://purl.obolibrary.org/obo/CHEBI_36080       NODES
# 1  http://purl.obolibrary.org/obo/CHEBI_15422       NODES
# 2   http://purl.obolibrary.org/obo/RO_0002448   RELATIONS
# 3   http://purl.obolibrary.org/obo/GO_0055085       NODES
# 4  http://purl.obolibrary.org/obo/CHEBI_16335       NODES
#
#                          label       cui
# 0                     Proteins  C0033684
# 1        ATP8A2_protein,_human  C2744579
# 2                   Activation       NaN
# 3  Membrane_Transport_Proteins  C0596902
# 4    Adenosine_Triphosphatases  C0001473

# %%
dfmap = dfmap.rename(columns={"index":"entity_uri"})
dfmap.head()
# Out:
#                                    entity_uri entity_type  \
# 0  http://purl.obolibrary.org/obo/CHEBI_36080       NODES
# 1  http://purl.obolibrary.org/obo/CHEBI_15422       NODES
# 2   http://purl.obolibrary.org/obo/RO_0002448   RELATIONS
# 3   http://purl.obolibrary.org/obo/GO_0055085       NODES
# 4  http://purl.obolibrary.org/obo/CHEBI_16335       NODES
#
#                          label       cui
# 0                     Proteins  C0033684
# 1        ATP8A2_protein,_human  C2744579
# 2                   Activation       NaN
# 3  Membrane_Transport_Proteins  C0596902
# 4    Adenosine_Triphosphatases  C0001473

# %%
dfmap.to_csv('output_graphs/machineread_kratom_version2_NodeLabels.tsv', index=False, sep='\t')
